# %% [markdown]
# # The 5 Puctured Sphere Term Rewriting System

# %%
# %display latex
import string
from itertools import *
import re
import operator
import itertools
import functools
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
pool = ProcessPoolExecutor(8)
import concurrent.futures as futures
import pickle

# %% [markdown]
# ## Defining the Free Algebra

# %% [markdown]
# Let $s_A$ denote the simplest loop going around the punctures $A$.
# The skein algebra is an algebra over $Q[q]$.
# The variable $p$ is used in the `transform` function to allow more freedom in how coefficients act under symmetries.

# %%
G.<q> = FunctionField(QQ);
F.<p> = FunctionField(G)

# %% [markdown]
# It has central elements going around each puncture. For the 5-punctured sphere we therefore have the central elements $s_a, s_b, s_c, c_d$ and $s_{abcd}$, the loop around the final puncture. The variable $x,y,z,w$ are for finding errors in the relations.
# The algebra $P$ is the centre of the skein algebra.

# %%
P.<s_a,s_b,s_c, s_d, s_abcd,x,y,z,w> = PolynomialRing(F,9,order='neglex')

# %% [markdown]
# We now define the free algebra $A$ which is generated by the extended generators: `s_bcd` is the simple loop around the punctures b,c,d; `s_bc_ad` consists of a loop around b and c and a loop around a and d; `s_b_c_d` is the loop which contains points b and d and goes around c on the outside. The skein algebra of the 5-punctured sphere is a quotient of this algebra.

# %%
variables = ('s_ab, s_bc, s_cd, s_ad, '
             's_a_b_c, s_ab_cd, s_b_c_d, s_d_a_b, s_bc_ad, s_c_d_a, '
             's_a_bc_d, s_b_cd_a, s_c_da_b, s_d_ab_c, '
             's_ac, s_bd, s_abc, s_bcd, s_acd, s_abd').split(', ')
A = FreeAlgebra(P, order='neglex', names=variables)
for k, v in zip(variables, A._first_ngens(len(variables))):
    locals()[k] = v

# %%
s_ad_bc = s_bc_ad
s_cd_ab = s_ab_cd
s_c_ad_b = s_c_da_b

# %%
#Check ordering
s_ab < s_a_b_c < s_ac < s_abd
# Out:
# True

# %% [markdown]
# ## Rewriting System

# %% [markdown]
# In this section we define a class `RewritingSystem` which consists of the term rewriting rules. This class has methods which are used to reduce an expression by using term rewriting rules.
#
# The main functions are `replace` which makes a single reduction and `reduce_all` which reduces all the reduction rules: `reduce_all` is needed as the generated reduction rules will often have unreduced right hand sides.

# %% [markdown]
# The `to_gen_str` function takes an expression with powers and removes the powers e.g. `to_gen_str(s_ac^2) = s_ac*s_ac`. Firstly it replaces powers in the q coefficients: it places brackets around the result at this stage so that negative powers work correctly i.e. `to_gen_str(q^(-2)) = 1/(q*q)` rather than `1/q*q` which is just `1`. Then it removes powers in the monomials: at this stage it does not add brackets as brackets intefere with the regular expression used in `replace_rel`.

# %%
_sub1 = re.compile(r"([q]+)\^([0-9]+)")
_sub2 = re.compile(r"([a-z_]+)\^([0-9]+)")

def to_gen_str(expr):
    """Turn an expression into a string with no powers."""
    s = str(expr)
    qsub = (_sub1.sub(
                 (lambda m: "("+("*".join([m.group(1)]*int(m.group(2))))+")"),
                 s))
    return _sub2.sub(
                 (lambda m: ("*".join([m.group(1)]*int(m.group(2))))),
                 qsub)

# %%
to_gen_str(s_a_b_c^2 * s_bcd)
# Out:
# 's_a_b_c*s_a_b_c*s_bcd'

# %%
class RewritingSystem:
    def __init__(self, rels):
        self._rep_table = [
            (re.compile(f"{re.escape(to_gen_str(a))}(?![a-z_])"), f"({to_gen_str(b)})")
            for a, b in rels.items()
        ]
        self.rels = rels
        
    def __getitem__(self, key):
        """Return the reduction rule associated to the monomial key."""
        return self.rels[key]
    
    def __len__(self):
        """Count the number of reduction rules."""
        return len(self.rels)
    
    def __iter__(self):
        yield from self.rels
        
    def replace(self, expr):
        """Apply a single reduction to an expression."""
        expr_s1 = to_gen_str(expr)
        for pattern, res in self._rep_table:
            expr_s2 = pattern.sub(res, expr_s1, count=1)
            if expr_s1 != expr_s2:
                break
            expr_s1 = expr_s2
        return eval(expr_s2)
    
    def replace_with_rule(self, expr):
        """Apply a single reduction to an expression and return the result together with the reduction rule used."""
        expr_s1 = to_gen_str(expr)
        for (a, b), (pattern, res) in zip(self.rels.items(), self._rep_table):
            expr_s2 = pattern.sub(res, expr_s1, count=1)
            if expr_s1 != expr_s2:
                break
            expr_s1 = expr_s2
        return eval(expr_s2), {a: b}
    
    def reduce_all(self):
        """Reduces all the reduction rules using the RewritingSystem itself to do the reductions."""
        rw = {}
        reduced_bs = (pool.submit(self.reduce_rel, a, b) for a,b in self.rels.items())
        for fut in futures.as_completed(reduced_bs):
            a, b = fut.result()
            print(f"{a} : {b}")
            rw.update({a:b})
        return RewritingSystem(rw)
    
    def reduce_all_seq(self):
        """Reduces all the reduction rules like reduce_all but sequentially rather than inputing to the futures pool"""
        rw = {}
        reduced_bs = (self.reduce_rel(a, b) for a,b in self.rels.items())
        for (a,b) in reduced_bs:
            print(f"{a} : {b}")
            rw.update({a:b})
        return RewritingSystem(rw)
                      
    def reduce_rel(self, a, b):
        """Prints a and tries to reduce b using the RewritingSystem"""
        print(a)
        try:
            return a, reduce(b, self)
        except RecursionError:
            print(f"recursion error occurred on {a}")
            raise

# %% [markdown]
# ## Reduction Functions

# %% [markdown]
# We now define the functions which reduce an expression using a RewritingSystem. The main function is `reduce(expr, rels, max_reductions)` but we also define `reduction_table(expr,rels, nrows)` which creates a table where each row applies a single reduction. To prevent infinite loops, for example when there is an error in the relations, these functions we stop after a set number of reductions.

# %%
class LoopException(Exception):
    pass

# %%
def multi_rep(expr, rels):
    """Create a generator object which applies a reduction at each interative step"""
    yield expr
    expr1 = rels.replace(expr)
    if expr == expr1:
        return
    expr = expr1
    yield from multi_rep(expr, rels)

# %%
def reduce(expr, rels, max_reductions=None):
    """Fully reduces an expression using a RewritingSystem with a max_reductions cap"""
    for i, res in enumerate(multi_rep(expr, rels)):
        if max_reductions is not None and i >= max_reductions:
            raise LoopException()
    return res

# %%
def multi_rep_with_rule(expr, rels, rule=None):
    """Similar to multi_rep but also outputs the rule applied"""
    yield expr, rule
    expr1, rule = rels.replace_with_rule(expr)
    if expr == expr1:
        return
    expr = expr1
    yield from multi_rep_with_rule(expr, rels, rule=rule)

# %%
def reduction_table(expr,rels, nrows):
    """Reduce an expression and create a table of each step."""
    reductions = itertools.islice(
    multi_rep_with_rule(expr, rels), 0, nrows+1)
    return table([["","Reduction table for "+str(expr),"reduction rule"]]+[[i, red, rule] for i, (red, rule) in enumerate(reductions)], header_row=True)

# %%
reduction_table(s_a*s_b*s_a*s_b^2, RewritingSystem({s_a*s_b: s_c}), 5)
# Out:
#       Reduction table for s_a^2*s_b^3   reduction rule
# +---+---------------------------------+----------------+
#   0   s_a^2*s_b^3                       None
#   1   s_a*s_b^2*s_c                     {s_a*s_b: s_c}
#   2   s_b*s_c^2                         {s_a*s_b: s_c}

# %% [markdown]
# Instead of stopping after a set number of interations one could also time out the function after a set amount of time. We do not use this function at the moment.

# %%
thread_pool = ThreadPoolExecutor(100)

def run_or_timeout(f, timeout=None, timeout_value=None):
    """Runs a function f for a set maximum amount of time"""
    try:
        return thread_pool.submit(f).result(timeout=timeout)
    except:
        return timeout_value

# %% [markdown]
# ## Ambiguity Checking Functions

# %% [markdown]
# In this section we define the functions which are used to check overlap ambiguities i.e. expressions $abc$ where both $ab$ and $bc$ have a replacement rule. The main function is `check_amb(a, b, c, rels, max_reductions)` which checks this ambiguity.

# %%
def left_reduce(a,b,c,rels, max_reductions=None):
    """Reduce abc starting with the left ab reduction"""
    if a*b in rels:
        return reduce(RewritingSystem({a*b: rels[a*b]}).replace(a*b*c),rels, max_reductions=max_reductions)
    else: 
        return "no relation"
    
def right_reduce(a,b,c,rels, max_reductions=None):
    """Reduce abc starting with the right bc reduction"""
    if b*c in rels:
        return reduce(RewritingSystem({b*c: rels[b*c]}).replace(a*b*c),rels)
    else: 
        return "no relation"

# %% [markdown]
# The `amb_reduction_table` is similar to `reduction_table` but only works for the expression $abc$ and takes an extra argument which is either `"l"` or `"r"` and produces the reduction table for either the left or the right reduction of $abc$.

# %%
def amb_reduction_table(a,b,c,lr, rels, ncols):
    """Produce a left or right reduction table for the expression abc"""
    if lr == "l":
        leftreductions = itertools.islice(
            multi_rep_with_rule(RewritingSystem({a*b: rels[a*b]}).replace(a*b*c), rels), 0, ncols+1)
        return table([["","Reduction table for "+"("+str(a*b)+")*"+str(c), "left reduction rule"]]+[[i, red, rule] for i, (red, rule) in enumerate(leftreductions)], header_row=True)
    elif lr == "r":
        rightreductions = itertools.islice(
            multi_rep_with_rule(RewritingSystem({b*c: rels[b*c]}).replace(a*b*c), rels), 0, ncols+1)
        return table([["","Reduction table for "+str(a)+"*("+str(b*c)+")", "right reduction rule"]]+[[i, red, rule] for i, (red, rule) in enumerate(rightreductions)], header_row=True)
    else:
        print("must specify left l or right r")

# %% [markdown]
# The function `check_amb` checks the ambiguity $abc$. If the ambiguity is resolvable is returns `"consistent"`. If there is no relation a*b or b*c then it returns `"no relation"`. It raises a `LoopException` if the number of reductios exceeds a set amount.

# %%
def check_amb(a, b, c, rels, max_reductions=20):
    """Checks that abc can be unambiguously reduced."""
    if (a*b in rels) and (b*c in rels):
        try:
            l = left_reduce(a,b,c,rels, max_reductions)
            r = right_reduce(a,b,c,rels, max_reductions)
            if l == r:
                return "consistent"
            else:
                diff = l - r
                return diff
        except LoopException:
            return "max reductions exceeded"
    else: 
        return "no relation"

# %% [markdown]
# ## Auxilary Functions

# %%
def s(lst):
    """Construct a loop from a list specifying the points"""
    return eval('s'+"".join(['_'+"".join(sorted(p)) for p in lst]))

def letters(a):
    """Return all the point letters in the string a."""
    return set(re.findall(r'[abcd]', str(a)))

def loop_points(loop):
    """Return all points which are used to define the loop."""
    return re.split(r'\_', str(loop))[1:]

def loop_point_groups(m):
    """Extract the subscript of a loop."""
    return re.findall(r'[abcd]+', str(m))

# %%
[s(["a", "bc", "d"]), s(["ad"]), s(["ab", "cd"])]
# Out:
# [s_a_bc_d, s_ad, s_ab_cd]

# %%
loop_points(s_a_b_c)
# Out:
# ['a', 'b', 'c']

# %%
loop_point_groups(s_c_ad_b)
# Out:
# ['c', 'da', 'b']

# %%
def make_subject(lhs, rhs, term):
    """Make the monomial term the subject of the equation lhs=rhs."""
    if term in lhs.monomials():
        return make_subject(rhs, lhs, term)
    if term in rhs.monomials():
        coeff = [c for (t,c) in list(rhs) if t == term]
        return {term: 1/coeff[0]*(lhs - rhs + coeff[0]*term)}
    return "monomial not in expression"

# %%
def terms_of_product(monomial):
    """Return a list of the loops in a monomial."""
    return eval('[' + str(monomial).replace('*', ',', -1).replace('^', '**', -1) + ']')

# %%
terms_of_product(s_ad*s_a_b_c*s_ab_cd)
# Out:
# [s_ad, s_a_b_c, s_ab_cd]

# %%
def is_ordered(mon):
    """Test if a monomial is ordered."""
    return terms_of_product(to_gen_str(mon)) == sorted(terms_of_product(to_gen_str(mon)))

def ordered_key(key):
    """Order the monomial key."""
    return sorted(terms_of_product(key)) == terms_of_product(key)

def reverse(k):
    """Reverse the terms in a monomial."""
    lst = terms_of_product(to_gen_str(k))
    lst.reverse()
    return prod(lst)

# %%
is_ordered(s_ad*s_ab^2) == False
# Out:
# True

# %%
is_ordered(s_bc*s_cd) == True
# Out:
# True

# %%
ordered_key(s_ab*s_cd) == True
# Out:
# True

# %%
ordered_key(s_cd*s_ab) == False
# Out:
# True

# %% [markdown]
# Lists of simple generators and non-simple generators:

# %%
simple_terms = [loop for loop in A.gens() if len(loop_point_groups(loop))==1]

# %%
m_terms = [loop for loop in A.gens() if not loop in simple_terms]

# %% [markdown]
# ## Symmetry Functions

# %% [markdown]
# Give a relation we can generate other relations from it. Using `generate_symmetric` we can generate the relations formed by reflecting all the loops horizontally or vertically (and changing the coefficients) and using `generate_undercrossing` we generate the relation formed by changing all overcrossing to undercrossing and vice versa (and changing the coefficients).

# %%
def transform(expr, loop_fn=None, coeff_trans=1/q, p_trans=1/q):
    """Transform expr using loop_fn to transform the loops and coeff_trans and p_trans to change the p and q coeffients"""
    return sage_eval(str(expr), 
                     locals=dict(q=coeff_trans,p=p_trans,
                                 **{str(y): loop_fn(y) for y in P.gens()}, 
                                 **{str(z): loop_fn(z) for z in A.gens()},))

# %%
# Loop transformation functions
def swap(loop,pt1,pt2):
    """Transform a loop by swapping the points pt1 and pt2"""
    expr = str(loop)
    expr = re.sub(pt1, 'a1', expr)
    expr = re.sub(pt2, pt1, expr)
    return re.sub('a1', pt2, expr)

def horizontal_flip(loop):
    """Flip a loop horizontally. Assumes have 4 points."""
    lst = loop_points(swap(swap(loop, 'a', 'b'), 'c', 'd'))
    lst.reverse()
    return s(lst)

def vertical_flip(loop):
    """Flip a loop vertically. Assumes have 4 points."""
    lst = loop_points(swap(swap(loop, 'a', 'd'), 'b', 'c'))
    lst.reverse()
    return s(lst)

# %%
#tests
[horizontal_flip(s_a_b_c) == s_d_a_b,
vertical_flip(s_abc) == s_bcd,
 horizontal_flip(s_ab_cd) == s_ab_cd,
]
# Out:
# [True, True, True]

# %%
transform(q^2*s_c*s_abc + s_a + p, horizontal_flip)
# Out:
# (1/q+s_b) + 1/q^2*s_d*s_abd

# %%
def generate_symmetric(rel_dict):
    """Add to rel_dict all relations which are flips of the original relations."""
    gen_rels = {}
    for k,r in rel_dict.items():
        gen_rels.update({
        #both horizontal and vertical flip
        transform(transform(k, vertical_flip), horizontal_flip): transform(transform(r, vertical_flip), horizontal_flip),
        #horizontal flip
        transform(k, horizontal_flip): transform(r, horizontal_flip),
        #vertical flip
        transform(k, vertical_flip): transform(r, vertical_flip),
        #original relation
        k: r,
        })
    return gen_rels

# %%
def generate_undercrossing(rel_dict):
    """Add to rel_dict the undercrossing relations."""
    gen_rels = {}
    for k,r in rel_dict.items():
        m = terms_of_product(k)
        #Assume key of length 2 as that is all we need here.
        if len(m) == 2:
            gen_rels.update({m[0]*m[1]: transform(r, lambda x:x, q, q)})
            gen_rels.update({m[1]*m[0]: transform(r, lambda x:x, 1/q, q)})
    return gen_rels

# %% [markdown]
# ## Term Rewriting System

# %% [markdown]
# We now define the term rewriting system which generated from the relations on the skein algebra of the four punctured sphere and where all the relations have keys of length 2.

# %% [markdown]
# #### Basic Relations
# These relations are the interesting relations for the skein algebra which are not generated from other relations.

# %%
simple = {
        #double cross relation 
        s_ac*s_bd: (q^(-2)*s_ab*s_cd + q^2*s_bc*s_ad
                 + q^(-1)*s_a*s_b*s_cd + q^(-1)*s_c*s_d*s_ab + q*s_a*s_d*s_bc + q*s_b*s_c*s_ad
                 + s_a*s_bcd + s_d*s_abc + s_c*s_abd + s_b*s_acd
                 + s_a*s_b*s_c*s_d + (q+q^(-1))*s_abcd
                ),
        #double and triple cross relation
        s_ac*s_bcd: (q*p*(s_bc*s_acd - p*s_abd - s_c*s_abcd - s_b*s_ad) 
                     + q^(-1)*p^(-1)*(s_cd*s_abc - p^(-1)*s_abd - s_c*s_abcd - s_d*s_ab) 
                     + s_c*s_abcd + s_a*s_b_c_d),
        
        #triple loop relations
        s_abc*s_acd: q*s_d_a_b + q^(-1)*s_b_c_d + s_abcd*s_ac + s_b*s_d,
        s_bcd*s_abc: q*s_a_bc_d + q^(-1)*s_ad + s_a*s_d + s_abcd*s_bc,
        s_abc*s_abd: q*s_d_ab_c + q^(-1)*s_cd + s_c*s_d + s_abcd*s_ab,
    
        #cubic
        s_a_b_c*s_ac: (  q^2*s_ab^2 + s_b^2 + q*s_a*s_b*s_ab + s_c^2
                       + s_abc^2 + q^(-2)*s_bc^2 + q^(-1)*s_a*s_bc*s_abc
                       + q*s_c*s_ab*s_abc + q^(-1)*s_b*s_c*s_bc + s_a*s_b*s_c*s_abc
                       - (q + q^(-1))^2 + s_a^2 ),
        #cubic with triple
        s_a_b_c*s_acd: ( q^2*s_ab*s_abd + s_b*s_bd + q*s_a*s_b*s_abd + s_c*s_cd
                        + s_abcd*s_abc + q^(-2)*s_bc*s_bcd + q^(-1)*s_a*s_abcd*s_bc
                        + q*s_c*s_abcd*s_ab + q^(-1)*s_b*s_c*s_bcd + s_a*s_b*s_c*s_abcd
                        + (q + q^(-1))*s_d + s_a*s_ad),
    
        #quadratic
        s_ab*s_b_cd_a: (q^2*s_acd^2 + s_cd^2 + q*s_a*s_cd*s_acd + s_b^2
                        + s_abcd^2 + q^(-2)*s_bcd^2 + q^(-1)*s_a*s_abcd*s_bcd
                        + q*s_b*s_abcd*s_acd + q^(-1)*s_b*s_cd*s_bcd + s_a*s_b*s_abcd*s_cd
                        - (q + q^(-1))^2 + s_a^2),
    
        s_bc*s_c_ad_b: (q^2*s_abd^2 + s_abcd^2 + q*s_c*s_abcd*s_abd + s_b^2
                        + s_ad^2 + q^(-2)*s_acd^2 + q^(-1)*s_c*s_ad*s_acd
                        + q*s_b*s_ad*s_abd + q^(-1)*s_b*s_abcd*s_acd + s_b*s_c*s_abcd*s_ad
                        - (q + q^(-1))^2 + s_c^2),
    
    }

simple_relations = generate_symmetric(generate_undercrossing(simple))

# %%
#length test
len(simple_relations) == 46
# Out:
# True

# %% [markdown]
# #### Commutative Relations
# These are the relations of the form {ab: ba} which specify when two loops commute.

# %%
def generate_commutative():
    """Generate commutative relations."""
    commutative_pairs = [ 
        (s_ab, s_cd), (s_bc, s_ad), 
        (s_ab, s_abc), (s_bc, s_abc), (s_ac, s_abc), 
        #higher commutative
        (s_bc, s_a_bc_d), (s_ab, s_d_ab_c)
    ]
    rels = generate_symmetric({x[1]*x[0]: x[0]*x[1] for x in commutative_pairs})
    return {r[0]:r[1] for r in rels.items() if not is_ordered(r[0])}

# %%
commutative_rels = generate_commutative()

# %%
#length test
len(commutative_rels) == 18
# Out:
# True

# %%
#test all keys are not ordered
len(list(filter( lambda x: is_ordered(x) , commutative_rels.keys()))) == 0
# Out:
# True

# %%
def is_commutative(a, b):
    """Test if a and b commute."""
    return a*b in commutative_rels or b*a in commutative_rels or a==b or a in P or b in P

# %% [markdown]
# #### Commutators between Simple Loops

# %% [markdown]
# We now add all the relations of the form $[s_A, s_B]_q = (q^2 - q^{-2}) s_{A \cup B - A \cap B} + (q - q^{-1}) (s_{A \cap B} s_{A \cup B} + s_{A - A \cap B} s_{B - A \cap B})$ where $[s_A, s_B]_q := q s_A s_B - q^{-1} s_B s_A$ is the quantum Lie bracket.

# %%
def generate_commutator(a, b, r1, r2):
    """Given the monomials of the commutator generator the standard commutator."""
    if a>b:
        return (a*b, q^2*b*a + (q^(-1) - q^3)*r1 + (1-q^2)*r2)
    if b>a:
        return (b*a, q^(-2)*a*b + (q - q^(-3))*r1 + (1-q^(-2))*r2)
    raise ValueError(f"{a,b}")

# %%
def commutator_symmetries(lst):
    """Generate all the symmetric standard commutators given a list of standard commutator relations."""
    full = lst
    for a,b,r1,r2 in lst:
        full = full + list(filter(lambda y: {y[0], y[1]} != {a,b} ,[tuple(map(lambda x: transform(x, horizontal_flip), (b,a,r1,r2))),
                                               tuple(map(lambda x: transform(x, vertical_flip), (b,a,r1,r2))),
                                               tuple(map(lambda x: transform(transform(x, vertical_flip), horizontal_flip), (a,b,r1,r2)))]))
    return full

# %%
def generate_commutators():
    """Generates the standard commutators for the n=4 case."""
#    s_d_a_bc = p*(s_ad*s_abc -p*s_bcd - s_a*s_abcd - s_d*s_bc)
#    s_a_b_cd = p*(s_ab*s_bcd - p*s_acd - s_b*s_abcd - s_a*s_cd)
#    s_ab_c_d = p^(-1)*(s_cd*s_abc - p^(-1)*s_abd - s_c*s_abcd - s_d*s_ab)

    s_d_a_bc = q*(s_ad*s_abc -q*s_bcd - s_a*s_abcd - s_d*s_bc)
    s_a_b_cd = q*(s_ab*s_bcd - q*s_acd - s_b*s_abcd - s_a*s_cd)
    s_ab_c_d = q^(-1)*(s_cd*s_abc - q^(-1)*s_abd - s_c*s_abcd - s_d*s_ab)
    
    commutator_lst = [
    # doubles
    (s_ab, s_ad, s_bd, (s_a*s_abd + s_b*s_d)),
    (s_ab, s_ac, s_bc, (s_a*s_abc + s_b*s_c)),
    (s_bc, s_bd, s_cd, (s_b*s_bcd + s_c*s_d)),
    # double and triple
    (s_abc, s_ad, s_bcd, (s_a*s_abcd + s_d*s_bc)),
    (s_bcd, s_ab, s_acd, (s_b*s_abcd + s_a*s_cd)),
    #higher commutators
    (s_bc, s_d_ab_c, s_d_a_b, (s_b*s_d + s_c*s_d_a_bc)),
    (s_a_bc_d, s_a_b_c, s_cd, (s_c*s_d + s_a*s_a_b_cd)),
    (s_a_bc_d, s_ab, s_b_c_d, (s_b*s_d + s_a*s_ab_c_d)),
     ]
    rels = dict(generate_commutator(*x) for x in commutator_symmetries(commutator_lst))
    
    rels_system = RewritingSystem(rels)
    m_dict = RewritingSystem({s_ab*s_cd: s_ab_cd, s_bc*s_ad: s_bc_ad, s_cd*s_ab: s_ab_cd, s_ad*s_bc: s_bc_ad})
    backwards = RewritingSystem({ m_dict[k]:k  for k in m_dict})
    
    for k in [s_c_da_b*s_ab_cd, s_a_bc_d*s_ab_cd, s_b_cd_a*s_bc_ad, s_d_ab_c*s_bc_ad]:
        rels.update({k: reduce(reduce(reduce(k, backwards), rels_system), m_dict)})
    
    return rels

# %%
base_commutators = generate_commutators()

# %%
#length test
len(base_commutators) == 20
# Out:
# False

# %%
#test all keys are not ordered
len(list(filter( lambda x: is_ordered(x) , base_commutators.keys()))) == 0
# Out:
# True

# %% [markdown]
# #### Generate Extra Generators

# %% [markdown]
# These are the relations which generate the extra generators from the orginal simple generators.

# %%
def generate_m_generators():
    """Generate the relations used to generate the extended generators from the basic ones."""
    rels = { 
        # single missing point   
        s_ab*s_bc: q^(-1)*s_a_b_c + q*s_ac + s_a*s_c + s_b*s_abc,
        s_ab*s_cd: s_ab_cd,
        s_bc*s_ad: s_bc_ad,
        
        # two missing points
        s_ab*s_b_c_d: (q^(-1)*s_a_bc_d + s_a*s_d 
                   + q*p^(-1)*(s_cd*s_ac - p^(-1)*s_ad - s_a*s_d - s_c*s_acd)
                   + p^(-1)*s_b*(s_cd*s_abc - p^(-1)*s_abd - s_d*s_ab - s_c*s_abcd)),
        s_ad*s_a_b_c: (q^(-1)*s_d_ab_c + s_c*s_d 
                   + q*p^(-1)*(s_bc*s_bd - p^(-1)*s_cd - s_b*s_bcd - s_c*s_d)
                   + p^(-1)*s_a*(s_bc*s_abd - p^(-1)*s_acd - s_c*s_ad - s_b*s_abcd)), 
    }
    
    rels = generate_symmetric(generate_undercrossing(rels))
    
    rels2 = {
        # with commutative generators (all overcrossings changed to undercrossing)
        s_ab*s_bc_ad: q*s_ac*s_ad + q^(-1)*rels[s_a_b_c*s_ad] + s_b*s_abc*s_ad + s_a*s_c*s_ad,
        s_bc_ad*s_ab: q^(-1)*s_ad*s_ac + q*rels[s_ad*s_a_b_c] + s_b*s_ad*s_abc + s_a*s_c*s_ad,
        
        s_ab_cd*s_ad: q*s_ab*s_ac + q^(-1)*rels[s_ab*s_c_d_a] + s_d*s_ab*s_acd + s_a*s_c*s_ab,
        s_ad*s_ab_cd: q^(-1)*s_ac*s_ab + q*rels[s_c_d_a*s_ab] + s_d*s_acd*s_ab + s_a*s_c*s_ab,
    } 
    
    return {**rels, **generate_symmetric(rels2)}

# %%
m_relations = generate_m_generators()
m_rules = RewritingSystem(m_relations)

# %% [markdown]
# #### Rewriting Systems with Simple Relations

# %% [markdown]
# We construct the RewritingSystems used to generate the higher relations.
#
# `reordering_rw` consists of all the simple reordering relations $ba$ not including when there is a non-trivial relation between a and b e.g. a cross relation as they are in `simple_relations` and cannot be used to generate a higher commutator.

# %%
reordering = {
    **commutative_rels,
    **generate_commutators(),
}

reordering_rw = RewritingSystem(reordering)

# %%
reordering[s_d_ab_c*s_bc]
# Out:
# (((q^2-1)/q^2)*s_b*s_d+((-q^2+1)/q)*s_a*s_c*s_abcd) + (((-q^2+1)/q)*s_c*s_d)*s_bc + ((q^4-1)/q^3)*s_d_a_b + ((-q^2+1)*s_c)*s_bcd + 1/q^2*s_bc*s_d_ab_c + (((q^2-1)/q)*s_c)*s_ad*s_abc

# %%
#Check only missing expected number of terms b*a
len([b*a for a, b in combinations(simple_terms, 2) if not b*a in reordering]) == 11
# Out:
# True

# %%
#test can now reorder all simple generators
len([b*a for a, b in combinations(simple_terms, 2) if not b*a in {**reordering, **simple_relations}]) == 0
# Out:
# True

# %% [markdown]
# We combine all the basic relations together into two RewritingSystems: `basic_m_rw` with the m_relations and `basic_rw` without.

# %%
basic_rels = {**reordering, **simple_relations}
basic_m_rels = {**reordering, **simple_relations, **m_relations}

# %%
basic_rw = RewritingSystem({**reordering, **simple_relations})
basic_m_rw = RewritingSystem(basic_m_rels)

# %% [markdown]
# #### Generate Higher Commutators

# %% [markdown]
# Autogenerate relations from the commutativity and commutator relations.

# %%
def s_term_prod(m):
    """Given a generator m generate the product of simple generators which generates m using the m_relations."""
    letters = re.findall(r'[abcd]', str(m))
    if m in [s_ab, s_bc, s_cd, s_ad, s_ac, s_bd, s_abc, s_bcd, s_acd, s_abd]:
        return m
    if m in [s_a_b_c, s_b_c_d, s_c_d_a, s_d_a_b]:
        sa = eval('s_'+"".join(sorted(letters[:2])))
        sb = eval('s_'+"".join(sorted(letters[1:])))
        return sa*sb
    if m in [s_ab_cd, s_bc_ad]:
        sa = eval('s_'+"".join(sorted(letters[:2])))
        sb = eval('s_'+"".join(sorted(letters[2:])))
        return sa*sb
    if m in [s_a_bc_d, s_b_cd_a, s_c_ad_b, s_d_ab_c]:
        sa = eval('s_'+"".join(sorted(letters[:2])))
        sb = eval('s_'+"".join(sorted(letters[1:3])))
        sc = eval('s_'+"".join(sorted(letters[2:])))
        return sa*sb*sc
    

def is_s_term_ordered(k):
    return is_ordered(prod([ s_term_prod(x) for x in terms_of_product(k) ]))

# %%
s_term_prod(s_c_ad_b)
# Out:
# s_cd*s_ad*s_ab

# %%
def generate_commutator(b, a):
    """Takes two generators a and b of which at least one is non-simple and generates a commutator relation
    based on the relations reordering_rw gives us on the simple generators."""
    if a>=b:
        raise ValueError(f'{b} is not larger than {a}')
    s1l = sorted(terms_of_product(s_term_prod(b))); s1 = prod(s1l)
    s2l = sorted(terms_of_product(s_term_prod(a))); s2 = prod(s2l)
    if is_ordered(s1*s2):
        print('case 1')
        print(s2*s1)
        l = reduce(s2, m_rules)*reduce(s1, m_rules)
        r = reduce(reduce(s2*s1, reordering_rw), m_rules)
        print(f'l is {l} and r is {r}')
        return make_subject(l, r, b*a)    
    if s1l[0] >= s2l[-1]:
        print(s1*s2)
        print('case 2')
        l = reduce(s1, m_rules)*reduce(s2, m_rules)
        r = reduce(reduce(s1*s2, reordering_rw), m_rules)
        print(f'l is {l} and r is {r}')
        return make_subject(l, r, b*a)
    return {}

# %%
generate_commutator(s_a_b_c, s_bc)
# Out:
# case 1
# s_bc*s_ab*s_bc
# l is s_a*s_c*s_bc + 1/q*s_bc*s_a_b_c + q*s_bc*s_ac + s_b*s_bc*s_abc and r is (((q^6-q^4-q^2+1)/q)*s_a*s_b) + ((q^8-2*q^4+1)/q^2)*s_ab + s_a*s_c*s_bc + (((q^6-q^4-q^2+1)/q)*s_c)*s_abc + (-q^5+q)*s_bc*s_ac + ((-q^2+1)*s_b)*s_bc*s_abc + q*s_a_b_c*s_bc + q^3*s_ac*s_bc + q^2*s_b*s_abc*s_bc
# {s_a_b_c*s_bc: (((-q^6+q^4+q^2-1)/q^2)*s_a*s_b) + ((-q^8+2*q^4-1)/q^3)*s_ab + (((-q^6+q^4+q^2-1)/q^2)*s_c)*s_abc + 1/q^2*s_bc*s_a_b_c + q^4*s_bc*s_ac + q*s_b*s_bc*s_abc + (-q^2)*s_ac*s_bc + ((-q)*s_b)*s_abc*s_bc}

# %%
def higher_commutators():
    """Apply generate_commutator(a,b) to all relevant pairs."""
    gen_rels = {}
    for a, b in combinations(A.gens(),2):
        if not b*a in basic_rw and not b*a in m_rules:
            print(b,a)
            gen_rels.update(generate_commutator(b,a))
    return gen_rels

# %%
all_commutators = higher_commutators()
# Out:
# s_a_b_c s_ab
# s_ab*s_bc*s_ab
# case 2
# l is s_a*s_c*s_ab + 1/q*s_a_b_c*s_ab + q*s_ac*s_ab + s_b*s_abc*s_ab and r is s_a*s_c*s_ab + q*s_ab*s_a_b_c + 1/q*s_ab*s_ac + s_b*s_ab*s_abc
# s_ab_cd s_ab
# s_ab*s_cd*s_ab
# case 2
# l is s_ab_cd*s_ab and r is s_ab*s_ab_cd
# s_d_a_b s_ab
# s_ab*s_ad*s_ab
# case 2
# l is s_b*s_d*s_ab + q*s_d_a_b*s_ab + 1/q*s_bd*s_ab + s_a*s_abd*s_ab and r is s_b*s_d*s_ab + 1/q*s_ab*s_d_a_b + q*s_ab*s_bd + s_a*s_ab*s_abd
# s_a_b_c s_bc
# case 1
# s_bc*s_ab*s_bc
# l is s_a*s_c*s_bc + 1/q*s_bc*s_a_b_c + q*s_bc*s_ac + s_b*s_bc*s_abc and r is (((q^6-q^4-q^2+1)/q)*s_a*s_b) + ((q^8-2*q^4+1)/q^2)*s_ab + s_a*s_c*s_bc + (((q^6-q^4-q^2+1)/q)*s_c)*s_abc + (-q^5+q)*s_bc*s_ac + ((-q^2+1)*s_b)*s_bc*s_abc + q*s_a_b_c*s_bc + q^3*s_ac*s_bc + q^2*s_b*s_abc*s_bc
# s_b_c_d s_bc
# s_bc*s_cd*s_bc
# case 2
# l is s_b*s_d*s_bc + 1/q*s_b_c_d*s_bc + q*s_bd*s_bc + s_c*s_bcd*s_bc and r is s_b*s_d*s_bc + q*s_bc*s_b_c_d + 1/q*s_bc*s_bd + s_c*s_bc*s_bcd
# s_bc_ad s_bc
# s_bc*s_ad*s_bc
# case 2
# l is s_bc_ad*s_bc and r is s_bc*s_bc_ad
# s_ab_cd s_cd
# case 1
# s_cd*s_ab*s_cd
# l is s_cd*s_ab_cd and r is s_ab_cd*s_cd
# s_b_c_d s_cd
# case 1
# s_cd*s_bc*s_cd
# l is s_b*s_d*s_cd + 1/q*s_cd*s_b_c_d + q*s_cd*s_bd + s_c*s_cd*s_bcd and r is (((q^6-q^4-q^2+1)/q)*s_b*s_c) + ((q^8-2*q^4+1)/q^2)*s_bc + s_b*s_d*s_cd + (((q^6-q^4-q^2+1)/q)*s_d)*s_bcd + (-q^5+q)*s_cd*s_bd + ((-q^2+1)*s_c)*s_cd*s_bcd + q*s_b_c_d*s_cd + q^3*s_bd*s_cd + q^2*s_c*s_bcd*s_cd
# s_c_d_a s_cd
# s_cd*s_ad*s_cd
# case 2
# l is s_a*s_c*s_cd + 1/q*s_c_d_a*s_cd + q*s_ac*s_cd + s_d*s_acd*s_cd and r is s_a*s_c*s_cd + q*s_cd*s_c_d_a + 1/q*s_cd*s_ac + s_d*s_cd*s_acd
# s_d_a_b s_ad
# case 1
# s_ad*s_ab*s_ad
# l is s_b*s_d*s_ad + q*s_ad*s_d_a_b + 1/q*s_ad*s_bd + s_a*s_ad*s_abd and r is (((q^6-q^4-q^2+1)/q^5)*s_a*s_b) + ((q^8-2*q^4+1)/q^6)*s_ab + s_b*s_d*s_ad + (((q^6-q^4-q^2+1)/q^5)*s_d)*s_abd + ((q^4-1)/q^5)*s_ad*s_bd + (((q^2-1)/q^2)*s_a)*s_ad*s_abd + 1/q*s_d_a_b*s_ad + 1/q^3*s_bd*s_ad + 1/q^2*s_a*s_abd*s_ad
# s_bc_ad s_ad
# case 1
# s_ad*s_bc*s_ad
# l is s_ad*s_bc_ad and r is s_bc_ad*s_ad
# s_c_d_a s_ad
# case 1
# s_ad*s_cd*s_ad
# l is s_a*s_c*s_ad + 1/q*s_ad*s_c_d_a + q*s_ad*s_ac + s_d*s_ad*s_acd and r is (((q^6-q^4-q^2+1)/q)*s_c*s_d) + ((q^8-2*q^4+1)/q^2)*s_cd + s_a*s_c*s_ad + (((q^6-q^4-q^2+1)/q)*s_a)*s_acd + (-q^5+q)*s_ad*s_ac + ((-q^2+1)*s_d)*s_ad*s_acd + q*s_c_d_a*s_ad + q^3*s_ac*s_ad + q^2*s_d*s_acd*s_ad
# s_ab_cd s_a_b_c
# s_b_c_d s_a_b_c
# s_bc*s_cd*s_ab*s_bc
# case 2
# l is s_a*s_b*s_c*s_d + 1/q*s_b*s_d*s_a_b_c + 1/q*s_a*s_c*s_b_c_d + q*s_b*s_d*s_ac + q*s_a*s_c*s_bd + s_b^2*s_d*s_abc + s_a*s_c^2*s_bcd + 1/q^2*s_b_c_d*s_a_b_c + s_b_c_d*s_ac + 1/q*s_b*s_b_c_d*s_abc + s_bd*s_a_b_c + q^2*s_bd*s_ac + q*s_b*s_bd*s_abc + 1/q*s_c*s_bcd*s_a_b_c + q*s_c*s_bcd*s_ac + s_b*s_c*s_bcd*s_abc and r is (((q^8-2*q^6+2*q^2-1)/q)*s_c^2*s_abcd+(-q^4+2*q^2)*s_a*s_b*s_c*s_d) + (((q^8-2*q^6+2*q^2-1)/q)*s_c*s_d)*s_ab + ((-q^4+2*q^2-1)*s_b*s_c*s_abcd+(-q^7+q^5+q^3-q)*s_a*s_d)*s_bc + ((q^7-q^5-q^3+q)*s_a*s_b)*s_cd + ((-q^5+2*q^3)*s_b*s_d)*s_a_b_c + (q^8-2*q^4+1)*s_ab_cd + q*s_a*s_c*s_b_c_d + (-q^8+2*q^4-1)*s_bc_ad + ((-q^3+2*q)*s_b*s_d)*s_ac + 1/q*s_a*s_c*s_bd + s_b^2*s_d*s_abc + s_a*s_c^2*s_bcd + (((q^10-q^8-2*q^6+2*q^4+q^2-1)/q^2)*s_c)*s_abd + ((-q^7+q^5+q^3-q)*s_c)*s_bc*s_acd + (((-q^6+q^4+q^2-1)/q)*s_b)*s_bc*s_abd + (((q^6-q^4-q^2+1)/q)*s_c)*s_cd*s_abc + q^2*s_a_b_c*s_b_c_d + s_a_b_c*s_bd + q*s_c*s_a_b_c*s_bcd + (-q^4+1)*s_b_c_d*s_ac + (((-q^2+1)/q)*s_b)*s_b_c_d*s_abc + q^4*s_ac*s_b_c_d + ((q^8-q^4+1)/q^2)*s_ac*s_bd + (((q^6-q^2+1)/q)*s_c)*s_ac*s_bcd + (-q^6+q^2)*s_bd*s_ac + ((-q^3+q)*s_b)*s_bd*s_abc + q^3*s_b*s_abc*s_b_c_d + (((q^6-q^4+1)/q)*s_b)*s_abc*s_bd + ((q^4-q^2+1)*s_b*s_c)*s_abc*s_bcd + ((-q^5+q)*s_c)*s_bcd*s_ac + ((-q^2+1)*s_b*s_c)*s_bcd*s_abc
# s_d_a_b s_a_b_c
# s_bc_ad s_a_b_c
# s_bc*s_ad*s_ab*s_bc
# case 2
# l is s_a*s_c*s_bc_ad + 1/q*s_bc_ad*s_a_b_c + q*s_bc_ad*s_ac + s_b*s_bc_ad*s_abc and r is (((q^12+q^10-q^8-2*q^6-q^4+q^2+1)/q^6)*s_b*s_d+((-q^8+2*q^6-2*q^2+1)/q^3)*s_a*s_c*s_abcd) + (((q^8-2*q^4+1)/q^5)*s_c*s_d+((q^6-q^4-q^2+1)/q^4)*s_a*s_b*s_abcd)*s_bc + (((q^6-q^4-q^2+1)/q^3)*s_a*s_b)*s_ad + ((q^12-q^8-q^4+1)/q^7)*s_b_c_d + ((q^8-2*q^4+1)/q^3)*s_d_a_b + (((q^4-q^2+1)/q^4)*s_a*s_c)*s_bc_ad + ((q^12-3*q^4+2)/q^5)*s_bd + (((q^10+q^8-2*q^6-2*q^4+q^2+1)/q^6)*s_c)*s_bcd + (((q^8-2*q^4+1)/q^4)*s_a)*s_abd + ((q^2-1)*s_b*s_d)*s_bc^2 + (((q^8-2*q^4+1)/q^5)*s_b)*s_bc*s_bcd + (((q^10-q^8-q^2+1)/q^5)*s_a)*s_bc*s_acd + (((q^6-q^4-q^2+1)/q)*s_c)*s_ad*s_abc + 1/q*s_a_b_c*s_bc_ad + (-q^5+q)*s_bc_ad*s_ac + ((-q^2+1)*s_b)*s_bc_ad*s_abc + q*s_ac*s_bc_ad + s_b*s_abc*s_bc_ad + ((q^4-1)/q^5)*s_bc^2*s_bd + (((q^2-1)/q^4)*s_a)*s_bc^2*s_abd
# s_c_d_a s_a_b_c
# s_cd*s_ad*s_ab*s_bc
# case 2
# l is s_a^2*s_c^2 + 1/q*s_a*s_c*s_a_b_c + 1/q*s_a*s_c*s_c_d_a + 2*q*s_a*s_c*s_ac + s_a*s_b*s_c*s_abc + s_a*s_c*s_d*s_acd + 1/q^2*s_c_d_a*s_a_b_c + s_c_d_a*s_ac + 1/q*s_b*s_c_d_a*s_abc + s_ac*s_a_b_c + q^2*s_ac^2 + q*s_b*s_ac*s_abc + 1/q*s_d*s_acd*s_a_b_c + q*s_d*s_acd*s_ac + s_b*s_d*s_acd*s_abc and r is s_a^2*s_c^2 + (((-q^4+2*q^2-1)/q^4)*s_c*s_d*s_abcd+((-q^6+q^4+q^2-1)/q^5)*s_a*s_b)*s_ab + (((q^6-q^4-q^2+1)/q^5)*s_c*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_b*s_abcd)*s_cd + (((2*q^2-1)/q^5)*s_a*s_c)*s_a_b_c + (((q^2-1)/q)*s_b*s_d)*s_b_c_d + (((-q^2+1)/q)*s_b*s_d)*s_d_a_b + (((2*q^4-2*q^2+1)/q^5)*s_a*s_c)*s_c_d_a + 2*q*s_a*s_c*s_ac + (((2*q^2-1)/q^4)*s_a*s_b*s_c)*s_abc + (((q^4-2*q^2+1)/q^4)*s_b*s_c*s_d)*s_bcd + (((2*q^4-2*q^2+1)/q^4)*s_a*s_c*s_d)*s_acd + (((-q^4+2*q^2-1)/q^4)*s_a*s_b*s_d)*s_abd + ((-q^8+2*q^4-1)/q^6)*s_ab^2 + (((-q^6+q^4+q^2-1)/q^5)*s_c)*s_ab*s_abc + (((-q^6+q^4+q^2-1)/q^5)*s_d)*s_ab*s_abd + ((q^8-2*q^4+1)/q^6)*s_cd^2 + (((q^6-q^4-q^2+1)/q^5)*s_b)*s_cd*s_bcd + (((q^6-q^4-q^2+1)/q^5)*s_a)*s_cd*s_acd + 1/q^2*s_a_b_c*s_c_d_a + s_a_b_c*s_ac + 1/q*s_d*s_a_b_c*s_acd + ((q^4-1)/q^4)*s_b_c_d*s_bd + (((q^2-1)/q^3)*s_a)*s_b_c_d*s_abd + ((-q^4+1)/q^4)*s_d_a_b*s_bd + (((-q^2+1)/q^3)*s_c)*s_d_a_b*s_bcd + s_ac*s_c_d_a + q^2*s_ac^2 + q*s_d*s_ac*s_acd + (((-q^2+1)/q)*s_c)*s_bd*s_bcd + (((q^2-1)/q^5)*s_a)*s_bd*s_abd + 1/q*s_b*s_abc*s_c_d_a + q*s_b*s_abc*s_ac + s_b*s_d*s_abc*s_acd + (((q^4-1)/q^3)*s_c)*s_bcd*s_bd + (((q^2-1)/q^4)*s_a*s_c)*s_bcd*s_abd + (((-q^4+1)/q^5)*s_a)*s_abd*s_bd + (((-q^2+1)/q^4)*s_a*s_c)*s_abd*s_bcd
# s_b_cd_a s_a_b_c
# s_bc*s_cd*s_ad*s_ab*s_bc
# case 2
# l is ((-1/q^2)*s_a*s_c^2*s_d*s_abcd) + ((-1/q^2)*s_a*s_c)*s_ab + (((q^2-1)/q^2)*s_a^2*s_c^2)*s_bc + ((-1/q^3)*s_c*s_d*s_abcd)*s_a_b_c + 1/q^2*s_a*s_c*s_b_cd_a + ((-1/q)*s_c*s_d*s_abcd)*s_ac + ((-1/q^2)*s_b*s_c*s_d*s_abcd+(-1/q^3)*s_a*s_c^2)*s_abc + ((-1/q)*s_a*s_c*s_d)*s_abd + (-1/q^3)*s_ab*s_a_b_c + (-1/q)*s_ab*s_ac + ((-1/q^2)*s_b)*s_ab*s_abc + (((q^2-1)/q^3)*s_a*s_c)*s_bc*s_a_b_c + (((2*q^2-1)/q)*s_a*s_c)*s_bc*s_ac + (((q^2-1)/q^2)*s_a*s_b*s_c)*s_bc*s_abc + s_a*s_c*s_d*s_bc*s_acd + 1/q*s_a*s_c*s_ad*s_bd + 1/q^2*s_a*s_c^2*s_ad*s_bcd + 1/q^3*s_b_cd_a*s_a_b_c + 1/q*s_b_cd_a*s_ac + 1/q^2*s_b*s_b_cd_a*s_abc + ((-1/q^4)*s_c)*s_abc*s_a_b_c + ((-1/q^2)*s_c)*s_abc*s_ac + ((-1/q^3)*s_b*s_c)*s_abc^2 + ((-1/q^2)*s_d)*s_abd*s_a_b_c + (-s_d)*s_abd*s_ac + ((-1/q)*s_b*s_d)*s_abd*s_abc + s_bc*s_ac*s_a_b_c + q^2*s_bc*s_ac^2 + q*s_b*s_bc*s_ac*s_abc + 1/q*s_d*s_bc*s_acd*s_a_b_c + q*s_d*s_bc*s_acd*s_ac + s_b*s_d*s_bc*s_acd*s_abc + 1/q^2*s_ad*s_bd*s_a_b_c + s_ad*s_bd*s_ac + 1/q*s_b*s_ad*s_bd*s_abc + 1/q^3*s_c*s_ad*s_bcd*s_a_b_c + 1/q*s_c*s_ad*s_bcd*s_ac + 1/q^2*s_b*s_c*s_ad*s_bcd*s_abc and r is (((q^14-q^12-3*q^10+3*q^8+3*q^6-3*q^4-q^2+1)/q^9)*s_b*s_c+((-q^12+3*q^10-2*q^8-q^2+1)/q^5)*s_b*s_c*s_d^2+((-q^8+2*q^4-1)/q^2)*s_a*s_d*s_abcd+((-q^6+q^2-1)/q^6)*s_a*s_c^2*s_d*s_abcd+((-q^10+3*q^8-q^6-q^4-q^2+1)/q^4)*s_a*s_b^2*s_d*s_abcd+((2*q^8-4*q^6+4*q^2-2)/q^5)*s_a^2*s_b*s_c) + (((-q^12+2*q^10-4*q^6+q^4+4*q^2-3)/q^6)*s_a*s_c)*s_ab + ((-2*q^12+5*q^8-4*q^4+1)/q^10+(-q^6+3*q^4-2*q^2)*s_b^2*s_d^2+((q^6-2*q^4+2*q^2-1)/q^6)*s_a^2*s_c^2)*s_bc + (((-q^14+2*q^12+2*q^10-3*q^8-q^4+1)/q^6)*s_b*s_d+((-q^8+2*q^6-2*q^2+1)/q^3)*s_a*s_c*s_abcd)*s_cd + (((q^8-2*q^6+2*q^2-1)/q^3)*s_c^2*s_abcd)*s_ad + (((-q^4+q^2-1)/q^3)*s_c*s_d*s_abcd+((-q^6+q^4+q^2-1)/q^4)*s_a*s_b)*s_a_b_c + (((-q^12+3*q^10-q^8-2*q^6+q^4-q^2+1)/q^6)*s_c*s_d+((q^6-q^4-q^2+1)/q^5)*s_a*s_b*s_abcd)*s_b_c_d + (((q^8-2*q^6+2*q^2-1)/q^2)*s_c*s_d)*s_d_a_b + (((-q^4+2*q^2-1)/q^2)*s_b*s_c*s_abcd+((-q^6+q^4+q^2-1)/q)*s_a*s_d)*s_bc_ad + (((q^6-q^4-q^2+1)/q^2)*s_a*s_b)*s_c_d_a + (((2*q^4-2*q^2+1)/q^6)*s_a*s_c)*s_b_cd_a + ((q^8-2*q^4+1)/q^2)*s_c_da_b + ((-q^4+q^2)*s_b*s_d)*s_d_ab_c + (((q^8-q^6-2*q^4+2*q^2-1)/q^5)*s_c*s_d*s_abcd+((q^12-q^10-q^8+q^4+q^2-1)/q^6)*s_a*s_b)*s_ac + (((q^10-2*q^8+q^6+2*q^4-3*q^2+1)/q^4)*s_c*s_d+((q^4-q^2-1)/q^3)*s_a*s_b*s_abcd)*s_bd + (((-q^4+q^2-1)/q^4)*s_b*s_c*s_d*s_abcd+((-q^16+q^14+q^12-3*q^10+2*q^8+3*q^6-3*q^4-q^2+1)/q^9)*s_a+((2*q^10-4*q^8+2*q^4-1)/q^7)*s_a*s_c^2+((-q^6+q^4+q^2-1)/q^5)*s_a*s_b^2)*s_abc + (((-q^8+2*q^4-1)/q^3)*s_d+((2*q^6-2*q^4-q^2+1)/q^5)*s_c^2*s_d+((-q^12+2*q^10+q^8-q^6-2*q^4+1)/q^5)*s_b^2*s_d+((2*q^4-4*q^2+1)/q^4)*s_a*s_b*s_c*s_abcd)*s_bcd + (((-q^12+4*q^10-2*q^8-2*q^6+q^4-q^2+1)/q^5)*s_a*s_b*s_d)*s_acd + (((q^10-2*q^8-q^6+q^4+2*q^2-2)/q^5)*s_a*s_c*s_d)*s_abd + ((-q^8+2*q^4-1)/q^3)*s_ab*s_a_b_c + ((q^16-q^12-q^8+2*q^4-1)/q^9)*s_ab*s_ac + (((-q^8+q^6+q^4-1)/q^6)*s_b)*s_ab*s_abc + (((q^8-2*q^4+1)/q^2)*s_d)*s_ab*s_acd + ((q^3-q)*s_b*s_d)*s_bc*s_b_c_d + (((-q^4+3*q^2-1)/q)*s_a*s_c)*s_bc*s_ac + (((-q^6+2*q^4+q^2-2)/q^3)*s_b*s_d)*s_bc*s_bd + (((-q^4+2*q^2-1)/q^4)*s_a*s_b*s_c)*s_bc*s_abc + (((2*q^4-3*q^2+1)/q^4)*s_b*s_c*s_d)*s_bc*s_bcd + (((2*q^4-2*q^2+1)/q^4)*s_a*s_c*s_d)*s_bc*s_acd + (((-q^6+q^4+q^2-1)/q^4)*s_a*s_b*s_d)*s_bc*s_abd + ((q^4-2)/q^3)*s_cd*s_bd + (((-q^8+3*q^4-3)/q^2)*s_c)*s_cd*s_bcd + (((q^8-2*q^4+1)/q^2)*s_a)*s_cd*s_abd + ((q^7-q^5-q^3+q)*s_b*s_d)*s_ad*s_ac + (((q^4-2*q^2+1)/q^5)*s_a*s_c)*s_ad*s_bd + ((q^6-2*q^4+q^2)*s_b^2*s_d)*s_ad*s_abc + (((q^4-2*q^2+1)/q^6)*s_a*s_c^2)*s_ad*s_bcd + (((q^10-q^8-2*q^6+2*q^4+q^2-1)/q^4)*s_c)*s_ad*s_abd + (-1/q)*s_a_b_c*s_ab + (((q^2-1)/q^3)*s_a*s_c)*s_a_b_c*s_bc + 1/q*s_a_b_c*s_b_cd_a + (((-q^6+q^4-1)/q^4)*s_c)*s_a_b_c*s_abc + (((-q^6+q^2-1)/q^4)*s_d)*s_a_b_c*s_abd + ((q^12-q^8-q^4+1)/q^7)*s_b_c_d*s_cd + (((q^8-2*q^4+1)/q^6)*s_b)*s_b_c_d*s_bcd + (((q^10-q^8-q^2+1)/q^6)*s_a)*s_b_c_d*s_acd + ((-q^8+2*q^4-1)/q^2)*s_bc_ad*s_ad + (((-q^6+q^4+q^2-1)/q)*s_c)*s_bc_ad*s_acd + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_bc_ad*s_abd + (((q^6-q^4-q^ ...
# s_c_da_b s_a_b_c
# s_d_ab_c s_a_b_c
# s_bd s_a_b_c
# s_bd*s_ab*s_bc
# case 2
# l is s_a*s_c*s_bd + 1/q*s_bd*s_a_b_c + q*s_bd*s_ac + s_b*s_bd*s_abc and r is (((-q^4+2*q^2-1)/q^2)*s_b^2*s_abcd) + ((q^2-1)*s_c*s_d)*s_ab + ((-q^2+1)*s_a*s_d)*s_bc + (((-q^4+2*q^2-1)/q^2)*s_b*s_c)*s_ad + ((q^4-1)/q)*s_ab_cd + ((-q^4+1)/q)*s_bc_ad + s_a*s_c*s_bd + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_acd + ((q^2-1)*s_b)*s_ab*s_bcd + (((-q^2+1)/q^2)*s_b)*s_bc*s_abd + 1/q*s_a_b_c*s_bd + q*s_ac*s_bd + s_b*s_abc*s_bd
# s_abc s_a_b_c
# s_abc*s_ab*s_bc
# case 2
# l is s_a*s_c*s_abc + 1/q*s_abc*s_a_b_c + q*s_abc*s_ac + s_b*s_abc^2 and r is s_a*s_c*s_abc + 1/q*s_a_b_c*s_abc + q*s_ac*s_abc + s_b*s_abc^2
# s_bcd s_a_b_c
# s_bcd*s_ab*s_bc
# case 2
# l is s_a*s_c*s_bcd + 1/q*s_bcd*s_a_b_c + q*s_bcd*s_ac + s_b*s_bcd*s_abc and r is (((q^6-q^4-q^2+1)/q)*s_c*s_abcd+(-q^2+1)*s_a*s_b*s_d) + ((-q^2+1)*s_b*s_abcd)*s_bc + (((q^6-q^4-q^2+1)/q)*s_b)*s_ad + ((-q^3+q)*s_a)*s_b_c_d + (((-q^2+1)/q)*s_a)*s_bd + s_a*s_c*s_bcd + ((q^8-2*q^4+1)/q^2)*s_abd + (-q^5+q)*s_bc*s_acd + q*s_a_b_c*s_bcd + q^3*s_ac*s_bcd + q^2*s_b*s_abc*s_bcd
# s_abd s_a_b_c
# s_abd*s_ab*s_bc
# case 2
# l is s_a*s_c*s_abd + 1/q*s_abd*s_a_b_c + q*s_abd*s_ac + s_b*s_abd*s_abc and r is (((q^2-1)/q^2)*s_b*s_c*s_d) + (((q^2-1)/q^2)*s_b*s_abcd)*s_ab + (((q^2-1)/q)*s_c)*s_d_a_b + (((q^2-1)/q^3)*s_c)*s_bd + s_a*s_c*s_abd + ((q^4-1)/q^3)*s_ab*s_acd + 1/q^3*s_a_b_c*s_abd + 1/q*s_ac*s_abd + 1/q^2*s_b*s_abc*s_abd
# s_b_c_d s_ab_cd
# s_d_a_b s_ab_cd
# s_bc_ad s_ab_cd
# s_c_d_a s_ab_cd
# s_cd*s_ad*s_ab*s_cd
# case 2
# l is s_a*s_c*s_ab_cd + 1/q*s_c_d_a*s_ab_cd + q*s_ac*s_ab_cd + s_d*s_acd*s_ab_cd and r is (((-q^8+2*q^4-1)/q^4)*s_b*s_d) + (((-q^6+q^4+q^2-1)/q^3)*s_b*s_c+((-q^4+2*q^2-1)/q^2)*s_a*s_d*s_abcd)*s_cd + ((-q^2+2)*s_a*s_c)*s_ab_cd + ((-q^8+2*q^4-1)/q^3)*s_b_c_d + ((-q^8+2*q^4-1)/q^5)*s_bd + (((-q^8+2*q^4-1)/q^4)*s_c)*s_bcd + (((q^2-1)/q^2)*s_b*s_d)*s_cd^2 + (((-q^6+q^4+q^2-1)/q^3)*s_a)*s_cd*s_abc + (((-q^6+q^4+q^2-1)/q^3)*s_d)*s_cd*s_bcd + 1/q*s_ab_cd*s_c_d_a + 1/q^3*s_ab_cd*s_ac + 1/q^2*s_d*s_ab_cd*s_acd + ((q^4-1)/q)*s_cd^2*s_bd + ((q^2-1)*s_a)*s_cd^2*s_abd
# s_b_cd_a s_ab_cd
# s_d_ab_c s_ab_cd
# s_ac s_ab_cd
# s_ac*s_ab*s_cd
# case 2
# l is s_ac*s_ab_cd and r is (((q^6+q^4-q^2-1)/q^5)*s_b*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_c*s_abcd) + (((q^2-1)/q^2)*s_a*s_d)*s_ab + (((q^2-1)/q^2)*s_b*s_c)*s_cd + ((q^4-1)/q^4)*s_b_c_d + ((q^4-1)/q^4)*s_d_a_b + ((q^8-1)/q^6)*s_bd + (((q^4-1)/q^3)*s_c)*s_bcd + (((q^4-1)/q^3)*s_a)*s_abd + (((q^2-1)/q^4)*s_c)*s_ab*s_acd + (((q^2-1)/q^4)*s_a)*s_cd*s_abc + 1/q^4*s_ab_cd*s_ac
# s_bd s_ab_cd
# s_bd*s_ab*s_cd
# case 2
# l is s_bd*s_ab_cd and r is ((q^4-2*q^2+1)*s_b*s_d*s_abcd+((-q^6-q^4+q^2+1)/q)*s_a*s_c) + ((-q^2+1)*s_b*s_c)*s_ab + ((-q^2+1)*s_a*s_d)*s_cd + (-q^4+1)*s_a_b_c + (-q^4+1)*s_c_d_a + ((-q^8+1)/q^2)*s_ac + (((-q^4+1)/q)*s_b)*s_abc + (((-q^4+1)/q)*s_d)*s_acd + ((-q^4+q^2)*s_d)*s_ab*s_bcd + ((-q^4+q^2)*s_b)*s_cd*s_abd + q^4*s_ab_cd*s_bd
# s_abc s_ab_cd
# s_abc*s_ab*s_cd
# case 2
# l is s_abc*s_ab_cd and r is (((q^2-1)/q^2)*s_c*s_abcd)*s_ab + (((q^2-1)/q^2)*s_d)*s_ab^2 + ((q^4-1)/q^3)*s_ab*s_abd + 1/q^2*s_ab_cd*s_abc
# s_bcd s_ab_cd
# s_bcd*s_ab*s_cd
# case 2
# l is s_bcd*s_ab_cd and r is ((-q^2+1)*s_b*s_abcd)*s_cd + ((-q^2+1)*s_a)*s_cd^2 + ((-q^4+1)/q)*s_cd*s_acd + q^2*s_ab_cd*s_bcd
# s_acd s_ab_cd
# s_acd*s_ab*s_cd
# case 2
# l is s_acd*s_ab_cd and r is (((q^2-1)/q^2)*s_a*s_abcd)*s_cd + (((q^2-1)/q^2)*s_b)*s_cd^2 + ((q^4-1)/q^3)*s_cd*s_bcd + 1/q^2*s_ab_cd*s_acd
# s_abd s_ab_cd
# s_abd*s_ab*s_cd
# case 2
# l is s_abd*s_ab_cd and r is ((-q^2+1)*s_d*s_abcd)*s_ab + ((-q^2+1)*s_c)*s_ab^2 + ((-q^4+1)/q)*s_ab*s_abc + q^2*s_ab_cd*s_abd
# s_d_a_b s_b_c_d
# s_bc_ad s_b_c_d
# s_c_d_a s_b_c_d
# s_cd*s_ad*s_bc*s_cd
# case 2
# l is s_a*s_b*s_c*s_d + 1/q*s_a*s_c*s_b_c_d + 1/q*s_b*s_d*s_c_d_a + q*s_b*s_d*s_ac + q*s_a*s_c*s_bd + s_a*s_c^2*s_bcd + s_b*s_d^2*s_acd + 1/q^2*s_c_d_a*s_b_c_d + s_c_d_a*s_bd + 1/q*s_c*s_c_d_a*s_bcd + s_ac*s_b_c_d + q^2*s_ac*s_bd + q*s_c*s_ac*s_bcd + 1/q*s_d*s_acd*s_b_c_d + q*s_d*s_acd*s_bd + s_c*s_d*s_acd*s_bcd and r is (((q^8-2*q^6+2*q^2-1)/q)*s_d^2*s_abcd+(-q^4+2*q^2)*s_a*s_b*s_c*s_d) + (((q^8-2*q^6+2*q^2-1)/q)*s_a*s_d)*s_bc + ((-q^4+2*q^2-1)*s_c*s_d*s_abcd+(-q^7+q^5+q^3-q)*s_a*s_b)*s_cd + ((q^7-q^5-q^3+q)*s_b*s_c)*s_ad + (-q^8+2*q^4-1)*s_ab_cd + ((-q^5+2*q^3)*s_a*s_c)*s_b_c_d + (q^8-2*q^4+1)*s_bc_ad + q*s_b*s_d*s_c_d_a + 1/q*s_b*s_d*s_ac + ((-q^3+2*q)*s_a*s_c)*s_bd + (((q^10-q^8-2*q^6+2*q^4+q^2-1)/q^2)*s_d)*s_abc + s_a*s_c^2*s_bcd + s_b*s_d^2*s_acd + (((-q^6+q^4+q^2-1)/q)*s_c)*s_cd*s_abc + ((-q^7+q^5+q^3-q)*s_d)*s_cd*s_abd + (((q^6-q^4-q^2+1)/q)*s_d)*s_ad*s_bcd + q^2*s_b_c_d*s_c_d_a + s_b_c_d*s_ac + q*s_d*s_b_c_d*s_acd + (-q^4+1)*s_c_d_a*s_bd + (((-q^2+1)/q)*s_c)*s_c_d_a*s_bcd + (-q^6+q^2)*s_ac*s_bd + ((-q^3+q)*s_c)*s_ac*s_bcd + q^4*s_bd*s_c_d_a + ((q^8-q^4+1)/q^2)*s_bd*s_ac + (((q^6-q^2+1)/q)*s_d)*s_bd*s_acd + q^3*s_c*s_bcd*s_c_d_a + (((q^6-q^4+1)/q)*s_c)*s_bcd*s_ac + ((q^4-q^2+1)*s_c*s_d)*s_bcd*s_acd + ((-q^5+q)*s_d)*s_acd*s_bd + ((-q^2+1)*s_c*s_d)*s_acd*s_bcd
# s_b_cd_a s_b_c_d
# s_c_da_b s_b_c_d
# s_d_ab_c s_b_c_d
# s_ac s_b_c_d
# s_ac*s_bc*s_cd
# case 2
# l is s_b*s_d*s_ac + 1/q*s_ac*s_b_c_d + q*s_ac*s_bd + s_c*s_ac*s_bcd and r is (((-q^4+2*q^2-1)/q^2)*s_c^2*s_abcd) + (((-q^4+2*q^2-1)/q^2)*s_c*s_d)*s_ab + ((q^2-1)*s_a*s_d)*s_bc + ((-q^2+1)*s_a*s_b)*s_cd + ((-q^4+1)/q)*s_ab_cd + ((q^4-1)/q)*s_bc_ad + s_b*s_d*s_ac + (((-q^6+q^4+q^2-1)/q^3)*s_c)*s_abd + ((q^2-1)*s_c)*s_bc*s_acd + (((-q^2+1)/q^2)*s_c)*s_cd*s_abc + 1/q*s_b_c_d*s_ac + q*s_bd*s_ac + s_c*s_bcd*s_ac
# s_abc s_b_c_d
# s_abc*s_bc*s_cd
# case 2
# l is s_b*s_d*s_abc + 1/q*s_abc*s_b_c_d + q*s_abc*s_bd + s_c*s_abc*s_bcd and r is (((q^2-1)/q^2)*s_a*s_c*s_d) + (((q^2-1)/q^2)*s_c*s_abcd)*s_bc + (((q^2-1)/q)*s_d)*s_a_b_c + (((q^2-1)/q^3)*s_d)*s_ac + s_b*s_d*s_abc + ((q^4-1)/q^3)*s_bc*s_abd + 1/q^3*s_b_c_d*s_abc + 1/q*s_bd*s_abc + 1/q^2*s_c*s_bcd*s_abc
# s_bcd s_b_c_d
# s_bcd*s_bc*s_cd
# case 2
# l is s_b*s_d*s_bcd + 1/q*s_bcd*s_b_c_d + q*s_bcd*s_bd + s_c*s_bcd^2 and r is s_b*s_d*s_bcd + 1/q*s_b_c_d*s_bcd + q*s_bd*s_bcd + s_c*s_bcd^2
# s_acd s_b_c_d
# s_acd*s_bc*s_cd
# case 2
# l is s_b*s_d*s_acd + 1/q*s_acd*s_b_c_d + q*s_acd*s_bd + s_c*s_acd*s_bcd and r is (((q^6-q^4-q^2+1)/q)*s_d*s_abcd+(-q^2+1)*s_a*s_b*s_c) + (((q^6-q^4-q^2+1)/q)*s_c)*s_ab + ((-q^2+1)*s_c*s_abcd)*s_cd + ((-q^3+q)*s_b)*s_c_d_a + (((-q^2+1)/q)*s_b)*s_ac + ((q^8-2*q^4+1)/q^2)*s_abc + s_b*s_d*s_acd + (-q^5+q)*s_cd*s_abd + q*s_b_c_d*s_acd + q^3*s_bd*s_acd + q^2*s_c*s_bcd*s_acd
# s_bc_ad s_d_a_b
# s_c_d_a s_d_a_b
# s_a_bc_d s_d_a_b
# s_b_cd_a s_d_a_b
# s_d_ab_c s_d_a_b
# s_ac s_d_a_b
# s_ac*s_ab*s_ad
# case 2
# l is s_b*s_d*s_ac + q*s_ac*s_d_a_b + 1/q*s_ac*s_bd + s_a*s_ac*s_abd and r is (((-q^4+2*q^2-1)/q^2)*s_a^2*s_abcd) + (((-q^2+1)/q^2)*s_c*s_d)*s_ab + (((-q^4+2*q^2-1)/q^2)*s_a*s_d)*s_bc + (((q^2-1)/q^2)*s_b*s_c)*s_ad + ((-q^4+1)/q^3)*s_ab_cd + ((q^4-1)/q^3)*s_bc_ad + s_b*s_d*s_ac + (((-q^6+q^4+q^2-1)/q^3)*s_a)*s_bcd + (((-q^2+1)/q^2)*s_a)*s_ab*s_acd + ((q^2-1)*s_a)*s_ad*s_abc + q*s_d_a_b*s_ac + 1/q*s_bd*s_ac + s_a*s_abd*s_ac
# s_abc s_d_a_b
# s_abc*s_ab*s_ad
# case 2
# l is s_b*s_d*s_abc + q*s_abc*s_d_a_b + 1/q*s_abc*s_bd + s_a*s_abc*s_abd and r is ((-q^2+1)*s_a*s_c*s_d) + ((-q^2+1)*s_a*s_abcd)*s_ab + (((-q^2+1)/q)*s_d)*s_a_b_c + ((-q^3+q)*s_d)*s_ac + s_b*s_d*s_abc + ((-q^4+1)/q)*s_ab*s_bcd + q^3*s_d_a_b*s_abc + q*s_bd*s_abc + q^2*s_a*s_abd*s_abc
# s_acd s_d_a_b
# s_acd*s_ab*s_ad
# case 2
# l is s_b*s_d*s_acd + q*s_acd*s_d_a_b + 1/q*s_acd*s_bd + s_a*s_acd*s_abd and r is (((q^6-q^4-q^2+1)/q^5)*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_b*s_c) + (((q^6-q^4-q^2+1)/q^5)*s_a)*s_bc + (((q^2-1)/q^2)*s_a*s_abcd)*s_ad + (((q^2-1)/q^3)*s_b)*s_c_d_a + (((q^2-1)/q)*s_b)*s_ac + ((q^8-2*q^4+1)/q^6)*s_abc + s_b*s_d*s_acd + ((q^4-1)/q^5)*s_ad*s_bcd + 1/q*s_d_a_b*s_acd + 1/q^3*s_bd*s_acd + 1/q^2*s_a*s_abd*s_acd
# s_abd s_d_a_b
# s_abd*s_ab*s_ad
# case 2
# l is s_b*s_d*s_abd + q*s_abd*s_d_a_b + 1/q*s_abd*s_bd + s_a*s_abd^2 and r is s_b*s_d*s_abd + q*s_d_a_b*s_abd + 1/q*s_bd*s_abd + s_a*s_abd^2
# s_c_d_a s_bc_ad
# s_a_bc_d s_bc_ad
# s_c_da_b s_bc_ad
# s_ac s_bc_ad
# s_ac*s_bc*s_ad
# case 2
# l is s_ac*s_bc_ad and r is (((-q^6-q^4+q^2+1)/q)*s_b*s_d+(q^4-2*q^2+1)*s_a*s_c*s_abcd) + ((-q^2+1)*s_c*s_d)*s_bc + ((-q^2+1)*s_a*s_b)*s_ad + (-q^4+1)*s_b_c_d + (-q^4+1)*s_d_a_b + ((-q^8+1)/q^2)*s_bd + (((-q^4+1)/q)*s_c)*s_bcd + (((-q^4+1)/q)*s_a)*s_abd + ((-q^4+q^2)*s_a)*s_bc*s_acd + ((-q^4+q^2)*s_c)*s_ad*s_abc + q^4*s_bc_ad*s_ac
# s_bd s_bc_ad
# s_bd*s_bc*s_ad
# case 2
# l is s_bd*s_bc_ad and r is (((q^4-2*q^2+1)/q^4)*s_b*s_d*s_abcd+((q^6+q^4-q^2-1)/q^5)*s_a*s_c) + (((q^2-1)/q^2)*s_a*s_b)*s_bc + (((q^2-1)/q^2)*s_c*s_d)*s_ad + ((q^4-1)/q^4)*s_a_b_c + ((q^4-1)/q^4)*s_c_d_a + ((q^8-1)/q^6)*s_ac + (((q^4-1)/q^3)*s_b)*s_abc + (((q^4-1)/q^3)*s_d)*s_acd + (((q^2-1)/q^4)*s_d)*s_bc*s_abd + (((q^2-1)/q^4)*s_b)*s_ad*s_bcd + 1/q^4*s_bc_ad*s_bd
# s_abc s_bc_ad
# s_abc*s_bc*s_ad
# case 2
# l is s_abc*s_bc_ad and r is ((-q^2+1)*s_a*s_abcd)*s_bc + ((-q^2+1)*s_d)*s_bc^2 + ((-q^4+1)/q)*s_bc*s_bcd + q^2*s_bc_ad*s_abc
# s_bcd s_bc_ad
# s_bcd*s_bc*s_ad
# case 2
# l is s_bcd*s_bc_ad and r is (((q^2-1)/q^2)*s_d*s_abcd)*s_bc + (((q^2-1)/q^2)*s_a)*s_bc^2 + ((q^4-1)/q^3)*s_bc*s_abc + 1/q^2*s_bc_ad*s_bcd
# s_acd s_bc_ad
# s_acd*s_bc*s_ad
# case 2
# l is s_acd*s_bc_ad and r is ((-q^2+1)*s_c*s_abcd)*s_ad + ((-q^2+1)*s_b)*s_ad^2 + ((-q^4+1)/q)*s_ad*s_abd + q^2*s_bc_ad*s_acd
# s_abd s_bc_ad
# s_abd*s_bc*s_ad
# case 2
# l is s_abd*s_bc_ad and r is (((q^2-1)/q^2)*s_b*s_abcd)*s_ad + (((q^2-1)/q^2)*s_c)*s_ad^2 + ((q^4-1)/q^3)*s_ad*s_acd + 1/q^2*s_bc_ad*s_abd
# s_a_bc_d s_c_d_a
# case 1
# s_cd*s_ad*s_ab*s_bc*s_cd
# l is (-s_a*s_b*s_c^2*s_abcd+((-q^2+1)/q)*s_a^2*s_c*s_d) + ((-q^2)*s_a*s_c)*s_ad + ((-1/q)*s_b*s_c*s_abcd+((-q^2+1)/q^2)*s_a*s_d)*s_c_d_a + 1/q^2*s_a*s_c*s_a_bc_d + ((-q)*s_b*s_c*s_abcd+(-q^2+1)*s_a*s_d)*s_ac + (-s_b*s_c*s_d*s_abcd+((-q^2+1)/q)*s_a*s_d^2+(-q)*s_a*s_c^2)*s_acd + ((-q)*s_a*s_b*s_c)*s_abd + q*s_a*s_c*s_ab*s_bd + s_a*s_c^2*s_ab*s_bcd + (-q)*s_c_d_a*s_ad + 1/q^3*s_c_d_a*s_a_bc_d + (-s_c)*s_c_d_a*s_acd + (-s_b)*s_c_d_a*s_abd + q*s_a*s_c*s_ac*s_cd + (-q^3)*s_ac*s_ad + 1/q*s_ac*s_a_bc_d + ((-q^2)*s_c)*s_ac*s_acd + ((-q^2)*s_b)*s_ac*s_abd + s_a*s_b*s_c*s_abc*s_cd + ((-q^2)*s_d)*s_acd*s_ad + 1/q^2*s_d*s_acd*s_a_bc_d + ((-q)*s_c*s_d)*s_acd^2 + ((-q)*s_b*s_d)*s_acd*s_abd + s_c_d_a*s_ab*s_bd + 1/q*s_c*s_c_d_a*s_ab*s_bcd + s_c_d_a*s_ac*s_cd + 1/q*s_b*s_c_d_a*s_abc*s_cd + q^2*s_ac*s_ab*s_bd + q*s_c*s_ac*s_ab*s_bcd + q^2*s_ac^2*s_cd + q*s_b*s_ac*s_abc*s_cd + q*s_d*s_acd*s_ab*s_bd + s_c*s_d*s_acd*s_ab*s_bcd + q*s_d*s_acd*s_ac*s_cd + s_b*s_d*s_acd*s_abc*s_cd and r is (((2*q^14-2*q^12-5*q^10+5*q^8+4*q^6-4*q^4-q^2+1)/q^9)*s_c*s_d+((2*q^10-3*q^8-2*q^6+4*q^4-1)/q^5)*s_b^2*s_c*s_d+((-q^8+2*q^4-1)/q^4)*s_a*s_b*s_abcd+((q^6-2*q^4+2*q^2-1)/q^4)*s_a*s_b*s_d^2*s_abcd+(2*q^4-4*q^2+1)*s_a*s_b*s_c^2*s_abcd+((3*q^8-8*q^6+5*q^4+q^2-1)/q^3)*s_a^2*s_c*s_d) + (((q^8-2*q^6+2*q^2-1)/q^3)*s_d^2*s_abcd+((2*q^6-5*q^4+4*q^2-1)/q^2)*s_a*s_b*s_c*s_d)*s_ab + (((q^12-q^10-2*q^8+q^6+3*q^4-q^2-1)/q^6)*s_b*s_d)*s_bc + ((q^16-5*q^12+8*q^8-5*q^4+1)/q^10+((q^2-1)/q^2)*s_b^2*s_d^2+((q^4-2*q^2+1)/q^2)*s_a^2*s_c^2)*s_cd + (((3*q^10-5*q^8-q^6+2*q^4+q^2-1)/q^4)*s_a*s_c)*s_ad + (((q^8-2*q^6+2*q^2-1)/q^4)*s_a*s_d)*s_a_b_c + (((-q^4+2*q^2-1)/q^2)*s_c*s_d*s_abcd+((-q^6+q^4+q^2-1)/q)*s_a*s_b)*s_ab_cd + (((-q^6+q^4+q^2-1)/q^4)*s_b*s_c+((-q^4+2*q^2-1)/q^3)*s_a*s_d*s_abcd)*s_b_c_d + ((q^6-q^4-q^2+1)*s_b*s_c)*s_d_a_b + ((-q)*s_b*s_c*s_abcd+(-q^2+1)*s_a*s_d)*s_c_d_a + (((-2*q^4+4*q^2-1)/q^2)*s_a*s_c)*s_a_bc_d + ((-q^2+1)*s_b*s_d)*s_c_da_b + ((q^8-2*q^4+1)/q^2)*s_d_ab_c + ((-1/q)*s_b*s_c*s_abcd+(q^6-2*q^4+1)*s_a*s_d)*s_ac + (((q^12-3*q^8+3*q^4-1)/q^6)*s_b*s_c+((q^8-2*q^4+2*q^2-1)/q^5)*s_a*s_d*s_abcd)*s_bd + (((q^10-q^8-2*q^6+3*q^4-1)/q^5)*s_a*s_b*s_d)*s_abc + (((q^14-2*q^12-3*q^10+5*q^8+3*q^6-4*q^4-q^2+1)/q^9)*s_b+((q^10-q^8-q^6+q^4+q^2-1)/q^5)*s_b*s_d^2+((-q^6+q^4+q^2-1)/q^5)*s_b*s_c^2+((q^2-1)/q^4)*s_a*s_c*s_d*s_abcd)*s_bcd + (-s_b*s_c*s_d*s_abcd+((-q^8+2*q^4-1)/q^5)*s_a+((-q^2+1)/q)*s_a*s_d^2+(2*q^5-4*q^3+q)*s_a*s_c^2)*s_acd + (((4*q^8-7*q^6+3*q^2-1)/q^3)*s_a*s_b*s_c)*s_abd + ((-q^8+2*q^4-1)/q^2)*s_ab*s_ab_cd + (((-q^2+1)/q^3)*s_b*s_d)*s_ab*s_ac + (((q^6-2*q^4+3*q^2-1)/q^3)*s_a*s_c)*s_ab*s_bd + (((q^10-q^8-2*q^6+2*q^4+q^2-1)/q^4)*s_d)*s_ab*s_abc + (((-q^4+3*q^2-1)/q^2)*s_a*s_c^2)*s_ab*s_bcd + (((-q^2+1)/q^2)*s_b*s_d^2)*s_ab*s_acd + ((-q^8+2*q^4-1)/q^3)*s_bc*s_b_c_d + ((q^16-q^12-q^8+2*q^4-1)/q^9)*s_bc*s_bd + (((-q^8+q^6+q^4-1)/q^6)*s_c)*s_bc*s_bcd + (((q^8-2*q^4+1)/q^2)*s_a)*s_bc*s_abd + (((q^6-q^4-q^2+1)/q^5)*s_c*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_b*s_abcd)*s_cd^2 + (((q^4-2*q^2+1)/q^3)*s_a*s_c)*s_cd*s_c_d_a + (((q^4-2*q^2+1)/q)*s_a*s_c)*s_cd*s_ac + (((-q^8+q^6+q^4-1)/q^3)*s_b*s_d)*s_cd*s_bd + (((q^6-3*q^4+3*q^2-1)/q^4)*s_a*s_b*s_c)*s_cd*s_abc + (((-q^4+2*q^2-1)/q^2)*s_b*s_c*s_d)*s_cd*s_bcd + (((q^4-2*q^2+1)/q^4)*s_a*s_c*s_d)*s_cd*s_acd + (((-q^4+2*q^2-1)/q^2)*s_a*s_b*s_d)*s_cd*s_abd + (-q^3)*s_ad*s_c_d_a + (-q)*s_ad*s_ac + ((-q^2)*s_d)*s_ad*s_acd + (((-q^6+q^4+q^2-1)/q^3)*s_c)*s_ab_cd*s_abc + (((-q^6+q^4+q^2-1)/q)*s_d)*s_ab_cd*s_abd + (((q^2-1)/q)*s_b*s_d)*s_b_c_d*s_cd + (((-q^6+q^4+q^2-1)/q^4)*s_a)*s_b_c_d*s_abc + (((-q^6+q^4+q^2-1)/q^4)*s_d)*s_b_c_d*s_bcd + (((q^6-q^4-q^2+1)/q^2)*s_d)*s_d_a_b*s_bcd + 1/q*s_a_bc_d*s_c_d_a + 1/q^3*s_a_bc_d*s_ac + 1/q^2*s_d*s_a_bc_d*s_acd + ((-q^4+1)/q)*s_c_da_b*s_bd + (((-q^2+1)/q^2)*s_c)*s_c_da_b*s_bcd + ((-2*q^5+4*q^3-q)*s_a*s_c)*s_ac*s_cd + ((q^8-2*q^4+1)/q)*s_ac*s_ad + ((q^3-q)*s_b*s_d)*s_bd*s_cd + (((-q^6+q^4+q^2-1)/q^6)*s_a)*s_bd*s_abc + (((q^12-q^10-q^8+q^4+q^2-1)/q^6)*s_d)*s_bd*s_bcd + ((-2*q^4+4*q^2-1)*s_a*s_b*s_c)*s_abc*s_cd + (((q^8- ...
# s_b_cd_a s_c_d_a
# s_d_ab_c s_c_d_a
# s_bd s_c_d_a
# s_bd*s_cd*s_ad
# case 2
# l is s_a*s_c*s_bd + 1/q*s_bd*s_c_d_a + q*s_bd*s_ac + s_d*s_bd*s_acd and r is (((-q^4+2*q^2-1)/q^2)*s_d^2*s_abcd) + (((-q^4+2*q^2-1)/q^2)*s_a*s_d)*s_bc + ((q^2-1)*s_a*s_b)*s_cd + ((-q^2+1)*s_b*s_c)*s_ad + ((q^4-1)/q)*s_ab_cd + ((-q^4+1)/q)*s_bc_ad + s_a*s_c*s_bd + (((-q^6+q^4+q^2-1)/q^3)*s_d)*s_abc + ((q^2-1)*s_d)*s_cd*s_abd + (((-q^2+1)/q^2)*s_d)*s_ad*s_bcd + 1/q*s_c_d_a*s_bd + q*s_ac*s_bd + s_d*s_acd*s_bd
# s_bcd s_c_d_a
# s_bcd*s_cd*s_ad
# case 2
# l is s_a*s_c*s_bcd + 1/q*s_bcd*s_c_d_a + q*s_bcd*s_ac + s_d*s_bcd*s_acd and r is (((q^2-1)/q^2)*s_a*s_b*s_d) + (((q^2-1)/q^2)*s_d*s_abcd)*s_cd + (((q^2-1)/q)*s_a)*s_b_c_d + (((q^2-1)/q^3)*s_a)*s_bd + s_a*s_c*s_bcd + ((q^4-1)/q^3)*s_cd*s_abc + 1/q^3*s_c_d_a*s_bcd + 1/q*s_ac*s_bcd + 1/q^2*s_d*s_acd*s_bcd
# s_acd s_c_d_a
# s_acd*s_cd*s_ad
# case 2
# l is s_a*s_c*s_acd + 1/q*s_acd*s_c_d_a + q*s_acd*s_ac + s_d*s_acd^2 and r is s_a*s_c*s_acd + 1/q*s_c_d_a*s_acd + q*s_ac*s_acd + s_d*s_acd^2
# s_abd s_c_d_a
# s_abd*s_cd*s_ad
# case 2
# l is s_a*s_c*s_abd + 1/q*s_abd*s_c_d_a + q*s_abd*s_ac + s_d*s_abd*s_acd and r is ((-q^2+1)*s_b*s_c*s_d+((q^6-q^4-q^2+1)/q)*s_a*s_abcd) + (((q^6-q^4-q^2+1)/q)*s_d)*s_bc + ((-q^2+1)*s_d*s_abcd)*s_ad + ((-q^3+q)*s_c)*s_d_a_b + (((-q^2+1)/q)*s_c)*s_bd + ((q^8-2*q^4+1)/q^2)*s_bcd + s_a*s_c*s_abd + (-q^5+q)*s_ad*s_abc + q*s_c_d_a*s_abd + q^3*s_ac*s_abd + q^2*s_d*s_acd*s_abd
# s_b_cd_a s_a_bc_d
# s_c_da_b s_a_bc_d
# s_d_ab_c s_a_bc_d
# s_ac s_a_bc_d
# s_ac*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_ac + (-q^2)*s_ac*s_ad + 1/q^2*s_ac*s_a_bc_d + ((-q)*s_c)*s_ac*s_acd + ((-q)*s_b)*s_ac*s_abd + q*s_ac*s_ab*s_bd + s_c*s_ac*s_ab*s_bcd + q*s_ac^2*s_cd + s_b*s_ac*s_abc*s_cd and r is (((q^6-q^4-q^2+1)/q^6)*s_c*s_d+((q^2-1)/q^2)*s_b^2*s_c*s_d+((-q^4+1)/q^5)*s_a*s_b*s_abcd+((2*q^4-3*q^2+1)/q^4)*s_a^2*s_c*s_d) + (((-q^4+2*q^2-1)/q^4)*s_c^2*s_abcd)*s_ab + (((q^4-1)/q^3)*s_b*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_c*s_abcd)*s_bc + ((-q^4+1)/q^7)*s_cd + (((q^6-q^4-q^2+1)/q^5)*s_a*s_c)*s_ad + (((q^2-1)/q)*s_a*s_d)*s_a_b_c + (((-q^2+1)/q^2)*s_a*s_b)*s_ab_cd + (((q^2-1)/q^3)*s_b*s_c)*s_b_c_d + ((q^4-1)/q^3)*s_d_ab_c + ((-1/q^2)*s_b*s_c*s_abcd+((q^6-q^4-q^2+1)/q^5)*s_a*s_d)*s_ac + (((q^2-1)/q)*s_b*s_c)*s_bd + (((2*q^2-2)/q^2)*s_a*s_b*s_d)*s_abc + (((-q^4+1)/q^6)*s_b+((q^2-1)/q^2)*s_b*s_c^2)*s_bcd + (((-q^4+1)/q^6)*s_a+((q^2-1)/q^2)*s_a*s_c^2)*s_acd + (((-q^4+2*q^2-1)/q^4)*s_c*s_d)*s_ab^2 + ((-q^4+1)/q^3)*s_ab*s_ab_cd + (((-q^6+q^4+q^2-1)/q^5)*s_c)*s_ab*s_abd + ((q^4-1)/q^4)*s_bc*s_b_c_d + ((q^8-1)/q^6)*s_bc*s_bd + (((q^4-1)/q^3)*s_c)*s_bc*s_bcd + (((q^4-1)/q^3)*s_a)*s_bc*s_abd + (-1)*s_ad*s_ac + (((q^2-1)/q^3)*s_c)*s_a_b_c*s_acd + (((-q^2+1)/q^4)*s_c)*s_ab_cd*s_abc + (((q^2-1)/q^5)*s_a)*s_b_c_d*s_abc + 1/q^4*s_a_bc_d*s_ac + ((q^4-1)/q^2)*s_ac*s_ad + (((q^2-1)/q)*s_c)*s_ac*s_acd + (((q^2-1)/q^3)*s_a)*s_bd*s_abc + (((q^4-1)/q^3)*s_b)*s_abc*s_ad + (((q^2-1)/q^2)*s_b*s_c)*s_abc*s_acd + (((q^2-1)/q^4)*s_a*s_c)*s_bcd*s_abc + ((-1/q)*s_c)*s_acd*s_ac + ((-1/q)*s_b)*s_abd*s_ac + 1/q*s_ab*s_bd*s_ac + 1/q^2*s_c*s_ab*s_bcd*s_ac + 1/q*s_ac*s_cd*s_ac + 1/q^2*s_b*s_abc*s_cd*s_ac
# s_bd s_a_bc_d
# s_bd*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_bd + (-q^2)*s_bd*s_ad + 1/q^2*s_bd*s_a_bc_d + ((-q)*s_c)*s_bd*s_acd + ((-q)*s_b)*s_bd*s_abd + q*s_bd*s_ab*s_bd + s_c*s_bd*s_ab*s_bcd + q*s_bd*s_ac*s_cd + s_b*s_bd*s_abc*s_cd and r is (((q^4-1)/q)*s_c*s_d*s_abcd+(-q^2+1)*s_a*s_b*s_d^2+(-q^2+1)*s_a*s_b*s_c^2) + ((q^4-1)/q)*s_ab + (((q^4-2*q^2+1)/q^2)*s_b*s_d*s_abcd+((-q^4+1)/q)*s_a*s_c)*s_bc + (((-q^4+2*q^2-1)/q^2)*s_b^2*s_abcd)*s_cd + (((q^4-3*q^2+2)/q)*s_b*s_c)*s_a_b_c + ((q^2-1)*s_c*s_d)*s_ab_cd + (((-q^2+1)/q)*s_a*s_d)*s_b_c_d + (((-q^4+2*q^2-1)/q)*s_b*s_c)*s_c_d_a + ((-q^4+1)/q)*s_b_cd_a + ((-q^3+q)*s_b*s_c)*s_ac + ((-q^2)*s_b*s_c*s_abcd+(-2*q^3+2*q)*s_a*s_d)*s_bd + (((q^4-1)/q^2)*s_c+((-q^2+1)/q^2)*s_b^2*s_c)*s_abc + ((-2*q^2+2)*s_a*s_c*s_d)*s_bcd + (((-q^4+2*q^2-1)/q^2)*s_b*s_c*s_d)*s_acd + ((q^4-1)*s_d+(-q^2+1)*s_b^2*s_d)*s_abd + ((-q^4+1)/q^2)*s_bc*s_ac + (((q^6-q^4-q^2+1)/q^3)*s_b)*s_bc*s_abc + (((-q^4+1)/q)*s_d)*s_bc*s_acd + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_cd*s_acd + (-2*q^4+1)*s_ad*s_bd + (((-q^4+1)/q)*s_c)*s_ad*s_bcd + ((-q^4+1)/q^2)*s_a_b_c*s_bc + (((-q^2+1)/q)*s_d)*s_a_b_c*s_bcd + ((q^4-1)/q)*s_ab_cd*s_cd + ((q^2-1)*s_b)*s_ab_cd*s_bcd + (((-q^2+1)/q)*s_b)*s_b_c_d*s_abd + s_a_bc_d*s_bd + (-q^4+1)*s_ac*s_bc + ((-q^3+q)*s_d)*s_ac*s_bcd + ((-q^3+q)*s_b)*s_bd*s_abd + (((-q^4+1)/q)*s_b)*s_abc*s_bc + ((-q^2+1)*s_b*s_d)*s_abc*s_bcd + ((-q^2+1)*s_b*s_c)*s_bcd*s_abd + ((-q^3)*s_c)*s_acd*s_bd + ((-q^3)*s_b)*s_abd*s_bd + q^3*s_ab*s_bd^2 + q^2*s_c*s_ab*s_bcd*s_bd + q^3*s_ac*s_cd*s_bd + q^2*s_b*s_abc*s_cd*s_bd
# s_abc s_a_bc_d
# s_abc*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_abc + (-q^2)*s_abc*s_ad + 1/q^2*s_abc*s_a_bc_d + ((-q)*s_c)*s_abc*s_acd + ((-q)*s_b)*s_abc*s_abd + q*s_abc*s_ab*s_bd + s_c*s_abc*s_ab*s_bcd + q*s_abc*s_ac*s_cd + s_b*s_abc^2*s_cd and r is (((q^2-1)/q^2)*s_a*s_c^2*s_abcd) + (((q^2-1)/q^2)*s_a*s_c*s_d)*s_ab + (((q^2-1)/q^3)*s_c*s_abcd)*s_a_b_c + (((q^2-1)/q)*s_c*s_abcd)*s_ac + (((q^2-2)/q^2)*s_b*s_c*s_abcd+((-q^2+1)/q^3)*s_a*s_d)*s_abc + (((q^4-1)/q^3)*s_a*s_c)*s_abd + (((q^2-1)/q)*s_d)*s_ab*s_a_b_c + (((q^2-1)/q^3)*s_d)*s_ab*s_ac + (((q^2-1)/q^2)*s_b*s_d)*s_ab*s_abc + (-1)*s_ad*s_abc + ((q^4-1)/q^4)*s_a_b_c*s_abd + 1/q^4*s_a_bc_d*s_abc + ((q^4-1)/q^2)*s_ac*s_abd + (((q^4-1)/q^3)*s_b)*s_abc*s_abd + ((-1/q)*s_c)*s_acd*s_abc + ((-1/q)*s_b)*s_abd*s_abc + 1/q*s_ab*s_bd*s_abc + 1/q^2*s_c*s_ab*s_bcd*s_abc + 1/q*s_ac*s_cd*s_abc + 1/q^2*s_b*s_abc*s_cd*s_abc
# s_bcd s_a_bc_d
# s_bcd*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_bcd + (-q^2)*s_bcd*s_ad + 1/q^2*s_bcd*s_a_bc_d + ((-q)*s_c)*s_bcd*s_acd + ((-q)*s_b)*s_bcd*s_abd + q*s_bcd*s_ab*s_bd + s_c*s_bcd*s_ab*s_bcd + q*s_bcd*s_ac*s_cd + s_b*s_bcd*s_abc*s_cd and r is (((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_d*s_abcd+(-q^2+1)*s_b^2*s_d*s_abcd+((-q^8+3*q^6-q^4-3*q^2+2)/q)*s_a*s_b*s_c) + (((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_c)*s_ab + (((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_a)*s_bc + (((q^6-q^4-q^2+1)/q)*s_c*s_abcd+(-q^2+1)*s_a*s_b*s_d)*s_cd + (((-q^2+1)/q)*s_b*s_abcd)*s_b_c_d + ((q^6-q^4-q^2+1)*s_b)*s_c_d_a + (((q^6-q^4-q^2+1)/q^2)*s_b)*s_ac + ((-q^3+q)*s_b*s_abcd)*s_bd + ((-q^12+3*q^8-3*q^4+1)/q^3)*s_abc + ((-2*q^2+1)*s_b*s_c*s_abcd+((-q^8+2*q^6-q^4-q^2+1)/q)*s_a*s_d)*s_bcd + (((-q^4+1)/q)*s_b*s_d)*s_acd + ((q^7-q^5-q^3+q)*s_a)*s_cd*s_bd + ((q^4-2*q^2+1)*s_a*s_c)*s_cd*s_bcd + (q^8-2*q^4+1)*s_cd*s_abd + (-q^4)*s_ad*s_bcd + ((-q^3+q)*s_a)*s_b_c_d*s_cd + (-q^4+1)*s_b_c_d*s_acd + s_a_bc_d*s_bcd + ((-q^5+q^3)*s_a)*s_bd*s_cd + (-q^6+q^2)*s_bd*s_acd + ((-q^4+q^2)*s_a*s_c)*s_bcd*s_cd + ((-q^5+q)*s_c)*s_bcd*s_acd + ((-q^3)*s_c)*s_acd*s_bcd + ((-q^3)*s_b)*s_abd*s_bcd + q^3*s_ab*s_bd*s_bcd + q^2*s_c*s_ab*s_bcd^2 + q^3*s_ac*s_cd*s_bcd + q^2*s_b*s_abc*s_cd*s_bcd
# s_acd s_a_bc_d
# s_acd*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_acd + (-q^2)*s_acd*s_ad + 1/q^2*s_acd*s_a_bc_d + ((-q)*s_c)*s_acd^2 + ((-q)*s_b)*s_acd*s_abd + q*s_acd*s_ab*s_bd + s_c*s_acd*s_ab*s_bcd + q*s_acd*s_ac*s_cd + s_b*s_acd*s_abc*s_cd and r is (((q^8-2*q^6+2*q^2-1)/q^3)*s_b^2*s_c+((q^4-1)/q^2)*s_a*s_b*s_d*s_abcd) + (((q^6-q^4-q^2+1)/q^3)*s_d*s_abcd+((q^4-2*q^2+1)/q^2)*s_a*s_b*s_c)*s_ab + (((q^10-q^8-q^6+q^4+q^2-1)/q^4)*s_b)*s_bc + (((q^2-1)/q^2)*s_b^2*s_d)*s_cd + (((-q^2+1)/q^2)*s_c*s_abcd)*s_ab_cd + (((q^2-1)/q^3)*s_a*s_abcd)*s_b_c_d + ((-q^2+1)*s_b)*s_c_da_b + (((q^2-1)/q)*s_a*s_abcd)*s_bd + ((q^3-q)*s_a*s_b)*s_abc + (((q^8-2*q^6+2*q^4+q^2-2)/q^3)*s_b*s_d+((q^2-1)/q^2)*s_a*s_c*s_abcd)*s_bcd + (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_acd + (((q^6-q^4-q^2+1)/q^3)*s_c)*s_ab^2 + (((-q^2+1)/q^3)*s_b)*s_ab*s_ac + ((q^8-2*q^4+1)/q^4)*s_ab*s_abc + (((-q^2+1)/q^2)*s_b*s_d)*s_ab*s_acd + ((-q^5+q^3)*s_b)*s_cd*s_bd + (((-q^4+2*q^2-1)/q^2)*s_b*s_c)*s_cd*s_bcd + ((-q^2+1)*s_a*s_b)*s_cd*s_abd + (-q^2)*s_ad*s_acd + ((-q^4+1)/q)*s_ab_cd*s_abd + (((q^2-1)/q)*s_b)*s_b_c_d*s_cd + ((q^4-1)/q^4)*s_b_c_d*s_bcd + 1/q^2*s_a_bc_d*s_acd + ((q^3-q)*s_b)*s_bd*s_cd + ((q^4-1)/q^2)*s_bd*s_bcd + ((q^2-1)*s_b*s_c)*s_bcd*s_cd + (((q^4-1)/q^3)*s_c)*s_bcd^2 + ((-q)*s_c)*s_acd^2 + ((-q)*s_b)*s_abd*s_acd + q*s_ab*s_bd*s_acd + s_c*s_ab*s_bcd*s_acd + q*s_ac*s_cd*s_acd + s_b*s_abc*s_cd*s_acd
# s_abd s_a_bc_d
# s_abd*s_ab*s_bc*s_cd
# case 2
# l is (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_abd + (-q^2)*s_abd*s_ad + 1/q^2*s_abd*s_a_bc_d + ((-q)*s_c)*s_abd*s_acd + ((-q)*s_b)*s_abd^2 + q*s_abd*s_ab*s_bd + s_c*s_abd*s_ab*s_bcd + q*s_abd*s_ac*s_cd + s_b*s_abd*s_abc*s_cd and r is (((-q^4+1)/q^2)*s_a*s_c*s_d*s_abcd) + ((-q^2+1)*s_a*s_c^2)*s_ab + ((-q^2+1)*s_c)*s_bc + (((-q^2+1)/q^3)*s_d*s_abcd)*s_a_b_c + (((q^2-1)/q^2)*s_b*s_abcd)*s_ab_cd + ((q^2-1)*s_c)*s_c_da_b + (((-q^2+1)/q)*s_d*s_abcd)*s_ac + (((-q^2+1)/q^2)*s_b*s_d*s_abcd+((-q^6+1)/q^3)*s_a*s_c)*s_abc + (((-q^2+1)/q)*s_c*s_d)*s_bcd + (-s_b*s_c*s_abcd+((-q^2+1)/q)*s_a*s_d)*s_abd + (((-q^2+1)/q)*s_c)*s_ab*s_a_b_c + (((-q^2+1)/q^2)*s_b*s_c)*s_ab*s_abc + (((q^2-1)/q^2)*s_c*s_d)*s_ab*s_acd + (((q^2-1)/q)*s_c)*s_cd*s_bd + ((q^2-1)*s_a*s_c)*s_cd*s_abd + (-q^2)*s_ad*s_abd + ((-q^4+1)/q^4)*s_a_b_c*s_abc + ((q^4-1)/q^3)*s_ab_cd*s_acd + 1/q^2*s_a_bc_d*s_abd + ((-q^4+1)/q^2)*s_ac*s_abc + (((-q^4+1)/q^3)*s_b)*s_abc^2 + ((-q)*s_c)*s_acd*s_abd + ((-q)*s_b)*s_abd^2 + q*s_ab*s_bd*s_abd + s_c*s_ab*s_bcd*s_abd + q*s_ac*s_cd*s_abd + s_b*s_abc*s_cd*s_abd
# s_c_da_b s_b_cd_a
# s_d_ab_c s_b_cd_a
# s_ac s_b_cd_a
# s_ac*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_ac + (-1/q^2)*s_ac*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_ac*s_bc + 1/q^2*s_ac*s_b_cd_a + ((-1/q^3)*s_c)*s_ac*s_abc + ((-1/q)*s_d)*s_ac*s_abd + q*s_ac*s_bc*s_ac + s_d*s_ac*s_bc*s_acd + 1/q*s_ac*s_ad*s_bd + 1/q^2*s_c*s_ac*s_ad*s_bcd and r is ((-q^2+1)*s_b*s_c*s_d^2+((q^4-1)/q)*s_a*s_d*s_abcd+(-q^2+1)*s_a^2*s_b*s_c) + ((q^4-1)/q)*s_bc + (((-q^4+1)/q)*s_b*s_d+((q^4-2*q^2+1)/q^2)*s_a*s_c*s_abcd)*s_cd + (((-q^4+2*q^2-1)/q^2)*s_c^2*s_abcd)*s_ad + (((q^4-3*q^2+2)/q)*s_c*s_d)*s_b_c_d + (((-q^4+2*q^2-1)/q)*s_c*s_d)*s_d_a_b + ((q^2-1)*s_a*s_d)*s_bc_ad + (((-q^2+1)/q)*s_a*s_b)*s_c_d_a + ((-q^4+1)/q)*s_c_da_b + (-s_c*s_d*s_abcd+(-q^3+q)*s_a*s_b)*s_ac + ((-q^3+q)*s_c*s_d)*s_bd + ((q^4-1)*s_a+(-q^2+1)*s_a*s_c^2)*s_abc + (((q^4-1)/q^2)*s_d+((-q^2+1)/q^2)*s_c^2*s_d)*s_bcd + ((-2*q^2+2)*s_a*s_b*s_d)*s_acd + (((-q^4+2*q^2-1)/q^2)*s_a*s_c*s_d)*s_abd + (-q^4)*s_ab*s_ac + (((-q^4+1)/q)*s_d)*s_ab*s_acd + ((q^2-1)*s_a*s_c)*s_bc*s_ac + ((-q^4+1)/q^2)*s_cd*s_bd + (((q^6-q^4-q^2+1)/q^3)*s_c)*s_cd*s_bcd + (((-q^4+1)/q)*s_a)*s_cd*s_abd + (((-q^6+q^4+q^2-1)/q^3)*s_c)*s_ad*s_abd + ((-q^4+1)/q^2)*s_b_c_d*s_cd + (((-q^2+1)/q)*s_a)*s_b_c_d*s_acd + ((q^4-1)/q)*s_bc_ad*s_ad + ((q^2-1)*s_c)*s_bc_ad*s_acd + (((-q^2+1)/q)*s_c)*s_c_d_a*s_abc + s_b_cd_a*s_ac + ((-q^3+q)*s_c)*s_ac*s_abc + (-q^4+1)*s_bd*s_cd + ((-q^3+q)*s_a)*s_bd*s_acd + ((-1/q)*s_c)*s_abc*s_ac + (((-q^4+1)/q)*s_c)*s_bcd*s_cd + ((-q^2+1)*s_a*s_c)*s_bcd*s_acd + ((-q^2+1)*s_c*s_d)*s_acd*s_abc + ((-q)*s_d)*s_abd*s_ac + q^3*s_bc*s_ac^2 + q^2*s_d*s_bc*s_acd*s_ac + q*s_ad*s_bd*s_ac + s_c*s_ad*s_bcd*s_ac
# s_bd s_b_cd_a
# s_bd*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_bd + (-1/q^2)*s_bd*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_bd*s_bc + 1/q^2*s_bd*s_b_cd_a + ((-1/q^3)*s_c)*s_bd*s_abc + ((-1/q)*s_d)*s_bd*s_abd + q*s_bd*s_bc*s_ac + s_d*s_bd*s_bc*s_acd + 1/q*s_bd*s_ad*s_bd + 1/q^2*s_c*s_bd*s_ad*s_bcd and r is (((-2*q^8+2*q^6+q^4-2*q^2+1)/q^5)*s_b*s_c*s_abcd+((-2*q^10+2*q^8+3*q^6-3*q^4-q^2+1)/q^6)*s_a*s_d+((q^2-1)/q^2)*s_a*s_c^2*s_d+((2*q^4-3*q^2+1)/q^4)*s_a*s_b^2*s_d) + (((-q^8+2*q^6-2*q^2+1)/q^5)*s_b*s_d)*s_ab + (((-q^4+2*q^2-1)/q^4)*s_d^2*s_abcd)*s_bc + (((q^4-2*q^2+1)/q^4)*s_b*s_d*s_abcd+((-q^6+2*q^4+q^2-2)/q^3)*s_a*s_c)*s_cd + ((-2*q^12+4*q^8-3*q^4+1)/q^7)*s_ad + (((q^2-1)/q)*s_a*s_b)*s_b_c_d + (((-q^2+1)/q^2)*s_b*s_c)*s_bc_ad + (((q^2-1)/q^3)*s_c*s_d)*s_c_d_a + ((q^4-1)/q^3)*s_a_bc_d + (((q^2-1)/q)*s_c*s_d)*s_ac + ((-1/q^4)*s_c*s_d*s_abcd+((q^6-2*q^2+1)/q^5)*s_a*s_b)*s_bd + (((2*q^2-2)/q^2)*s_a*s_b*s_c)*s_bcd + (((-2*q^10+q^8+3*q^6-2*q^4-q^2+1)/q^6)*s_c+((q^2-1)/q^2)*s_c*s_d^2)*s_acd + (((-2*q^10+q^8+3*q^6-2*q^4-q^2+1)/q^6)*s_b+((q^2-1)/q^2)*s_b*s_d^2)*s_abd + ((q^8-q^4-1)/q^4)*s_ab*s_bd + (((q^4-1)/q)*s_c)*s_ab*s_bcd + (((-q^4+2*q^2-1)/q^4)*s_a*s_d)*s_bc^2 + ((-q^4+1)/q^3)*s_bc*s_bc_ad + (((q^2-1)/q^4)*s_a*s_c)*s_bc*s_bd + (((-q^6+q^4+q^2-1)/q^5)*s_d)*s_bc*s_abc + ((q^4-1)/q^4)*s_cd*s_c_d_a + ((q^4-1)/q^6)*s_cd*s_ac + (((q^4-1)/q^3)*s_d)*s_cd*s_acd + (((q^2-1)/q^3)*s_d)*s_b_c_d*s_abd + (((-q^2+1)/q^4)*s_d)*s_bc_ad*s_bcd + (((q^2-1)/q^5)*s_b)*s_c_d_a*s_bcd + 1/q^4*s_b_cd_a*s_bd + (q^4-1)*s_ac*s_cd + (((q^2-1)/q^3)*s_b)*s_ac*s_bcd + (((q^2-1)/q)*s_d)*s_bd*s_abd + (((q^4-1)/q)*s_b)*s_abc*s_cd + ((-1/q^5)*s_c)*s_abc*s_bd + (((q^2-1)/q^2)*s_c*s_d)*s_bcd*s_abd + (((q^2-1)/q^4)*s_b*s_d)*s_acd*s_bcd + ((-1/q^3)*s_d)*s_abd*s_bd + 1/q*s_bc*s_ac*s_bd + 1/q^2*s_d*s_bc*s_acd*s_bd + 1/q^3*s_ad*s_bd^2 + 1/q^4*s_c*s_ad*s_bcd*s_bd
# s_abc s_b_cd_a
# s_abc*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_abc + (-1/q^2)*s_abc*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_abc*s_bc + 1/q^2*s_abc*s_b_cd_a + ((-1/q^3)*s_c)*s_abc^2 + ((-1/q)*s_d)*s_abc*s_abd + q*s_abc*s_bc*s_ac + s_d*s_abc*s_bc*s_acd + 1/q*s_abc*s_ad*s_bd + 1/q^2*s_c*s_abc*s_ad*s_bcd and r is ((q^5-2*q^3+q)*s_c*s_d^2+((q^6-3*q^4+q^2+1)/q^2)*s_a*s_b*s_d*s_abcd) + ((q^4-3*q^2+2)*s_b*s_d^2)*s_bc + ((q^6-q^4-2*q^2+2)*s_d)*s_cd + (((-q^2+1)/q^3)*s_a*s_abcd)*s_b_c_d + (((q^2-1)/q^2)*s_c*s_abcd)*s_bc_ad + ((q^2-1)*s_d)*s_d_ab_c + (((-q^2+1)/q)*s_a*s_abcd)*s_bd + ((-1/q^2)*s_c*s_d*s_abcd)*s_abc + (((q^8-2*q^6-q^4+q^2+1)/q^3)*s_b*s_d+((-q^2+1)/q^2)*s_a*s_c*s_abcd)*s_bcd + (((q^6-2*q^4+1)/q)*s_a*s_d)*s_acd + (-1/q^2)*s_ab*s_abc + (((-q^2+1)/q)*s_d)*s_bc*s_b_c_d + (((q^2-1)/q^2)*s_a*s_c)*s_bc*s_abc + (((-q^2+1)/q^2)*s_c*s_d)*s_bc*s_bcd + (((q^2-1)/q^2)*s_a*s_d)*s_bc*s_abd + (((-q^6+q^4+q^2-1)/q)*s_d)*s_ad*s_ac + ((-q^4+2*q^2-1)*s_b*s_d)*s_ad*s_abc + ((-q^4+1)/q^4)*s_b_c_d*s_bcd + ((q^4-1)/q^3)*s_bc_ad*s_abd + 1/q^2*s_b_cd_a*s_abc + ((q^3-q)*s_d)*s_ac*s_ad + ((-q^4+1)/q^2)*s_bd*s_bcd + ((q^2-1)*s_b*s_d)*s_abc*s_ad + ((-1/q^3)*s_c)*s_abc^2 + (((-q^4+1)/q^3)*s_c)*s_bcd^2 + ((-1/q)*s_d)*s_abd*s_abc + q*s_bc*s_ac*s_abc + s_d*s_bc*s_acd*s_abc + 1/q*s_ad*s_bd*s_abc + 1/q^2*s_c*s_ad*s_bcd*s_abc
# s_bcd s_b_cd_a
# s_bcd*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_bcd + (-1/q^2)*s_bcd*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_bcd*s_bc + 1/q^2*s_bcd*s_b_cd_a + ((-1/q^3)*s_c)*s_bcd*s_abc + ((-1/q)*s_d)*s_bcd*s_abd + q*s_bcd*s_bc*s_ac + s_d*s_bcd*s_bc*s_acd + 1/q*s_bcd*s_ad*s_bd + 1/q^2*s_c*s_bcd*s_ad*s_bcd and r is (((q^2-1)/q^2)*s_b*s_d^2*s_abcd) + (((q^2-1)/q^2)*s_a*s_b*s_d)*s_bc + (((q^2-1)/q^3)*s_d*s_abcd)*s_b_c_d + (((q^2-1)/q)*s_d*s_abcd)*s_bd + (((q^4-1)/q^3)*s_b*s_d)*s_abc + (((q^4-q^2-1)/q^4)*s_c*s_d*s_abcd)*s_bcd + (-1/q^4)*s_ab*s_bcd + (((q^2-1)/q)*s_a)*s_bc*s_b_c_d + (((q^2-1)/q^3)*s_a)*s_bc*s_bd + (((q^4-1)/q^4)*s_a*s_c)*s_bc*s_bcd + ((q^4-1)/q^4)*s_b_c_d*s_abc + 1/q^4*s_b_cd_a*s_bcd + ((q^4-1)/q^2)*s_bd*s_abc + ((-1/q^5)*s_c)*s_abc*s_bcd + (((q^4-1)/q^3)*s_c)*s_bcd*s_abc + ((-1/q^3)*s_d)*s_abd*s_bcd + 1/q*s_bc*s_ac*s_bcd + 1/q^2*s_d*s_bc*s_acd*s_bcd + 1/q^3*s_ad*s_bd*s_bcd + 1/q^4*s_c*s_ad*s_bcd^2
# s_acd s_b_cd_a
# s_acd*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_acd + (-1/q^2)*s_acd*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_acd*s_bc + 1/q^2*s_acd*s_b_cd_a + ((-1/q^3)*s_c)*s_acd*s_abc + ((-1/q)*s_d)*s_acd*s_abd + q*s_acd*s_bc*s_ac + s_d*s_acd*s_bc*s_acd + 1/q*s_acd*s_ad*s_bd + 1/q^2*s_c*s_acd*s_ad*s_bcd and r is (((-q^8+3*q^6-q^4-3*q^2+2)/q)*s_b*s_c*s_d+((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_a*s_abcd+(-q^2+1)*s_a*s_c^2*s_abcd) + (((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_d)*s_bc + (((-q^10+q^8+2*q^6-2*q^4-q^2+1)/q^2)*s_b)*s_cd + (((q^6-q^4-q^2+1)/q)*s_d*s_abcd+(-q^2+1)*s_a*s_b*s_c)*s_ad + ((q^6-q^4-q^2+1)*s_c)*s_d_a_b + (((-q^2+1)/q)*s_c*s_abcd)*s_c_d_a + ((-q^3+q)*s_c*s_abcd)*s_ac + (((q^6-q^4-q^2+1)/q^2)*s_c)*s_bd + ((-q^12+3*q^8-3*q^4+1)/q^3)*s_bcd + ((-q^2)*s_c*s_d*s_abcd+((-q^8+2*q^6-2*q^2+1)/q)*s_a*s_b)*s_acd + (((-q^4+1)/q)*s_a*s_c)*s_abd + (-1)*s_ab*s_acd + ((q^2-1)*s_a*s_c)*s_bc*s_acd + ((q^7-q^5-q^3+q)*s_b)*s_ad*s_ac + (q^8-2*q^4+1)*s_ad*s_abc + ((q^4-2*q^2+1)*s_b*s_d)*s_ad*s_acd + ((-q^3+q)*s_b)*s_c_d_a*s_ad + (-q^4+1)*s_c_d_a*s_abd + s_b_cd_a*s_acd + ((-q^5+q^3)*s_b)*s_ac*s_ad + (-q^6+q^2)*s_ac*s_abd + ((-1/q)*s_c)*s_abc*s_acd + ((-q^4+q^2)*s_b*s_d)*s_acd*s_ad + ((-q^5+q)*s_d)*s_acd*s_abd + ((-q)*s_d)*s_abd*s_acd + q^3*s_bc*s_ac*s_acd + q^2*s_d*s_bc*s_acd^2 + q*s_ad*s_bd*s_acd + s_c*s_ad*s_bcd*s_acd
# s_abd s_b_cd_a
# s_abd*s_bc*s_cd*s_ad
# case 2
# l is ((-1/q^2)*s_c*s_d*s_abcd)*s_abd + (-1/q^2)*s_abd*s_ab + (((q^2-1)/q^2)*s_a*s_c)*s_abd*s_bc + 1/q^2*s_abd*s_b_cd_a + ((-1/q^3)*s_c)*s_abd*s_abc + ((-1/q)*s_d)*s_abd^2 + q*s_abd*s_bc*s_ac + s_d*s_abd*s_bc*s_acd + 1/q*s_abd*s_ad*s_bd + 1/q^2*s_c*s_abd*s_ad*s_bcd and r is (((-q^4+2*q^2-1)/q^3)*s_c^2*s_d+((-q^6+3*q^4-q^2-1)/q^2)*s_a*s_b*s_c*s_abcd) + (((-q^6+3*q^4-3*q^2+1)/q^2)*s_b*s_c*s_d+((q^6-q^4-q^2+1)/q^3)*s_a*s_abcd)*s_bc + (((q^2-1)/q^4)*s_c)*s_cd + (((q^2-1)/q^2)*s_a*s_c^2)*s_ad + (((-q^2+1)/q^2)*s_d*s_abcd)*s_bc_ad + (((q^2-1)/q^3)*s_b*s_abcd)*s_c_d_a + ((-q^2+1)*s_c)*s_d_ab_c + (((q^2-1)/q)*s_b*s_abcd)*s_ac + (((-q^6+2*q^4-1)/q)*s_b*s_c)*s_bcd + (((q^2-1)/q^2)*s_b*s_d*s_abcd+((q^4+q^2-2)/q^3)*s_a*s_c)*s_acd + ((-1/q^2)*s_c*s_d*s_abcd)*s_abd + (-1/q^2)*s_ab*s_abd + (((q^6-q^4-q^2+1)/q^3)*s_d)*s_bc^2 + (((-q^2+1)/q^3)*s_c)*s_bc*s_bd + ((q^8-2*q^4+1)/q^4)*s_bc*s_bcd + ((q^4-2*q^2+1)*s_b*s_c)*s_ad*s_abc + (((-q^4+2*q^2-1)/q^2)*s_c*s_d)*s_ad*s_acd + ((-q^4+1)/q)*s_bc_ad*s_abc + (((q^2-1)/q)*s_c)*s_c_d_a*s_ad + ((q^4-1)/q^4)*s_c_d_a*s_acd + 1/q^2*s_b_cd_a*s_abd + ((q^4-1)/q^2)*s_ac*s_acd + ((-q^2+1)*s_b*s_c)*s_abc*s_ad + ((-1/q^3)*s_c)*s_abc*s_abd + ((q^2-1)*s_c*s_d)*s_acd*s_ad + (((q^4-1)/q^3)*s_d)*s_acd^2 + ((-1/q)*s_d)*s_abd^2 + q*s_bc*s_ac*s_abd + s_d*s_bc*s_acd*s_abd + 1/q*s_ad*s_bd*s_abd + 1/q^2*s_c*s_ad*s_bcd*s_abd
# s_d_ab_c s_c_da_b
# s_ac s_c_da_b
# s_ac*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_ac + (-1)*s_ac*s_bc + s_ac*s_c_da_b + ((-q)*s_a)*s_ac*s_abc + ((-1/q)*s_d)*s_ac*s_bcd + q*s_ac*s_ab*s_ac + s_d*s_ac*s_ab*s_acd + 1/q*s_ac*s_cd*s_bd + s_a*s_ac*s_cd*s_abd and r is (((-q^4+1)/q^5)*s_c*s_d*s_abcd+((q^2-1)/q^4)*s_a*s_b*s_d^2+((q^2-1)/q^2)*s_a*s_b*s_c^2) + ((-q^4+1)/q^5)*s_ab + (((q^6-q^4-q^2+1)/q^5)*s_a*s_c)*s_bc + (((-q^4+2*q^2-1)/q^4)*s_a^2*s_abcd)*s_cd + (((q^4-1)/q^5)*s_b*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_c*s_abcd)*s_ad + (((-q^2+1)/q^4)*s_c*s_d)*s_ab_cd + (((-q^4+2*q^2-1)/q^3)*s_a*s_d)*s_b_c_d + (((q^2-1)/q)*s_a*s_d)*s_d_a_b + (((q^2-1)/q^3)*s_b*s_c)*s_c_d_a + ((q^4-1)/q^5)*s_b_cd_a + (((q^2-1)/q)*s_b*s_c+(-1/q^2)*s_a*s_d*s_abcd)*s_ac + (((q^2-1)/q^5)*s_a*s_d)*s_bd + (((-q^4+1)/q^6)*s_c+((q^2-1)/q^2)*s_a^2*s_c)*s_abc + (((-q^4+2*q^2-1)/q^4)*s_a*s_c*s_d)*s_bcd + (((q^4-1)/q^4)*s_b*s_c*s_d)*s_acd + (((-q^4+1)/q^4)*s_d+((q^2-1)/q^2)*s_a^2*s_d)*s_abd + ((q^4-2)/q^2)*s_bc*s_ac + (((q^4-1)/q^3)*s_d)*s_bc*s_acd + (((-q^6+q^4+q^2-1)/q^5)*s_a)*s_cd*s_bcd + ((q^4-1)/q^4)*s_ad*s_bd + (((q^4-1)/q^5)*s_c)*s_ad*s_bcd + (((q^6-q^4-q^2+1)/q^5)*s_a)*s_ad*s_abd + ((-q^4+1)/q^5)*s_ab_cd*s_cd + (((-q^2+1)/q^4)*s_a)*s_ab_cd*s_acd + ((q^4-1)/q^4)*s_d_a_b*s_ad + (((q^2-1)/q^3)*s_c)*s_d_a_b*s_acd + (((q^2-1)/q^3)*s_a)*s_c_d_a*s_abc + 1/q^2*s_c_da_b*s_ac + (((q^2-1)/q)*s_a)*s_ac*s_abc + ((q^4-1)/q^6)*s_bd*s_ad + (((q^2-1)/q^5)*s_c)*s_bd*s_acd + ((-1/q)*s_a)*s_abc*s_ac + ((-1/q^3)*s_d)*s_bcd*s_ac + (((q^2-1)/q^2)*s_a*s_d)*s_acd*s_abc + (((q^4-1)/q^5)*s_a)*s_abd*s_ad + (((q^2-1)/q^4)*s_a*s_c)*s_abd*s_acd + 1/q*s_ab*s_ac^2 + 1/q^2*s_d*s_ab*s_acd*s_ac + 1/q^3*s_cd*s_bd*s_ac + 1/q^2*s_a*s_cd*s_abd*s_ac
# s_bd s_c_da_b
# s_bd*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_bd + (-1)*s_bd*s_bc + s_bd*s_c_da_b + ((-q)*s_a)*s_bd*s_abc + ((-1/q)*s_d)*s_bd*s_bcd + q*s_bd*s_ab*s_ac + s_d*s_bd*s_ab*s_acd + 1/q*s_bd*s_cd*s_bd + s_a*s_bd*s_cd*s_abd and r is ((-q^8+q^6+q^4-q^2)*s_c*s_d+(-q^2+1)*s_b^2*s_c*s_d+(-q^7+2*q^5+q^3-2*q)*s_a*s_b*s_abcd+(-q^4+q^2)*s_a^2*s_c*s_d) + ((-q^4+2*q^2-1)*s_d^2*s_abcd)*s_ab + (((-q^8+2*q^6-2*q^2+1)/q)*s_b*s_d)*s_bc + (-q^9+3*q^5-2*q)*s_cd + ((q^4-2*q^2+1)*s_b*s_d*s_abcd+(-q^5+q)*s_a*s_c)*s_ad + (((-q^4+2*q^2-1)/q)*s_a*s_d)*s_a_b_c + ((q^4-q^2)*s_a*s_b)*s_ab_cd + ((-q^3+q)*s_b*s_c)*s_d_a_b + (((-q^2+1)/q)*s_a*s_d)*s_c_d_a + (-q^5+q)*s_d_ab_c + ((-q^5+q^3)*s_a*s_d)*s_ac + (((-q^2+1)/q)*s_b*s_c+(-q^2)*s_a*s_d*s_abcd)*s_bd + ((-q^4+2*q^2-1)*s_a*s_b*s_d)*s_abc + ((-q^8+q^6+2*q^4-q^2-1)*s_b+(-q^2+1)*s_b*s_d^2)*s_bcd + ((-q^8+q^6+2*q^4-q^2-1)*s_a+(-q^2+1)*s_a*s_d^2)*s_acd + ((-q^4+1)*s_a*s_b*s_c)*s_abd + (q^5-q)*s_ab*s_ab_cd + (((-q^6+q^4+q^2-1)/q)*s_d)*s_ab*s_abc + ((-2*q^4+1)/q^2)*s_bc*s_bd + (((-q^4+1)/q)*s_a)*s_bc*s_abd + (q^8-2*q^4+1)*s_ad*s_ac + ((q^7-q^5-q^3+q)*s_b)*s_ad*s_abc + (((q^6-q^4-q^2+1)/q)*s_d)*s_ad*s_acd + ((q^4-q^2)*s_d)*s_ab_cd*s_abd + ((-q^3+q)*s_d)*s_d_a_b*s_bcd + (-q^4+1)*s_c_d_a*s_ad + ((-q^3+q)*s_b)*s_c_d_a*s_abd + q^2*s_c_da_b*s_bd + (-2*q^6+2*q^2)*s_ac*s_ad + ((-q^5+q^3)*s_b)*s_ac*s_abd + (((-q^2+1)/q)*s_d)*s_bd*s_bcd + ((-q^5+q)*s_b)*s_abc*s_ad + ((-q^3)*s_a)*s_abc*s_bd + ((-q)*s_d)*s_bcd*s_bd + ((-q^5+q)*s_d)*s_acd*s_ad + ((-q^4+q^2)*s_b*s_d)*s_acd*s_abd + ((-q^2+1)*s_a*s_d)*s_abd*s_bcd + q^3*s_ab*s_ac*s_bd + q^2*s_d*s_ab*s_acd*s_bd + q*s_cd*s_bd^2 + q^2*s_a*s_cd*s_abd*s_bd
# s_abc s_c_da_b
# s_abc*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_abc + (-1)*s_abc*s_bc + s_abc*s_c_da_b + ((-q)*s_a)*s_abc^2 + ((-1/q)*s_d)*s_abc*s_bcd + q*s_abc*s_ab*s_ac + s_d*s_abc*s_ab*s_acd + 1/q*s_abc*s_cd*s_bd + s_a*s_abc*s_cd*s_abd and r is (((q^4-1)/q^2)*s_b*s_c*s_d*s_abcd+((q^4-2*q^2+1)/q)*s_a*s_d^2) + ((q^2-1)*s_b*s_d^2)*s_ab + ((q^4-q^2)*s_d)*s_ad + (((-q^2+1)/q^2)*s_a*s_abcd)*s_ab_cd + (((q^2-1)/q)*s_c*s_abcd)*s_d_a_b + (((-q^2+1)/q^2)*s_d)*s_a_bc_d + (((q^2-1)/q^3)*s_c*s_abcd)*s_bd + (-s_a*s_d*s_abcd)*s_abc + ((q^3-q)*s_c*s_d)*s_acd + (((q^6-1)/q^3)*s_b*s_d+((q^2-1)/q^2)*s_a*s_c*s_abcd)*s_abd + (((q^2-1)/q)*s_d)*s_ab*s_d_a_b + (((-q^2+1)/q^2)*s_c*s_d)*s_ab*s_bcd + (((q^2-1)/q^2)*s_a*s_d)*s_ab*s_abd + (-1)*s_bc*s_abc + ((-q^4+1)/q^3)*s_ab_cd*s_bcd + ((q^4-1)/q^2)*s_d_a_b*s_abd + s_c_da_b*s_abc + ((-q^3+q)*s_d)*s_ac*s_cd + ((q^4-1)/q^4)*s_bd*s_abd + ((-q^2+1)*s_b*s_d)*s_abc*s_cd + ((-q)*s_a)*s_abc^2 + ((-1/q)*s_d)*s_bcd*s_abc + (((q^4-1)/q^3)*s_a)*s_abd^2 + q*s_ab*s_ac*s_abc + s_d*s_ab*s_acd*s_abc + 1/q*s_cd*s_bd*s_abc + s_a*s_cd*s_abd*s_abc
# s_bcd s_c_da_b
# s_bcd*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_bcd + (-1)*s_bcd*s_bc + s_bcd*s_c_da_b + ((-q)*s_a)*s_bcd*s_abc + ((-1/q)*s_d)*s_bcd^2 + q*s_bcd*s_ab*s_ac + s_d*s_bcd*s_ab*s_acd + 1/q*s_bcd*s_cd*s_bd + s_a*s_bcd*s_cd*s_abd and r is ((-q^4+1)*s_a*s_b*s_c*s_abcd+(-q^5+2*q^3-q)*s_a^2*s_d) + ((-q^4+2*q^2-1)*s_a*s_b*s_d)*s_ab + ((-q^2+1)*s_a^2*s_c)*s_cd + ((-q^6+q^4)*s_a)*s_ad + ((q^2-1)*s_d*s_abcd)*s_ab_cd + (((-q^2+1)/q)*s_b*s_abcd)*s_c_d_a + ((q^2-1)*s_a)*s_a_bc_d + ((-q^3+q)*s_b*s_abcd)*s_ac + (-s_a*s_d*s_abcd)*s_bcd + ((-q^2+1)*s_b*s_d*s_abcd+((-q^6+1)/q)*s_a*s_c)*s_acd + ((-q^5+q^3)*s_a*s_b)*s_abd + (((q^2-1)/q)*s_a)*s_ab*s_bd + ((q^2-1)*s_a*s_c)*s_ab*s_bcd + (-1)*s_bc*s_bcd + (((-q^2+1)/q)*s_a)*s_cd*s_c_d_a + ((-q^3+q)*s_a)*s_cd*s_ac + ((-q^2+1)*s_a*s_d)*s_cd*s_acd + ((q^4-1)/q)*s_ab_cd*s_abc + ((-q^4+1)/q^2)*s_c_d_a*s_acd + s_c_da_b*s_bcd + ((q^5-q^3)*s_a)*s_ac*s_cd + (-q^4+1)*s_ac*s_acd + ((q^4-q^2)*s_a*s_b)*s_abc*s_cd + ((-q)*s_a)*s_abc*s_bcd + ((-1/q)*s_d)*s_bcd^2 + (((-q^4+1)/q)*s_d)*s_acd^2 + q*s_ab*s_ac*s_bcd + s_d*s_ab*s_acd*s_bcd + 1/q*s_cd*s_bd*s_bcd + s_a*s_cd*s_abd*s_bcd
# s_acd s_c_da_b
# s_acd*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_acd + (-1)*s_acd*s_bc + s_acd*s_c_da_b + ((-q)*s_a)*s_acd*s_abc + ((-1/q)*s_d)*s_acd*s_bcd + q*s_acd*s_ab*s_ac + s_d*s_acd*s_ab*s_acd + 1/q*s_acd*s_cd*s_bd + s_a*s_acd*s_cd*s_abd and r is (((q^6-q^4-q^2+1)/q^5)*s_a*s_b*s_d+((q^2-1)/q^2)*s_a^2*s_c*s_abcd) + (((q^6-q^4-q^2+1)/q^5)*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_b*s_c)*s_cd + (((q^6-q^4-q^2+1)/q^4)*s_a)*s_b_c_d + (((q^2-1)/q^3)*s_a*s_abcd)*s_c_d_a + (((q^2-1)/q)*s_a*s_abcd)*s_ac + (((q^6-q^4-q^2+1)/q^6)*s_a)*s_bd + (((q^4-1)/q^3)*s_a*s_c)*s_bcd + (((q^2-2)/q^2)*s_a*s_d*s_abcd)*s_acd + (-1/q^2)*s_bc*s_acd + (((q^2-1)/q^3)*s_b)*s_cd*s_c_d_a + (((q^2-1)/q)*s_b)*s_cd*s_ac + ((q^8-2*q^4+1)/q^6)*s_cd*s_abc + (((q^2-1)/q^2)*s_b*s_d)*s_cd*s_acd + ((q^4-1)/q^6)*s_c_d_a*s_bcd + 1/q^2*s_c_da_b*s_acd + ((q^4-1)/q^4)*s_ac*s_bcd + ((-1/q)*s_a)*s_abc*s_acd + ((-1/q^3)*s_d)*s_bcd*s_acd + (((q^4-1)/q^5)*s_d)*s_acd*s_bcd + 1/q*s_ab*s_ac*s_acd + 1/q^2*s_d*s_ab*s_acd^2 + 1/q^3*s_cd*s_bd*s_acd + 1/q^2*s_a*s_cd*s_abd*s_acd
# s_abd s_c_da_b
# s_abd*s_ab*s_cd*s_ad
# case 2
# l is (-s_a*s_d*s_abcd)*s_abd + (-1)*s_abd*s_bc + s_abd*s_c_da_b + ((-q)*s_a)*s_abd*s_abc + ((-1/q)*s_d)*s_abd*s_bcd + q*s_abd*s_ab*s_ac + s_d*s_abd*s_ab*s_acd + 1/q*s_abd*s_cd*s_bd + s_a*s_abd*s_cd*s_abd and r is ((-q^2+1)*s_b*s_d^2*s_abcd+((q^6-q^4-q^2+1)/q)*s_a*s_c*s_d) + ((-q^2+1)*s_b*s_c*s_d+((q^6-q^4-q^2+1)/q)*s_a*s_abcd)*s_ab + (((q^6-q^4-q^2+1)/q^2)*s_d)*s_a_b_c + ((-q^3+q)*s_d*s_abcd)*s_d_a_b + ((q^6-q^4-q^2+1)*s_d)*s_ac + (((-q^2+1)/q)*s_d*s_abcd)*s_bd + (((-q^4+1)/q)*s_b*s_d)*s_abc + ((-2*q^2+1)*s_a*s_d*s_abcd)*s_abd + ((-q^3+q)*s_c)*s_ab*s_d_a_b + (((-q^2+1)/q)*s_c)*s_ab*s_bd + ((q^8-2*q^4+1)/q^2)*s_ab*s_bcd + ((-q^2+1)*s_a*s_c)*s_ab*s_abd + (-q^2)*s_bc*s_abd + (-q^6+q^2)*s_d_a_b*s_abc + q^2*s_c_da_b*s_abd + (-q^4+1)*s_bd*s_abc + ((-q^3)*s_a)*s_abc*s_abd + ((-q)*s_d)*s_bcd*s_abd + ((-q^5+q)*s_a)*s_abd*s_abc + q^3*s_ab*s_ac*s_abd + q^2*s_d*s_ab*s_acd*s_abd + q*s_cd*s_bd*s_abd + q^2*s_a*s_cd*s_abd^2
# s_ac s_d_ab_c
# s_ac*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_ac + (-1/q^4)*s_ac*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_ac*s_ad + s_ac*s_d_ab_c + ((-1/q^3)*s_b)*s_ac*s_bcd + ((-1/q^3)*s_a)*s_ac*s_acd + 1/q^3*s_ac*s_bc*s_bd + 1/q^2*s_a*s_ac*s_bc*s_abd + q*s_ac^2*s_ad + s_b*s_ac*s_abc*s_ad and r is (((q^4-1)/q)*s_b*s_c*s_abcd+((q^6-q^4-q^2+1)/q^2)*s_a*s_d+((-q^2+1)/q^2)*s_a*s_c^2*s_d+((-q^2+1)/q^2)*s_a*s_b^2*s_d) + (((-q^4+1)/q^3)*s_b*s_d+((q^4-2*q^2+1)/q^2)*s_a*s_c*s_abcd)*s_ab + (((-q^4+2*q^2-1)/q^2)*s_a^2*s_abcd)*s_bc + (q^5-q)*s_ad + (((-q^2+1)/q^3)*s_c*s_d)*s_a_b_c + (((-q^2+1)/q)*s_a*s_b)*s_d_a_b + (((q^2-1)/q^2)*s_b*s_c)*s_bc_ad + ((-q^4+1)/q^3)*s_a_bc_d + (-s_a*s_b*s_abcd)*s_ac + (((-q^2+1)/q^3)*s_a*s_b)*s_bd + (((-q^4+1)/q^2)*s_b*s_c*s_d)*s_abc + ((q^4-1)*s_c+(-q^2+1)*s_a^2*s_c)*s_acd + ((q^4-1)*s_b+((-q^2+1)/q^2)*s_a^2*s_b)*s_abd + ((-q^4+1)/q^2)*s_ab*s_d_a_b + ((-q^8+1)/q^4)*s_ab*s_bd + (((-q^4+1)/q^3)*s_c)*s_ab*s_bcd + (((-q^4+1)/q^3)*s_a)*s_ab*s_abd + (((-q^4+2*q^2-1)/q^2)*s_a*s_d)*s_bc^2 + ((q^4-1)/q^3)*s_bc*s_bc_ad + (((-q^6+q^4+q^2-1)/q^3)*s_a)*s_bc*s_bcd + (-1/q^2)*s_cd*s_ac + ((q^2-1)*s_a*s_c)*s_ad*s_ac + (((-q^2+1)/q)*s_a)*s_a_b_c*s_acd + ((-q^3+q)*s_c)*s_d_a_b*s_abc + ((q^2-1)*s_a)*s_bc_ad*s_abc + q^2*s_d_ab_c*s_ac + (-q^4+1)*s_ac*s_cd + ((-q^3+q)*s_a)*s_ac*s_acd + (((-q^2+1)/q)*s_c)*s_bd*s_abc + (((-q^4+1)/q)*s_b)*s_abc*s_cd + ((-q^2+1)*s_a*s_b)*s_abc*s_acd + ((-1/q)*s_b)*s_bcd*s_ac + ((-1/q)*s_a)*s_acd*s_ac + ((-q^2+1)*s_a*s_c)*s_abd*s_abc + 1/q*s_bc*s_bd*s_ac + s_a*s_bc*s_abd*s_ac + q^3*s_ac*s_ad*s_ac + q^2*s_b*s_abc*s_ad*s_ac
# s_bd s_d_ab_c
# s_bd*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_bd + (-1/q^4)*s_bd*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_bd*s_ad + s_bd*s_d_ab_c + ((-1/q^3)*s_b)*s_bd*s_bcd + ((-1/q^3)*s_a)*s_bd*s_acd + 1/q^3*s_bd*s_bc*s_bd + 1/q^2*s_a*s_bd*s_bc*s_abd + q*s_bd*s_ac*s_ad + s_b*s_bd*s_abc*s_ad and r is ((q^2-1)*s_b*s_c*s_d^2+((-q^4+1)/q)*s_a*s_d*s_abcd+(q^2-1)*s_a^2*s_b*s_c) + (((q^4-2*q^2+1)/q^2)*s_b*s_d*s_abcd+((q^4-1)/q^3)*s_a*s_c)*s_ab + ((-q^4+1)/q)*s_bc + (((-q^4+2*q^2-1)/q^2)*s_b^2*s_abcd)*s_ad + (((q^2-1)/q)*s_a*s_b)*s_a_b_c + ((q^3-q)*s_c*s_d)*s_d_a_b + ((-q^2+1)*s_a*s_d)*s_bc_ad + ((q^4-1)/q)*s_c_da_b + ((q^3-q)*s_a*s_b)*s_ac + (((q^6-q^4+q^2-1)/q^5)*s_c*s_d+(-1/q^4)*s_a*s_b*s_abcd)*s_bd + ((-q^4+1)*s_a+(q^2-1)*s_a*s_b^2)*s_abc + (((-q^4+1)/q^2)*s_d+((q^2-1)/q^2)*s_b^2*s_d)*s_bcd + (((q^4-1)/q^2)*s_a*s_c*s_d)*s_abd + ((q^4-1)/q^2)*s_ab*s_a_b_c + ((q^8-1)/q^4)*s_ab*s_ac + (((q^4-1)/q)*s_b)*s_ab*s_abc + (((q^4-1)/q)*s_d)*s_ab*s_acd + ((q^8-q^4-1)/q^6)*s_cd*s_bd + (((q^4-1)/q)*s_a)*s_cd*s_abd + (((-q^4+2*q^2-1)/q^2)*s_b*s_c)*s_ad^2 + (((q^2-1)/q^4)*s_a*s_c)*s_ad*s_bd + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_ad*s_acd + (((q^2-1)/q^3)*s_d)*s_a_b_c*s_abd + (((q^2-1)/q)*s_b)*s_d_a_b*s_bcd + ((-q^4+1)/q)*s_bc_ad*s_ad + (((-q^2+1)/q^2)*s_b)*s_bc_ad*s_abd + 1/q^2*s_d_ab_c*s_bd + (((q^2-1)/q)*s_d)*s_ac*s_abd + (((q^2-1)/q^3)*s_b)*s_bd*s_bcd + (((q^2-1)/q^2)*s_b*s_d)*s_abc*s_abd + ((-1/q^5)*s_b)*s_bcd*s_bd + ((-1/q^5)*s_a)*s_acd*s_bd + (((q^2-1)/q^2)*s_a*s_b)*s_abd*s_bcd + 1/q^5*s_bc*s_bd^2 + 1/q^4*s_a*s_bc*s_abd*s_bd + 1/q*s_ac*s_ad*s_bd + 1/q^2*s_b*s_abc*s_ad*s_bd
# s_abc s_d_ab_c
# s_abc*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_abc + (-1/q^4)*s_abc*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_abc*s_ad + s_abc*s_d_ab_c + ((-1/q^3)*s_b)*s_abc*s_bcd + ((-1/q^3)*s_a)*s_abc*s_acd + 1/q^3*s_abc*s_bc*s_bd + 1/q^2*s_a*s_abc*s_bc*s_abd + q*s_abc*s_ac*s_ad + s_b*s_abc^2*s_ad and r is ((-q^2+1)*s_a^2*s_c*s_abcd) + ((-q^2+1)*s_a*s_c*s_d)*s_bc + (((-q^2+1)/q)*s_a*s_abcd)*s_a_b_c + ((-q^3+q)*s_a*s_abcd)*s_ac + (((q^2-1)/q)*s_c*s_d+(-q^2)*s_a*s_b*s_abcd)*s_abc + (((-q^4+1)/q)*s_a*s_c)*s_bcd + (-1/q^2)*s_cd*s_abc + ((q^2-1)*s_a*s_c)*s_ad*s_abc + (((-q^2+1)/q)*s_d)*s_a_b_c*s_bc + ((-q^4+1)/q^2)*s_a_b_c*s_bcd + q^2*s_d_ab_c*s_abc + ((-q^3+q)*s_d)*s_ac*s_bc + (-q^4+1)*s_ac*s_bcd + ((-q^2+1)*s_b*s_d)*s_abc*s_bc + (((-q^4+1)/q)*s_b)*s_abc*s_bcd + ((-1/q)*s_b)*s_bcd*s_abc + ((-1/q)*s_a)*s_acd*s_abc + 1/q*s_bc*s_bd*s_abc + s_a*s_bc*s_abd*s_abc + q^3*s_ac*s_ad*s_abc + q^2*s_b*s_abc*s_ad*s_abc
# s_bcd s_d_ab_c
# s_bcd*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_bcd + (-1/q^4)*s_bcd*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_bcd*s_ad + s_bcd*s_d_ab_c + ((-1/q^3)*s_b)*s_bcd^2 + ((-1/q^3)*s_a)*s_bcd*s_acd + 1/q^3*s_bcd*s_bc*s_bd + 1/q^2*s_a*s_bcd*s_bc*s_abd + q*s_bcd*s_ac*s_ad + s_b*s_bcd*s_abc*s_ad and r is (((q^6-q^4+q^2-1)/q^2)*s_a*s_c*s_d*s_abcd+((q^8-2*q^6+2*q^2-1)/q^3)*s_a^2*s_b) + (((q^10-q^8-q^6+q^4+q^2-1)/q^4)*s_a)*s_ab + (((q^2-1)/q^2)*s_a^2*s_c)*s_bc + (((q^6-q^4-q^2+1)/q)*s_c*s_abcd+(q^4-2*q^2+1)*s_a*s_b*s_d)*s_ad + (((q^2-1)/q)*s_d*s_abcd)*s_a_b_c + ((-q^2+1)*s_b*s_abcd)*s_bc_ad + ((-q^2+1)*s_a)*s_b_cd_a + ((q^3-q)*s_d*s_abcd)*s_ac + ((q^2-1)*s_b*s_d*s_abcd+((q^8-q^6+q^4-1)/q^3)*s_a*s_c)*s_abc + (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_bcd + (((q^8-q^6-q^4+2*q^2-1)/q^3)*s_a*s_d)*s_abd + ((-q^5+q^3)*s_a)*s_bc*s_ac + ((-q^4+q^2)*s_a*s_d)*s_bc*s_acd + (-1/q^4)*s_cd*s_bcd + (((q^6-q^4-q^2+1)/q)*s_b)*s_ad^2 + (((-q^2+1)/q^3)*s_a)*s_ad*s_bd + ((q^8-2*q^4+1)/q^2)*s_ad*s_abd + (((q^2-1)/q)*s_a)*s_a_b_c*s_bc + ((q^4-1)/q^2)*s_a_b_c*s_abc + (-q^5+q)*s_bc_ad*s_acd + s_d_ab_c*s_bcd + ((q^3-q)*s_a)*s_ac*s_bc + (q^4-1)*s_ac*s_abc + ((q^2-1)*s_a*s_b)*s_abc*s_bc + (((q^4-1)/q)*s_b)*s_abc^2 + ((-1/q^3)*s_b)*s_bcd^2 + ((-1/q^3)*s_a)*s_acd*s_bcd + 1/q^3*s_bc*s_bd*s_bcd + 1/q^2*s_a*s_bc*s_abd*s_bcd + q*s_ac*s_ad*s_bcd + s_b*s_abc*s_ad*s_bcd
# s_acd s_d_ab_c
# s_acd*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_acd + (-1/q^4)*s_acd*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_acd*s_ad + s_acd*s_d_ab_c + ((-1/q^3)*s_b)*s_acd*s_bcd + ((-1/q^3)*s_a)*s_acd^2 + 1/q^3*s_acd*s_bc*s_bd + 1/q^2*s_a*s_acd*s_bc*s_abd + q*s_acd*s_ac*s_ad + s_b*s_acd*s_abc*s_ad and r is (((-q^6+q^4-q^2+1)/q^4)*s_b*s_c*s_d*s_abcd+((-q^8+2*q^6-2*q^2+1)/q^5)*s_a*s_b^2) + (((-q^10+q^8+q^6-q^4-q^2+1)/q^6)*s_b)*s_ab + (((q^6-q^4-q^2+1)/q^5)*s_d*s_abcd+((q^4-2*q^2+1)/q^4)*s_a*s_b*s_c)*s_bc + ((-q^2+1)*s_b^2*s_d)*s_ad + (((-q^2+1)/q)*s_c*s_abcd)*s_d_a_b + (((q^2-1)/q^2)*s_a*s_abcd)*s_bc_ad + (((q^2-1)/q^2)*s_b)*s_b_cd_a + (((-q^2+1)/q^3)*s_c*s_abcd)*s_bd + (((-q^8+2*q^6-q^4-q^2+1)/q^5)*s_b*s_c)*s_abc + (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_acd + (((-q^8+q^4-q^2+1)/q^5)*s_b*s_d+((-q^2+1)/q^2)*s_a*s_c*s_abcd)*s_abd + (((q^6-q^4-q^2+1)/q^5)*s_a)*s_bc^2 + ((q^3-q)*s_b)*s_bc*s_ac + ((q^8-2*q^4+1)/q^6)*s_bc*s_abc + ((q^2-1)*s_b*s_d)*s_bc*s_acd + (-1/q^4)*s_cd*s_acd + (((q^2-1)/q^5)*s_b)*s_ad*s_bd + (((q^2-1)/q^4)*s_b*s_c)*s_ad*s_bcd + (((q^2-1)/q^2)*s_a*s_c)*s_ad*s_acd + (((-q^2+1)/q)*s_b)*s_d_a_b*s_ad + ((-q^4+1)/q^2)*s_d_a_b*s_abd + ((q^4-1)/q^5)*s_bc_ad*s_bcd + s_d_ab_c*s_acd + (((-q^2+1)/q^3)*s_b)*s_bd*s_ad + ((-q^4+1)/q^4)*s_bd*s_abd + ((-1/q^3)*s_b)*s_bcd*s_acd + ((-1/q^3)*s_a)*s_acd^2 + (((-q^2+1)/q^2)*s_a*s_b)*s_abd*s_ad + (((-q^4+1)/q^3)*s_a)*s_abd^2 + 1/q^3*s_bc*s_bd*s_acd + 1/q^2*s_a*s_bc*s_abd*s_acd + q*s_ac*s_ad*s_acd + s_b*s_abc*s_ad*s_acd
# s_abd s_d_ab_c
# s_abd*s_ab*s_bc*s_ad
# case 2
# l is (((q^2-1)/q^3)*s_c*s_d+(-1/q^2)*s_a*s_b*s_abcd)*s_abd + (-1/q^4)*s_abd*s_cd + (((q^2-1)/q^2)*s_a*s_c)*s_abd*s_ad + s_abd*s_d_ab_c + ((-1/q^3)*s_b)*s_abd*s_bcd + ((-1/q^3)*s_a)*s_abd*s_acd + 1/q^3*s_abd*s_bc*s_bd + 1/q^2*s_a*s_abd*s_bc*s_abd + q*s_abd*s_ac*s_ad + s_b*s_abd*s_abc*s_ad and r is (((q^2-1)/q^2)*s_b^2*s_d*s_abcd) + (((q^2-1)/q^2)*s_b*s_c*s_d)*s_ad + (((q^2-1)/q)*s_b*s_abcd)*s_d_a_b + (((q^2-1)/q^3)*s_b*s_abcd)*s_bd + (((q^4-1)/q^3)*s_b*s_d)*s_acd + (((q^2-1)/q^5)*s_c*s_d+((q^4-q^2-1)/q^4)*s_a*s_b*s_abcd)*s_abd + (-1/q^6)*s_cd*s_abd + (((q^2-1)/q^4)*s_a*s_c)*s_ad*s_abd + (((q^2-1)/q)*s_c)*s_d_a_b*s_ad + ((q^4-1)/q^2)*s_d_a_b*s_acd + 1/q^2*s_d_ab_c*s_abd + (((q^2-1)/q^3)*s_c)*s_bd*s_ad + ((q^4-1)/q^4)*s_bd*s_acd + ((-1/q^5)*s_b)*s_bcd*s_abd + ((-1/q^5)*s_a)*s_acd*s_abd + (((q^2-1)/q^2)*s_a*s_c)*s_abd*s_ad + (((q^4-1)/q^3)*s_a)*s_abd*s_acd + 1/q^5*s_bc*s_bd*s_abd + 1/q^4*s_a*s_bc*s_abd^2 + 1/q*s_ac*s_ad*s_abd + 1/q^2*s_b*s_abc*s_ad*s_abd

# %%
#List of missing reordering relations which are still to be generated.
[b*a for a,b in combinations(A.gens(),2) if not b*a in {**all_commutators, **basic_rels, **m_relations}]
# Out:
# [s_ab_cd*s_a_b_c,
#  s_d_a_b*s_a_b_c,
#  s_c_da_b*s_a_b_c,
#  s_d_ab_c*s_a_b_c,
#  s_b_c_d*s_ab_cd,
#  s_d_a_b*s_ab_cd,
#  s_bc_ad*s_ab_cd,
#  s_b_cd_a*s_ab_cd,
#  s_d_ab_c*s_ab_cd,
#  s_d_a_b*s_b_c_d,
#  s_bc_ad*s_b_c_d,
#  s_b_cd_a*s_b_c_d,
#  s_c_da_b*s_b_c_d,
#  s_d_ab_c*s_b_c_d,
#  s_bc_ad*s_d_a_b,
#  s_c_d_a*s_d_a_b,
#  s_a_bc_d*s_d_a_b,
#  s_b_cd_a*s_d_a_b,
#  s_d_ab_c*s_d_a_b,
#  s_c_d_a*s_bc_ad,
#  s_a_bc_d*s_bc_ad,
#  s_c_da_b*s_bc_ad,
#  s_b_cd_a*s_c_d_a,
#  s_d_ab_c*s_c_d_a,
#  s_b_cd_a*s_a_bc_d,
#  s_c_da_b*s_a_bc_d,
#  s_d_ab_c*s_a_bc_d,
#  s_c_da_b*s_b_cd_a,
#  s_d_ab_c*s_b_cd_a,
#  s_d_ab_c*s_c_da_b]

# %%
reorder_basic = {**all_commutators, **basic_rels, **m_relations}
commutator_rw = RewritingSystem(reorder_basic)

# %%
# %%time
pool = ProcessPoolExecutor(8)
reduced_commutator_rw = commutator_rw.reduce_all()
# Out:
# s_a_b_c*s_ab
# s_d_a_b*s_ab
# s_ab_cd*s_ab
# s_a_b_c*s_bc
# s_b_c_d*s_bc
# s_bc_ad*s_bc
# s_c_d_a*s_cd
# s_a_b_c*s_ab : ((-q^2+1)*s_b*s_c) + ((-q^4+1)/q)*s_bc + ((-q^2+1)*s_a)*s_abc + q^2*s_ab*s_a_b_c
# s_ab_cd*s_ab : s_ab*s_ab_cd
# s_d_a_b*s_ab : (((q^2-1)/q^2)*s_a*s_d) + ((q^4-1)/q^3)*s_ad + (((q^2-1)/q^2)*s_b)*s_abd + 1/q^2*s_ab*s_d_a_b
# s_a_b_c*s_bc : (((q^2-1)/q^2)*s_a*s_b) + ((q^4-1)/q^3)*s_ab + (((q^2-1)/q^2)*s_c)*s_abc + 1/q^2*s_bc*s_a_b_c
# s_b_c_d*s_cd
# s_ab_cd*s_cd
# s_b_c_d*s_bc : ((-q^2+1)*s_c*s_d) + ((-q^4+1)/q)*s_cd + ((-q^2+1)*s_b)*s_bcd + q^2*s_bc*s_b_c_d
# s_bc_ad*s_bc : s_bc*s_bc_ad
# s_ab_cd*s_cd : s_cd*s_ab_cd
# s_b_c_d*s_cd : (((q^2-1)/q^2)*s_b*s_c) + ((q^4-1)/q^3)*s_bc + (((q^2-1)/q^2)*s_d)*s_bcd + 1/q^2*s_cd*s_b_c_d
# s_d_a_b*s_ad
# s_bc_ad*s_ad
# s_c_d_a*s_cd : ((-q^2+1)*s_a*s_d) + ((-q^4+1)/q)*s_ad + ((-q^2+1)*s_c)*s_acd + q^2*s_cd*s_c_d_a
# s_d_a_b*s_ad : ((-q^2+1)*s_a*s_b) + ((-q^4+1)/q)*s_ab + ((-q^2+1)*s_d)*s_abd + q^2*s_ad*s_d_a_b
# s_bc_ad*s_ad : s_ad*s_bc_ad
# s_c_d_a*s_ad : (((q^2-1)/q^2)*s_c*s_d) + ((q^4-1)/q^3)*s_cd + (((q^2-1)/q^2)*s_a)*s_acd + 1/q^2*s_ad*s_c_d_a
# s_c_d_a*s_ad
# s_b_c_d*s_a_b_c
# s_bc_ad*s_a_b_c
# s_c_d_a*s_a_b_c
# s_b_cd_a*s_a_b_c
# s_bd*s_a_b_c
# s_bc_ad*s_a_b_c : (((-q^6-q^4+q^2+1)/q^5)*s_b*s_d+((q^4-2*q^2+1)/q^2)*s_a*s_c*s_abcd) + (((q^6-2*q^4+1)/q^4)*s_c*s_d+((-q^2+1)/q^3)*s_a*s_b*s_abcd)*s_bc + (((-q^2+1)/q^2)*s_a*s_b)*s_ad + ((-q^4+1)/q^6)*s_b_c_d + ((-q^4+1)/q^2)*s_d_a_b + (((-q^2+1)/q^3)*s_a*s_c)*s_bc_ad + ((-2*q^4+2)/q^4)*s_bd + (((q^8-q^6-2*q^4+q^2+1)/q^5)*s_c)*s_bcd + (((-q^4+1)/q^3)*s_a)*s_abd + (((-q^4+1)/q^4)*s_b)*s_bc*s_bcd + (((-q^2+1)/q^4)*s_a)*s_bc*s_acd + ((-q^2+1)*s_c)*s_ad*s_abc + s_a_b_c*s_bc_ad + ((q^4-1)/q^4)*s_bc^2*s_bd + (((q^2-1)/q^3)*s_a)*s_bc^2*s_abd
# s_abc*s_a_b_c
# s_bcd*s_a_b_c
# s_abd*s_a_b_c
# s_abc*s_a_b_c : s_a_b_c*s_abc
# s_bd*s_a_b_c : s_a_b_c*s_bd
# s_c_d_a*s_ab_cd
# s_b_c_d*s_a_b_c : (((-q^6-q^4+q^2+1)/q)*s_abcd+((q^4-1)/q)*s_c^2*s_abcd+(q^5-q)*s_b^2*s_abcd+(-q^4+1)*s_a*s_b*s_c*s_d) + ((-q^5+q^3)*s_c*s_d)*s_ab + ((-q^3+q)*s_a*s_d)*s_bc + (((-q^2+1)/q)*s_a*s_b)*s_cd + ((-q^8+1)/q^2)*s_ab_cd + ((-q^3+q)*s_b*s_c)*s_a_bc_d + ((-q^4+1)*s_d)*s_abc + ((-q^4+1)*s_a)*s_bcd + ((q^6-q^2)*s_b)*s_acd + (((q^4-1)/q^2)*s_c)*s_abd + ((-q^5+q)*s_b)*s_ab*s_bcd + (((-q^4+1)/q)*s_c)*s_cd*s_abc + q^4*s_a_b_c*s_b_c_d
# s_ac*s_ab_cd
# s_bd*s_ab_cd
# s_bcd*s_a_b_c : ((-q^2+1)*s_c*s_abcd) + ((-q^2+1)*s_a)*s_bd + ((-q^4+1)/q)*s_abd + q^2*s_a_b_c*s_bcd
# s_abd*s_a_b_c : (((q^2-1)/q^2)*s_a*s_abcd) + (((q^2-1)/q^2)*s_c)*s_bd + ((q^4-1)/q^3)*s_bcd + 1/q^2*s_a_b_c*s_abd
# s_abc*s_ab_cd
# s_bcd*s_ab_cd
# s_acd*s_ab_cd
# s_c_d_a*s_b_c_d
# s_abd*s_ab_cd
# s_ac*s_b_c_d
# s_c_d_a*s_ab_cd : (((-q^6-q^4+q^2+1)/q)*s_b*s_d+((-q^4+2*q^2-1)/q^2)*s_a*s_c*s_abcd) + ((-q^2+1)*s_a*s_d)*s_ab + (((-q^6+2*q^2-1)/q^2)*s_b*s_c+(-q^3+q)*s_a*s_d*s_abcd)*s_cd + ((-q^3+q)*s_a*s_c)*s_ab_cd + (-q^6+q^2)*s_b_c_d + ((-q^4+1)/q^2)*s_d_a_b + (-2*q^4+2)*s_bd + (((-q^8-q^6+2*q^4+q^2-1)/q^3)*s_c)*s_bcd + (((-q^4+1)/q)*s_a)*s_abd + (((-q^2+1)/q^2)*s_c)*s_ab*s_acd + ((-q^4+q^2)*s_a)*s_cd*s_abc + ((-q^4+1)*s_d)*s_cd*s_bcd + s_ab_cd*s_c_d_a + (q^4-1)*s_cd^2*s_bd + ((q^3-q)*s_a)*s_cd^2*s_abd
# s_ac*s_ab_cd : (((q^6+q^4-q^2-1)/q^5)*s_b*s_d+((q^4-2*q^2+1)/q^4)*s_a*s_c*s_abcd) + (((q^2-1)/q^2)*s_a*s_d)*s_ab + (((q^2-1)/q^2)*s_b*s_c)*s_cd + ((q^4-1)/q^4)*s_b_c_d + ((q^4-1)/q^4)*s_d_a_b + ((q^8-1)/q^6)*s_bd + (((q^4-1)/q^3)*s_c)*s_bcd + (((q^4-1)/q^3)*s_a)*s_abd + (((q^2-1)/q^4)*s_c)*s_ab*s_acd + (((q^2-1)/q^4)*s_a)*s_cd*s_abc + 1/q^4*s_ab_cd*s_ac
# s_abc*s_b_c_d
# s_bcd*s_b_c_d
# s_acd*s_b_c_d
# s_bd*s_ab_cd : ((q^4-2*q^2+1)*s_b*s_d*s_abcd+((-q^6-q^4+q^2+1)/q)*s_a*s_c) + ((-q^2+1)*s_b*s_c)*s_ab + ((-q^2+1)*s_a*s_d)*s_cd + (-q^4+1)*s_a_b_c + (-q^4+1)*s_c_d_a + ((-q^8+1)/q^2)*s_ac + (((-q^4+1)/q)*s_b)*s_abc + (((-q^4+1)/q)*s_d)*s_acd + ((-q^4+q^2)*s_d)*s_ab*s_bcd + ((-q^4+q^2)*s_b)*s_cd*s_abd + q^4*s_ab_cd*s_bd
# s_abc*s_ab_cd : (((q^2-1)/q^2)*s_c*s_abcd)*s_ab + (((q^2-1)/q^2)*s_d)*s_ab^2 + ((q^4-1)/q^3)*s_ab*s_abd + 1/q^2*s_ab_cd*s_abc
# s_ac*s_d_a_b
# s_abc*s_d_a_b
# s_bcd*s_ab_cd : ((-q^2+1)*s_b*s_abcd)*s_cd + ((-q^2+1)*s_a)*s_cd^2 + ((-q^4+1)/q)*s_cd*s_acd + q^2*s_ab_cd*s_bcd
# s_acd*s_d_a_b
# s_abd*s_d_a_b
# s_ac*s_bc_ad
# s_bd*s_bc_ad
# s_abc*s_bc_ad
# s_c_d_a*s_a_b_c : (((q^2-1)/q)*s_a*s_abcd)*s_bcd + (((-q^2+1)/q)*s_c*s_abcd)*s_abd + s_a_b_c*s_c_d_a + (((q^2-1)/q)*s_c)*s_bd*s_bcd + (((-q^2+1)/q)*s_a)*s_bd*s_abd + ((q^4-1)/q^2)*s_bcd^2 + ((-q^4+1)/q^2)*s_abd^2
# s_acd*s_ab_cd : (((q^2-1)/q^2)*s_a*s_abcd)*s_cd + (((q^2-1)/q^2)*s_b)*s_cd^2 + ((q^4-1)/q^3)*s_cd*s_bcd + 1/q^2*s_ab_cd*s_acd
# s_bcd*s_bc_ad
# s_abd*s_ab_cd : ((-q^2+1)*s_d*s_abcd)*s_ab + ((-q^2+1)*s_c)*s_ab^2 + ((-q^4+1)/q)*s_ab*s_abc + q^2*s_ab_cd*s_abd
# s_ac*s_b_c_d : s_b_c_d*s_ac
# s_abc*s_b_c_d : (((q^2-1)/q^2)*s_b*s_abcd) + (((q^2-1)/q^2)*s_d)*s_ac + ((q^4-1)/q^3)*s_acd + 1/q^2*s_b_c_d*s_abc
# s_bcd*s_b_c_d : s_b_c_d*s_bcd
# s_acd*s_b_c_d : ((-q^2+1)*s_d*s_abcd) + ((-q^2+1)*s_b)*s_ac + ((-q^4+1)/q)*s_abc + q^2*s_b_c_d*s_acd
# s_ac*s_d_a_b : s_d_a_b*s_ac
# s_acd*s_bc_ad
# s_abd*s_bc_ad
# s_a_bc_d*s_c_d_a
# s_abc*s_d_a_b : ((-q^2+1)*s_b*s_abcd) + ((-q^2+1)*s_d)*s_ac + ((-q^4+1)/q)*s_acd + q^2*s_d_a_b*s_abc
# s_bd*s_c_d_a
# s_bcd*s_c_d_a
# s_acd*s_c_d_a
# s_abd*s_c_d_a
# s_c_d_a*s_b_c_d : (((-q^6-q^4+q^2+1)/q)*s_abcd+((q^4-1)/q)*s_d^2*s_abcd+(q^5-q)*s_c^2*s_abcd+(-q^4+1)*s_a*s_b*s_c*s_d) + ((-q^5+q^3)*s_a*s_d)*s_bc + ((-q^3+q)*s_a*s_b)*s_cd + (((-q^2+1)/q)*s_b*s_c)*s_ad + ((-q^8+1)/q^2)*s_bc_ad + ((-q^3+q)*s_c*s_d)*s_b_cd_a + (((q^4-1)/q^2)*s_d)*s_abc + ((-q^4+1)*s_a)*s_bcd + ((-q^4+1)*s_b)*s_acd + ((q^6-q^2)*s_c)*s_abd + ((-q^5+q)*s_c)*s_bc*s_acd + (((-q^4+1)/q)*s_d)*s_ad*s_bcd + q^4*s_b_c_d*s_c_d_a
# s_acd*s_d_a_b : (((q^2-1)/q^2)*s_d*s_abcd) + (((q^2-1)/q^2)*s_b)*s_ac + ((q^4-1)/q^3)*s_abc + 1/q^2*s_d_a_b*s_acd
# s_abd*s_d_a_b : s_d_a_b*s_abd
# s_ac*s_a_bc_d
# s_bd*s_a_bc_d
# s_abc*s_a_bc_d
# s_ac*s_bc_ad : (((-q^6-q^4+q^2+1)/q)*s_b*s_d+(q^4-2*q^2+1)*s_a*s_c*s_abcd) + ((-q^2+1)*s_c*s_d)*s_bc + ((-q^2+1)*s_a*s_b)*s_ad + (-q^4+1)*s_b_c_d + (-q^4+1)*s_d_a_b + ((-q^8+1)/q^2)*s_bd + (((-q^4+1)/q)*s_c)*s_bcd + (((-q^4+1)/q)*s_a)*s_abd + ((-q^4+q^2)*s_a)*s_bc*s_acd + ((-q^4+q^2)*s_c)*s_ad*s_abc + q^4*s_bc_ad*s_ac
# s_bcd*s_a_bc_d
# s_bd*s_bc_ad : (((q^4-2*q^2+1)/q^4)*s_b*s_d*s_abcd+((q^6+q^4-q^2-1)/q^5)*s_a*s_c) + (((q^2-1)/q^2)*s_a*s_b)*s_bc + (((q^2-1)/q^2)*s_c*s_d)*s_ad + ((q^4-1)/q^4)*s_a_b_c + ((q^4-1)/q^4)*s_c_d_a + ((q^8-1)/q^6)*s_ac + (((q^4-1)/q^3)*s_b)*s_abc + (((q^4-1)/q^3)*s_d)*s_acd + (((q^2-1)/q^4)*s_d)*s_bc*s_abd + (((q^2-1)/q^4)*s_b)*s_ad*s_bcd + 1/q^4*s_bc_ad*s_bd
# s_abc*s_bc_ad : ((-q^2+1)*s_a*s_abcd)*s_bc + ((-q^2+1)*s_d)*s_bc^2 + ((-q^4+1)/q)*s_bc*s_bcd + q^2*s_bc_ad*s_abc
# s_bcd*s_bc_ad : (((q^2-1)/q^2)*s_d*s_abcd)*s_bc + (((q^2-1)/q^2)*s_a)*s_bc^2 + ((q^4-1)/q^3)*s_bc*s_abc + 1/q^2*s_bc_ad*s_bcd
# s_acd*s_bc_ad : ((-q^2+1)*s_c*s_abcd)*s_ad + ((-q^2+1)*s_b)*s_ad^2 + ((-q^4+1)/q)*s_ad*s_abd + q^2*s_bc_ad*s_acd
# s_abd*s_bc_ad : (((q^2-1)/q^2)*s_b*s_abcd)*s_ad + (((q^2-1)/q^2)*s_c)*s_ad^2 + ((q^4-1)/q^3)*s_ad*s_acd + 1/q^2*s_bc_ad*s_abd
# s_bd*s_c_d_a : s_c_d_a*s_bd
# s_acd*s_c_d_a : s_c_d_a*s_acd
# s_bcd*s_c_d_a : (((q^2-1)/q^2)*s_c*s_abcd) + (((q^2-1)/q^2)*s_a)*s_bd + ((q^4-1)/q^3)*s_abd + 1/q^2*s_c_d_a*s_bcd
# s_abd*s_c_d_a : ((-q^2+1)*s_a*s_abcd) + ((-q^2+1)*s_c)*s_bd + ((-q^4+1)/q)*s_bcd + q^2*s_c_d_a*s_abd
# s_acd*s_a_bc_d
# s_abd*s_a_bc_d
# s_abc*s_a_bc_d : (((q^2-1)/q^2)*s_a*s_abcd) + (((q^2-1)/q^2)*s_d)*s_bc + ((q^4-1)/q^3)*s_bcd + 1/q^2*s_a_bc_d*s_abc
# s_ac*s_b_cd_a
# s_acd*s_a_bc_d : (((-q^2+1)/q)*s_d*s_abcd)*s_ab + (((q^2-1)/q)*s_a*s_abcd)*s_b_c_d + (((-q^2+1)/q)*s_a*s_b)*s_abc + (((q^2-1)/q)*s_b*s_d)*s_bcd + ((-q^4+1)/q^2)*s_ab*s_abc + ((q^4-1)/q^2)*s_b_c_d*s_bcd + s_a_bc_d*s_acd
# s_bcd*s_a_bc_d : ((-q^2+1)*s_d*s_abcd) + ((-q^2+1)*s_a)*s_bc + ((-q^4+1)/q)*s_abc + q^2*s_a_bc_d*s_bcd
# s_bd*s_b_cd_a
# s_abc*s_b_cd_a
# s_abd*s_a_bc_d : (((q^2-1)/q)*s_a*s_abcd)*s_cd + (((-q^2+1)/q)*s_d*s_abcd)*s_a_b_c + (((-q^2+1)/q)*s_a*s_c)*s_abc + (((q^2-1)/q)*s_c*s_d)*s_bcd + ((q^4-1)/q^2)*s_cd*s_bcd + ((-q^4+1)/q^2)*s_a_b_c*s_abc + s_a_bc_d*s_abd
# s_bcd*s_b_cd_a
# s_ac*s_a_bc_d : ((-q^2+1)*s_c*s_d+((-q^2+1)/q^3)*s_a*s_b*s_abcd) + ((-q^4+1)/q)*s_cd + (((-q^2+1)/q^3)*s_a*s_d)*s_ac + (((-q^4+1)/q^2)*s_b)*s_bcd + (((-q^2+1)/q^4)*s_a)*s_acd + ((q^4-1)/q^2)*s_bc*s_b_c_d + (((q^2-1)/q^3)*s_a)*s_b_c_d*s_abc + 1/q^2*s_a_bc_d*s_ac
# s_bcd*s_b_cd_a : (((q^2-1)/q^2)*s_b*s_abcd) + (((q^2-1)/q^2)*s_a)*s_cd + ((q^4-1)/q^3)*s_acd + 1/q^2*s_b_cd_a*s_bcd
# s_acd*s_b_cd_a
# s_abc*s_b_cd_a : (((q^2-1)/q)*s_b*s_abcd)*s_ad + (((-q^2+1)/q)*s_a*s_abcd)*s_b_c_d + (((-q^2+1)/q)*s_b*s_d)*s_bcd + (((q^2-1)/q)*s_a*s_d)*s_acd + ((q^4-1)/q^2)*s_ad*s_acd + ((-q^4+1)/q^2)*s_b_c_d*s_bcd + s_b_cd_a*s_abc
# s_abd*s_b_cd_a
# s_ac*s_c_da_b
# s_bd*s_a_bc_d : ((q^3-q)*s_c*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_b) + ((q^4-1)/q^3)*s_ab + ((q^3-q)*s_a*s_d)*s_bd + (((q^4-1)/q^2)*s_c)*s_abc + ((q^4-q^2)*s_d)*s_abd + ((-q^4+1)/q^2)*s_bc*s_a_b_c + ((-q^3+q)*s_d)*s_a_b_c*s_bcd + q^2*s_a_bc_d*s_bd
# s_bd*s_c_da_b
# s_abc*s_c_da_b
# s_acd*s_b_cd_a : ((-q^2+1)*s_a*s_abcd) + ((-q^2+1)*s_b)*s_cd + ((-q^4+1)/q)*s_bcd + q^2*s_b_cd_a*s_acd
# s_bcd*s_c_da_b
# s_abd*s_b_cd_a : (((-q^2+1)/q)*s_a*s_abcd)*s_bc + (((q^2-1)/q)*s_b*s_abcd)*s_c_d_a + (((-q^2+1)/q)*s_b*s_c)*s_bcd + (((q^2-1)/q)*s_a*s_c)*s_acd + ((-q^4+1)/q^2)*s_bc*s_bcd + ((q^4-1)/q^2)*s_c_d_a*s_acd + s_b_cd_a*s_abd
# s_ac*s_b_cd_a : (((q^2-1)/q^2)*s_b*s_c+(q^3-q)*s_a*s_d*s_abcd) + ((q^4-1)/q^3)*s_bc + ((q^3-q)*s_a*s_b)*s_ac + ((q^4-q^2)*s_a)*s_abc + (((q^4-1)/q^2)*s_d)*s_bcd + ((-q^4+1)/q^2)*s_cd*s_b_c_d + ((-q^3+q)*s_a)*s_b_c_d*s_acd + q^2*s_b_cd_a*s_ac
# s_bd*s_b_cd_a : (((-q^2+1)/q^3)*s_b*s_c*s_abcd+(-q^2+1)*s_a*s_d) + ((-q^4+1)/q)*s_ad + (((-q^2+1)/q^3)*s_a*s_b)*s_bd + (((-q^4+1)/q^2)*s_c)*s_acd + (((-q^2+1)/q^4)*s_b)*s_abd + ((q^4-1)/q^2)*s_cd*s_c_d_a + (((q^2-1)/q^3)*s_b)*s_c_d_a*s_bcd + 1/q^2*s_b_cd_a*s_bd
# s_acd*s_c_da_b
# s_abd*s_c_da_b
# s_bcd*s_c_da_b : (((q^2-1)/q)*s_c*s_abcd)*s_ab + (((-q^2+1)/q)*s_b*s_abcd)*s_c_d_a + (((-q^2+1)/q)*s_a*s_c)*s_acd + (((q^2-1)/q)*s_a*s_b)*s_abd + ((q^4-1)/q^2)*s_ab*s_abd + ((-q^4+1)/q^2)*s_c_d_a*s_acd + s_c_da_b*s_bcd
# s_ac*s_d_ab_c
# s_abc*s_c_da_b : (((-q^2+1)/q)*s_b*s_abcd)*s_cd + (((q^2-1)/q)*s_c*s_abcd)*s_d_a_b + (((-q^2+1)/q)*s_c*s_d)*s_acd + (((q^2-1)/q)*s_b*s_d)*s_abd + ((-q^4+1)/q^2)*s_cd*s_acd + ((q^4-1)/q^2)*s_d_a_b*s_abd + s_c_da_b*s_abc
# s_acd*s_c_da_b : (((q^2-1)/q^2)*s_c*s_abcd) + (((q^2-1)/q^2)*s_b)*s_ad + ((q^4-1)/q^3)*s_abd + 1/q^2*s_c_da_b*s_acd
# s_bd*s_d_ab_c
# s_abc*s_d_ab_c
# s_abd*s_c_da_b : ((-q^2+1)*s_b*s_abcd) + ((-q^2+1)*s_c)*s_ad + ((-q^4+1)/q)*s_acd + q^2*s_c_da_b*s_abd
# s_bd*s_c_da_b : (((q^2-1)/q^2)*s_c*s_d+(q^3-q)*s_a*s_b*s_abcd) + ((q^4-1)/q^3)*s_cd + ((q^3-q)*s_b*s_c)*s_bd + ((q^4-q^2)*s_b)*s_bcd + (((q^4-1)/q^2)*s_a)*s_acd + ((-q^4+1)/q^2)*s_ad*s_c_d_a + ((-q^3+q)*s_b)*s_c_d_a*s_abd + q^2*s_c_da_b*s_bd
# s_bcd*s_d_ab_c
# s_acd*s_d_ab_c
# s_ac*s_c_da_b : (((-q^2+1)/q^3)*s_c*s_d*s_abcd+(-q^2+1)*s_a*s_b) + ((-q^4+1)/q)*s_ab + (((-q^2+1)/q^3)*s_b*s_c)*s_ac + (((-q^2+1)/q^4)*s_c)*s_abc + (((-q^4+1)/q^2)*s_d)*s_abd + ((q^4-1)/q^2)*s_ad*s_d_a_b + (((q^2-1)/q^3)*s_c)*s_d_a_b*s_acd + 1/q^2*s_c_da_b*s_ac
# s_abd*s_d_ab_c
# s_abc*s_d_ab_c : ((-q^2+1)*s_c*s_abcd) + ((-q^2+1)*s_d)*s_ab + ((-q^4+1)/q)*s_abd + q^2*s_d_ab_c*s_abc
# s_cd*s_ab
# s_cd*s_ab : s_ab_cd
# s_acd*s_d_ab_c : (((q^2-1)/q)*s_d*s_abcd)*s_bc + (((-q^2+1)/q)*s_c*s_abcd)*s_d_a_b + (((q^2-1)/q)*s_b*s_c)*s_abc + (((-q^2+1)/q)*s_b*s_d)*s_abd + ((q^4-1)/q^2)*s_bc*s_abc + ((-q^4+1)/q^2)*s_d_a_b*s_abd + s_d_ab_c*s_acd
# s_ad*s_bc
# s_ad*s_bc : s_bc_ad
# s_acd*s_cd
# s_abd*s_ab
# s_bcd*s_d_ab_c : (((-q^2+1)/q)*s_c*s_abcd)*s_ad + (((q^2-1)/q)*s_d*s_abcd)*s_a_b_c + (((q^2-1)/q)*s_a*s_c)*s_abc + (((-q^2+1)/q)*s_a*s_d)*s_abd + ((-q^4+1)/q^2)*s_ad*s_abd + ((q^4-1)/q^2)*s_a_b_c*s_abc + s_d_ab_c*s_bcd
# s_acd*s_cd : s_cd*s_acd
# s_abd*s_d_ab_c : (((q^2-1)/q^2)*s_d*s_abcd) + (((q^2-1)/q^2)*s_c)*s_ab + ((q^4-1)/q^3)*s_abc + 1/q^2*s_d_ab_c*s_abd
# s_abd*s_ab : s_ab*s_abd
# s_bcd*s_cd
# s_abc*s_ab
# s_bcd*s_cd : s_cd*s_bcd
# s_acd*s_ad
# s_abc*s_ab : s_ab*s_abc
# s_acd*s_ad : s_ad*s_acd
# s_abd*s_ad
# s_bcd*s_bc
# s_abd*s_ad : s_ad*s_abd
# s_abc*s_bc
# s_acd*s_ac
# s_bcd*s_bc : s_bc*s_bcd
# s_abc*s_bc : s_bc*s_abc
# s_acd*s_ac : s_ac*s_acd
# s_abd*s_bd
# s_abd*s_bd : s_bd*s_abd
# s_bcd*s_bd
# s_abc*s_ac
# s_c_da_b*s_ad
# s_ac*s_d_ab_c : ((q^3-q)*s_b*s_c*s_abcd+((q^2-1)/q^2)*s_a*s_d) + ((q^4-1)/q^3)*s_ad + ((q^3-q)*s_c*s_d)*s_ac + ((q^4-q^2)*s_c)*s_acd + (((q^4-1)/q^2)*s_b)*s_abd + ((-q^4+1)/q^2)*s_ab*s_d_a_b + ((-q^3+q)*s_c)*s_d_a_b*s_abc + q^2*s_d_ab_c*s_ac
# s_a_bc_d*s_bc
# s_b_cd_a*s_cd
# s_d_ab_c*s_ab
# s_ad*s_ab
# s_bcd*s_bd : s_bd*s_bcd
# s_abc*s_ac : s_ac*s_abc
# s_c_da_b*s_ad : s_ad*s_c_da_b
# s_ac*s_ab
# s_abc*s_ad
# s_bd*s_bc
# s_bcd*s_ab
# s_a_bc_d*s_a_b_c
# s_a_bc_d*s_bc : s_bc*s_a_bc_d
# s_b_cd_a*s_cd : s_cd*s_b_cd_a
# s_d_ab_c*s_ab : s_ab*s_d_ab_c
# s_ad*s_ab : s_b*s_d + 1/q*s_d_a_b + q*s_bd + s_a*s_abd
# s_d_ab_c*s_bc
# s_bd*s_d_ab_c : ((-q^2+1)*s_b*s_c+((-q^2+1)/q^3)*s_a*s_d*s_abcd) + ((-q^4+1)/q)*s_bc + (((-q^2+1)/q^3)*s_c*s_d)*s_bd + (((-q^4+1)/q^2)*s_a)*s_abc + (((-q^2+1)/q^4)*s_d)*s_bcd + ((q^4-1)/q^2)*s_ab*s_a_b_c + (((q^2-1)/q^3)*s_d)*s_a_b_c*s_abd + 1/q^2*s_d_ab_c*s_bd
# s_ac*s_ab : (((q^2-1)/q^2)*s_b*s_c) + ((q^4-1)/q^3)*s_bc + (((q^2-1)/q^2)*s_a)*s_abc + 1/q^2*s_ab*s_ac
# s_bd*s_bc : (((q^2-1)/q^2)*s_c*s_d) + ((q^4-1)/q^3)*s_cd + (((q^2-1)/q^2)*s_b)*s_bcd + 1/q^2*s_bc*s_bd
# s_a_bc_d*s_ab
# s_bc*s_ab
# s_ad*s_cd
# s_abc*s_ad : ((-q^2+1)*s_a*s_abcd) + ((-q^2+1)*s_d)*s_bc + ((-q^4+1)/q)*s_bcd + q^2*s_ad*s_abc
# s_cd*s_bc
# s_bcd*s_ab : ((-q^2+1)*s_b*s_abcd) + ((-q^2+1)*s_a)*s_cd + ((-q^4+1)/q)*s_acd + q^2*s_ab*s_bcd
# s_bd*s_ab
# s_bd*s_cd
# s_d_ab_c*s_bc : (((q^2-1)/q^2)*s_b*s_d+((-q^2+1)/q)*s_a*s_c*s_abcd) + (((-q^2+1)/q)*s_c*s_d)*s_bc + ((q^4-1)/q^3)*s_d_a_b + ((-q^2+1)*s_c)*s_bcd + 1/q^2*s_bc*s_d_ab_c + (((q^2-1)/q)*s_c)*s_ad*s_abc
# s_ac*s_cd
# s_a_bc_d*s_a_b_c : ((-q^2+1)*s_c*s_d+(q^3-q)*s_a*s_b*s_abcd) + ((-q^4+1)/q+(q^3-q)*s_a^2)*s_cd + ((q^4-q^2)*s_a)*s_acd + ((-q^3+q)*s_a)*s_ab*s_bcd + q^2*s_a_b_c*s_a_bc_d
# s_ac*s_ad
# s_ac*s_bc
# s_a_bc_d*s_ab : ((-q^2+1)*s_b*s_d+((q^2-1)/q)*s_a*s_c*s_abcd) + (((q^2-1)/q)*s_a*s_d)*s_ab + ((-q^4+1)/q)*s_b_c_d + (((q^2-1)/q^2)*s_a)*s_abd + q^2*s_ab*s_a_bc_d + (((-q^2+1)/q)*s_a)*s_cd*s_abc
# s_bc*s_ab : s_a*s_c + q*s_a_b_c + 1/q*s_ac + s_b*s_abc
# s_bd*s_ad
# s_abd*s_bc
# s_ad*s_cd : s_a*s_c + q*s_c_d_a + 1/q*s_ac + s_d*s_acd
# s_bcd*s_ad
# s_acd*s_bc
# s_cd*s_bc : s_b*s_d + q*s_b_c_d + 1/q*s_bd + s_c*s_bcd
# s_bd*s_ab : ((-q^2+1)*s_a*s_d) + ((-q^4+1)/q)*s_ad + ((-q^2+1)*s_b)*s_abd + q^2*s_ab*s_bd
# s_acd*s_ab
# s_abc*s_cd
# s_bd*s_cd : ((-q^2+1)*s_b*s_c) + ((-q^4+1)/q)*s_bc + ((-q^2+1)*s_d)*s_bcd + q^2*s_cd*s_bd
# s_ac*s_cd : (((q^2-1)/q^2)*s_a*s_d) + ((q^4-1)/q^3)*s_ad + (((q^2-1)/q^2)*s_c)*s_acd + 1/q^2*s_cd*s_ac
# s_abd*s_cd
# s_d_ab_c*s_ad
# s_b_cd_a*s_bc
# s_ac*s_ad : ((-q^2+1)*s_c*s_d) + ((-q^4+1)/q)*s_cd + ((-q^2+1)*s_a)*s_acd + q^2*s_ad*s_ac
# s_b_cd_a*s_ad
# s_ac*s_bc : ((-q^2+1)*s_a*s_b) + ((-q^4+1)/q)*s_ab + ((-q^2+1)*s_c)*s_abc + q^2*s_bc*s_ac
# s_c_da_b*s_d_a_b
# s_a_bc_d*s_b_c_d
# s_bd*s_ad : (((q^2-1)/q^2)*s_a*s_b) + ((q^4-1)/q^3)*s_ab + (((q^2-1)/q^2)*s_d)*s_abd + 1/q^2*s_ad*s_bd
# s_c_da_b*s_c_d_a
# s_c_da_b*s_ab
# s_a_bc_d*s_cd
# s_c_da_b*s_cd
# s_abd*s_bc : (((q^2-1)/q^2)*s_b*s_abcd) + (((q^2-1)/q^2)*s_c)*s_ad + ((q^4-1)/q^3)*s_acd + 1/q^2*s_bc*s_abd
# s_bcd*s_ad : (((q^2-1)/q^2)*s_d*s_abcd) + (((q^2-1)/q^2)*s_a)*s_bc + ((q^4-1)/q^3)*s_abc + 1/q^2*s_ad*s_bcd
# s_acd*s_bc : ((-q^2+1)*s_c*s_abcd) + ((-q^2+1)*s_b)*s_ad + ((-q^4+1)/q)*s_abd + q^2*s_bc*s_acd
# s_c_da_b*s_ab_cd
# s_a_bc_d*s_ab_cd
# s_acd*s_ab : (((q^2-1)/q^2)*s_a*s_abcd) + (((q^2-1)/q^2)*s_b)*s_cd + ((q^4-1)/q^3)*s_bcd + 1/q^2*s_ab*s_acd
# s_abc*s_cd : (((q^2-1)/q^2)*s_c*s_abcd) + (((q^2-1)/q^2)*s_d)*s_ab + ((q^4-1)/q^3)*s_abd + 1/q^2*s_cd*s_abc
# s_abd*s_cd : ((-q^2+1)*s_d*s_abcd) + ((-q^2+1)*s_c)*s_ab + ((-q^4+1)/q)*s_abc + q^2*s_cd*s_abd
# s_b_cd_a*s_bc_ad
# s_d_ab_c*s_bc_ad
# s_ac*s_bd
# s_d_ab_c*s_ad : (((q^2-1)/q)*s_b*s_d*s_abcd+(-q^2+1)*s_a*s_c) + (((q^2-1)/q)*s_c*s_d)*s_ad + ((-q^4+1)/q)*s_a_b_c + (((q^2-1)/q^2)*s_d)*s_acd + (((-q^2+1)/q)*s_d)*s_bc*s_abd + q^2*s_ad*s_d_ab_c
# s_bd*s_ac
# s_ac*s_abd
# s_bd*s_abc
# s_b_cd_a*s_bc : (((q^2-1)/q)*s_b*s_d*s_abcd+(-q^2+1)*s_a*s_c) + (((q^2-1)/q)*s_a*s_b)*s_bc + ((-q^4+1)/q)*s_c_d_a + (((q^2-1)/q^2)*s_b)*s_abc + q^2*s_bc*s_b_cd_a + (((-q^2+1)/q)*s_b)*s_ad*s_bcd
# s_b_cd_a*s_ad : (((q^2-1)/q^2)*s_b*s_d+((-q^2+1)/q)*s_a*s_c*s_abcd) + (((-q^2+1)/q)*s_a*s_b)*s_ad + ((q^4-1)/q^3)*s_b_c_d + ((-q^2+1)*s_a)*s_abd + (((q^2-1)/q)*s_a)*s_bc*s_acd + 1/q^2*s_ad*s_b_cd_a
# s_c_da_b*s_d_a_b : (((q^2-1)/q^2)*s_c*s_d+((-q^2+1)/q^3)*s_a*s_b*s_abcd) + ((q^4-1)/q^3+((-q^2+1)/q^3)*s_b^2)*s_cd + (((-q^2+1)/q^4)*s_b)*s_bcd + (((q^2-1)/q^3)*s_b)*s_ab*s_acd + 1/q^2*s_d_a_b*s_c_da_b
# s_bd*s_acd
# Process ForkProcess-6:
# Process ForkProcess-7:
# Process ForkProcess-4:
# Process ForkProcess-3:
# Process ForkProcess-1:
# Traceback (most recent call last):
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "sage/rings/fraction_field_element.pyx", line 1206, in sage.rings.fraction_field_element.make_element (build/cythonized/sage/rings/fraction_field_element.c:12695)
#     return parent._element_class(parent, numerator, denominator)
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "sage/rings/fraction_field_element.pyx", line 121, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:3073)
#     self.reduce()
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkProcess-2:
#   File "sage/rings/fraction_field_element.pyx", line 1190, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.reduce (build/cythonized/sage/rings/fraction_field_element.c:12485)
#     self.normalize_leading_coefficients()
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
#   File "sage/rings/fraction_field_element.pyx", line 1126, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.normalize_leading_coefficients (build/cythonized/sage/rings/fraction_field_element.c:11846)
#     invlc = ~self.__denominator.leading_coefficient()
# KeyboardInterrupt
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "sage/structure/element.pyx", line 2658, in sage.structure.element.RingElement.__invert__ (build/cythonized/sage/structure/element.c:18456)
#     return self._parent.one() / self
#   File "sage/structure/element.pyx", line 1716, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:12802)
#     return (<Element>left)._div_(right)
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "sage/rings/function_field/element.pyx", line 1073, in sage.rings.function_field.element.FunctionFieldElement_rational._div_ (build/cythonized/sage/rings/function_field/element.c:10157)
#     res._x = self._x / (<FunctionFieldElement>right)._x
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "sage/structure/element.pyx", line 1716, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:12802)
#     return (<Element>left)._div_(right)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "sage/modules/with_basis/indexed_element.pyx", line 911, in sage.modules.with_basis.indexed_element._unpickle_element (build/cythonized/sage/modules/with_basis/indexed_element.c:9410)
#     return C._from_dict(d, coerce=False, remove_zeros=False)
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "sage/rings/fraction_field_element.pyx", line 720, in sage.rings.fraction_field_element.FractionFieldElement._div_ (build/cythonized/sage/rings/fraction_field_element.c:8501)
#     rightinv = self.__class__(self._parent, sden, snum,
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/combinat/free_module.py", line 1192, in _from_dict
#     return self.element_class(self, d)
# Traceback (most recent call last):
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/algebras/free_algebra_element.py", line 81, in __init__
#     x = {A.monoid()(e1): R(e2) for e1,e2 in x.items()}
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "sage/rings/fraction_field_element.pyx", line 114, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:2906)
#     self.__numerator   = parent.ring()(numerator)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/rings/fraction_field.py", line 498, in ring
#     def ring(self):
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/algebras/free_algebra_element.py", line 81, in <dictcomp>
#     x = {A.monoid()(e1): R(e2) for e1,e2 in x.items()}
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/rings/polynomial/multi_polynomial_ring.py", line 410, in __call__
#     import sage.rings.polynomial.polynomial_element as polynomial_element
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
#   File "sage/rings/fraction_field_element.pyx", line 1206, in sage.rings.fraction_field_element.make_element (build/cythonized/sage/rings/fraction_field_element.c:12695)
#     return parent._element_class(parent, numerator, denominator)
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 226, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "sage/rings/fraction_field_element.pyx", line 121, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:3073)
#     self.reduce()
# KeyboardInterrupt
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
# KeyboardInterrupt
#   File "sage/rings/fraction_field_element.pyx", line 1190, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.reduce (build/cythonized/sage/rings/fraction_field_element.c:12485)
#     self.normalize_leading_coefficients()
#   File "sage/rings/fraction_field_element.pyx", line 1126, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.normalize_leading_coefficients (build/cythonized/sage/rings/fraction_field_element.c:11846)
#     invlc = ~self.__denominator.leading_coefficient()
#   File "sage/structure/element.pyx", line 2658, in sage.structure.element.RingElement.__invert__ (build/cythonized/sage/structure/element.c:18456)
#     return self._parent.one() / self
#   File "sage/structure/element.pyx", line 1716, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:12802)
#     return (<Element>left)._div_(right)
#   File "sage/rings/function_field/element.pyx", line 1073, in sage.rings.function_field.element.FunctionFieldElement_rational._div_ (build/cythonized/sage/rings/function_field/element.c:10157)
#     res._x = self._x / (<FunctionFieldElement>right)._x
#   File "sage/structure/element.pyx", line 1716, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:12802)
#     return (<Element>left)._div_(right)
#   File "sage/rings/fraction_field_element.pyx", line 720, in sage.rings.fraction_field_element.FractionFieldElement._div_ (build/cythonized/sage/rings/fraction_field_element.c:8501)
#     rightinv = self.__class__(self._parent, sden, snum,
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "sage/rings/fraction_field_element.pyx", line 114, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:2906)
#     self.__numerator   = parent.ring()(numerator)
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/rings/fraction_field.py", line 498, in ring
#     def ring(self):
#   File "src/cysignals/signals.pyx", line 320, in cysignals.signals.python_check_interrupt
# KeyboardInterrupt
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/home/sage/sage/local/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/sage/sage/local/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/queues.py", line 236, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "/home/sage/sage/local/lib/python3.7/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "sage/rings/rational.pyx", line 541, in sage.rings.rational.Rational.__reduce__ (build/cythonized/sage/rings/rational.c:6489)
#     return sage.rings.rational.make_rational, (self.str(32),)
#   File "sage/rings/rational.pyx", line 2174, in sage.rings.rational.Rational.str (build/cythonized/sage/rings/rational.c:19371)
#     sig_on()
# KeyboardInterrupt
# s_a_bc_d*s_b_c_d : (((-q^2+1)/q^3)*s_c*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_b) + ((q^4-1)/q^3+((-q^2+1)/q^3)*s_d^2)*s_ab + (((-q^2+1)/q^4)*s_d)*s_abd + (((q^2-1)/q^3)*s_d)*s_cd*s_abc + 1/q^2*s_b_c_d*s_a_bc_d
# s_c_da_b*s_c_d_a : ((q^3-q)*s_c*s_d*s_abcd+(-q^2+1)*s_a*s_b) + ((-q^4+1)/q+(q^3-q)*s_c^2)*s_ab + ((q^4-q^2)*s_c)*s_abc + ((-q^3+q)*s_c)*s_cd*s_abd + q^2*s_c_d_a*s_c_da_b
# s_c_da_b*s_ab : (((-q^2+1)/q)*s_b*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_c) + (((-q^2+1)/q)*s_b*s_c)*s_ab + ((q^4-1)/q^3)*s_c_d_a + ((-q^2+1)*s_b)*s_abc + 1/q^2*s_ab*s_c_da_b + (((q^2-1)/q)*s_b)*s_cd*s_abd
# s_a_bc_d*s_cd : (((-q^2+1)/q)*s_b*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_c) + (((-q^2+1)/q)*s_a*s_d)*s_cd + ((q^4-1)/q^3)*s_a_b_c + ((-q^2+1)*s_d)*s_acd + (((q^2-1)/q)*s_d)*s_ab*s_bcd + 1/q^2*s_cd*s_a_bc_d
# s_c_da_b*s_cd : ((-q^2+1)*s_b*s_d+((q^2-1)/q)*s_a*s_c*s_abcd) + (((q^2-1)/q)*s_b*s_c)*s_cd + ((-q^4+1)/q)*s_d_a_b + (((q^2-1)/q^2)*s_c)*s_bcd + (((-q^2+1)/q)*s_c)*s_ab*s_acd + q^2*s_cd*s_c_da_b
# s_c_da_b*s_ab_cd : (((-q^4+2*q^2-1)/q^2)*s_b*s_c*s_abcd+((-q^6+q^4+q^2-1)/q^3)*s_a*s_d) + ((-q^2+1)*s_b*s_d+((q^2-1)/q^3)*s_a*s_c*s_abcd)*s_ab + ((-q^3+q)*s_b*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_c)*s_cd + ((-q^8+2*q^4-1)/q^4)*s_ad + (((-q^6+q^4+q^2-1)/q^3)*s_b*s_c)*s_ab_cd + (((-q^6+q^4+q^2-1)/q^3)*s_c)*s_acd + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_abd + ((-q^4+1)/q^3)*s_ab*s_d_a_b + (((q^2-1)/q^4)*s_c)*s_ab*s_bcd + ((q^4-1)/q)*s_cd*s_c_d_a + ((-q^4+q^2)*s_b)*s_cd*s_abc + s_ab_cd*s_c_da_b + (((-q^2+1)/q^3)*s_c)*s_ab^2*s_acd + ((q^3-q)*s_b)*s_cd^2*s_abd
# s_a_bc_d*s_ab_cd : (((-q^6+q^4+q^2-1)/q^3)*s_b*s_c+((-q^4+2*q^2-1)/q^2)*s_a*s_d*s_abcd) + ((-q^3+q)*s_b*s_d*s_abcd+((q^2-1)/q^2)*s_a*s_c)*s_ab + ((-q^8+2*q^4-1)/q^4)*s_bc + ((-q^2+1)*s_b*s_d+((q^2-1)/q^3)*s_a*s_c*s_abcd)*s_cd + (((-q^6+q^4+q^2-1)/q^3)*s_a*s_d)*s_ab_cd + (((-q^6+q^4+q^2-1)/q^3)*s_a)*s_abc + (((-q^6+q^4+q^2-1)/q^3)*s_d)*s_bcd + ((q^4-1)/q)*s_ab*s_a_b_c + ((-q^4+q^2)*s_d)*s_ab*s_acd + ((-q^4+1)/q^3)*s_cd*s_b_c_d + (((q^2-1)/q^4)*s_a)*s_cd*s_abd + s_ab_cd*s_a_bc_d + ((q^3-q)*s_d)*s_ab^2*s_bcd + (((-q^2+1)/q^3)*s_a)*s_cd^2*s_abc
# s_b_cd_a*s_bc_ad : (((-q^6+q^4+q^2-1)/q^3)*s_c*s_d+((-q^4+2*q^2-1)/q^2)*s_a*s_b*s_abcd) + (((q^2-1)/q^2)*s_b*s_d+(-q^3+q)*s_a*s_c*s_abcd)*s_bc + ((-q^8+2*q^4-1)/q^4)*s_cd + (((q^2-1)/q^3)*s_b*s_d*s_abcd+(-q^2+1)*s_a*s_c)*s_ad + (((-q^6+q^4+q^2-1)/q^3)*s_a*s_b)*s_bc_ad + (((-q^6+q^4+q^2-1)/q^3)*s_b)*s_bcd + (((-q^6+q^4+q^2-1)/q^3)*s_a)*s_acd + ((q^4-1)/q)*s_bc*s_b_c_d + ((-q^4+q^2)*s_a)*s_bc*s_abd + ((-q^4+1)/q^3)*s_ad*s_c_d_a + (((q^2-1)/q^4)*s_b)*s_ad*s_abc + s_bc_ad*s_b_cd_a + ((q^3-q)*s_a)*s_bc^2*s_acd + (((-q^2+1)/q^3)*s_b)*s_ad^2*s_bcd
# s_ac*s_bd : (((q^2+1)/q)*s_abcd+s_a*s_b*s_c*s_d) + 1/q*s_c*s_d*s_ab + q*s_a*s_d*s_bc + 1/q*s_a*s_b*s_cd + q*s_b*s_c*s_ad + 1/q^2*s_ab_cd + q^2*s_bc_ad + s_d*s_abc + s_a*s_bcd + s_b*s_acd + s_c*s_abd
# s_d_ab_c*s_bc_ad : (((-q^4+2*q^2-1)/q^2)*s_c*s_d*s_abcd+((-q^6+q^4+q^2-1)/q^3)*s_a*s_b) + ((-q^8+2*q^4-1)/q^4)*s_ab + (((q^2-1)/q^3)*s_b*s_d*s_abcd+(-q^2+1)*s_a*s_c)*s_bc + (((q^2-1)/q^2)*s_b*s_d+(-q^3+q)*s_a*s_c*s_abcd)*s_ad + (((-q^6+q^4+q^2-1)/q^3)*s_c*s_d)*s_bc_ad + (((-q^6+q^4+q^2-1)/q^3)*s_c)*s_abc + (((-q^6+q^4+q^2-1)/q^3)*s_d)*s_abd + ((-q^4+1)/q^3)*s_bc*s_a_b_c + (((q^2-1)/q^4)*s_d)*s_bc*s_acd + ((q^4-1)/q)*s_ad*s_d_a_b + ((-q^4+q^2)*s_c)*s_ad*s_bcd + s_bc_ad*s_d_ab_c + (((-q^2+1)/q^3)*s_d)*s_bc^2*s_abd + ((q^3-q)*s_c)*s_ad^2*s_abc
# s_bd*s_ac : (((q^2+1)/q)*s_abcd+s_a*s_b*s_c*s_d) + q*s_c*s_d*s_ab + 1/q*s_a*s_d*s_bc + q*s_a*s_b*s_cd + 1/q*s_b*s_c*s_ad + q^2*s_ab_cd + 1/q^2*s_bc_ad + s_d*s_abc + s_a*s_bcd + s_b*s_acd + s_c*s_abd
# s_ac*s_abd : (((-q^4+q^2-1)/q^2)*s_a*s_abcd) + ((-q^2)*s_d)*s_bc + ((-1/q^2)*s_b)*s_cd + s_c*s_d_a_b + ((-q^6-1)/q^3)*s_bcd + 1/q^2*s_ab*s_acd + q^2*s_ad*s_abc
# s_bd*s_acd : (((-q^4+q^2-1)/q^2)*s_d*s_abcd) + ((-q^2)*s_c)*s_ab + ((-1/q^2)*s_a)*s_bc + s_b*s_c_d_a + ((-q^6-1)/q^3)*s_abc + q^2*s_cd*s_abd + 1/q^2*s_ad*s_bcd
# s_bd*s_abc : (((-q^4+q^2-1)/q^2)*s_b*s_abcd) + ((-q^2)*s_a)*s_cd + ((-1/q^2)*s_c)*s_ad + s_d*s_a_b_c + ((-q^6-1)/q^3)*s_acd + q^2*s_ab*s_bcd + 1/q^2*s_bc*s_abd
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/sage/sage/local/lib/python3.7/concurrent/futures/process.py", line 232, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "<ipython-input-9-1afeb264e994>", line 63, in reduce_rel
#     return a, reduce(b, self)
#   File "<ipython-input-12-45589c535b1f>", line 3, in reduce
#     for i, res in enumerate(multi_rep(expr, rels)):
#   File "<ipython-input-11-a4e1d119d2d4>", line 8, in multi_rep
#     yield from multi_rep(expr, rels)
#   File "<ipython-input-11-a4e1d119d2d4>", line 8, in multi_rep
#     yield from multi_rep(expr, rels)
#   File "<ipython-input-11-a4e1d119d2d4>", line 8, in multi_rep
#     yield from multi_rep(expr, rels)
#   [Previous line repeated 62 more times]
#   File "<ipython-input-11-a4e1d119d2d4>", line 4, in multi_rep
#     expr1 = rels.replace(expr)
#   File "<ipython-input-9-1afeb264e994>", line 28, in replace
#     return eval(expr_s2)
#   File "<string>", line 1, in <module>
#   File "sage/structure/element.pyx", line 1517, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:12034)
#     return coercion_model.bin_op(left, right, mul)
#   File "sage/structure/coerce.pyx", line 1201, in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:10057)
#     return (<Action>action)._act_(x, y)
#   File "sage/structure/coerce_actions.pyx", line 599, in sage.structure.coerce_actions.LeftModuleAction._act_ (build/cythonized/sage/structure/coerce_actions.c:8314)
#     return (<ModuleElement>a)._rmul_(<Element>g)  # g * a
#   File "sage/modules/with_basis/indexed_element.pyx", line 839, in sage.modules.with_basis.indexed_element.IndexedFreeModuleElement._rmul_ (build/cythonized/sage/modules/with_basis/indexed_element.c:8635)
#     return self._acted_upon_(left, False)
#   File "sage/modules/with_basis/indexed_element.pyx", line 744, in sage.modules.with_basis.indexed_element.IndexedFreeModuleElement._acted_upon_ (build/cythonized/sage/modules/with_basis/indexed_element.c:8013)
#     cpdef _acted_upon_(self, scalar, bint self_on_left):
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/algebras/free_algebra_element.py", line 228, in _acted_upon_
#     return super(FreeAlgebraElement, self)._acted_upon_(scalar, self_on_left)
#   File "sage/modules/with_basis/indexed_element.pyx", line 744, in sage.modules.with_basis.indexed_element.IndexedFreeModuleElement._acted_upon_ (build/cythonized/sage/modules/with_basis/indexed_element.c:8404)
#     cpdef _acted_upon_(self, scalar, bint self_on_left):
#   File "sage/modules/with_basis/indexed_element.pyx", line 814, in sage.modules.with_basis.indexed_element.IndexedFreeModuleElement._acted_upon_ (build/cythonized/sage/modules/with_basis/indexed_element.c:8256)
#     scal(scalar, self._monomial_coefficients,
#   File "sage/data_structures/blas_dict.pyx", line 243, in sage.data_structures.blas_dict.scal (build/cythonized/sage/data_structures/blas_dict.c:2373)
#     return axpy(a, D, {}, factor_on_left=factor_on_left)
#   File "sage/data_structures/blas_dict.pyx", line 203, in sage.data_structures.blas_dict.axpy (build/cythonized/sage/data_structures/blas_dict.c:2032)
#     iaxpy(a, X, Y, True, factor_on_left)
#   File "sage/data_structures/blas_dict.pyx", line 112, in sage.data_structures.blas_dict.iaxpy (build/cythonized/sage/data_structures/blas_dict.c:1373)
#     elif a == -1:
#   File "/home/sage/sage/local/lib/python3.7/site-packages/sage/rings/polynomial/multi_polynomial_element.py", line 1512, in __eq__
#     return CommutativeRingElement.__eq__(self, right)
#   File "sage/structure/element.pyx", line 1091, in sage.structure.element.Element.__richcmp__ (build/cythonized/sage/structure/element.c:9969)
#     return coercion_model.richcmp(self, other, op)
#   File "sage/structure/coerce.pyx", line 1980, in sage.structure.coerce.CoercionModel.richcmp (build/cythonized/sage/structure/coerce.c:19869)
#     x, y = self.canonical_coercion(x, y)
#   File "sage/structure/coerce.pyx", line 1322, in sage.structure.coerce.CoercionModel.canonical_coercion (build/cythonized/sage/structure/coerce.c:11635)
#     y_elt = (<Map>y_map)._call_(y)
#   File "sage/categories/map.pyx", line 1694, in sage.categories.map.FormalCompositeMap._call_ (build/cythonized/sage/categories/map.c:11607)
#     x = f._call_(x)
#   File "sage/structure/coerce_maps.pyx", line 402, in sage.structure.coerce_maps.CallableConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:7695)
#     cpdef Element _call_(self, x):
#   File "sage/structure/coerce_maps.pyx", line 430, in sage.structure.coerce_maps.CallableConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:7349)
#     y = self._func(C, x)
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "sage/rings/fraction_field_element.pyx", line 121, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:3073)
#     self.reduce()
#   File "sage/rings/fraction_field_element.pyx", line 1190, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.reduce (build/cythonized/sage/rings/fraction_field_element.c:12485)
#     self.normalize_leading_coefficients()
#   File "sage/rings/fraction_field_element.pyx", line 1127, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.normalize_leading_coefficients (build/cythonized/sage/rings/fraction_field_element.c:11873)
#     self.__denominator = self.__denominator.monic()
#   File "sage/rings/polynomial/polynomial_element.pyx", line 5595, in sage.rings.polynomial.polynomial_element.Polynomial.monic (build/cythonized/sage/rings/polynomial/polynomial_element.c:45260)
#     if self.is_monic():
#   File "sage/rings/polynomial/polynomial_element.pyx", line 5368, in sage.rings.polynomial.polynomial_element.Polynomial.is_monic (build/cythonized/sage/rings/polynomial/polynomial_element.c:43909)
#     return not self.is_zero() and self[self.degree()] == 1
#   File "sage/structure/element.pyx", line 1091, in sage.structure.element.Element.__richcmp__ (build/cythonized/sage/structure/element.c:9969)
#     return coercion_model.richcmp(self, other, op)
#   File "sage/structure/coerce.pyx", line 1980, in sage.structure.coerce.CoercionModel.richcmp (build/cythonized/sage/structure/coerce.c:19869)
#     x, y = self.canonical_coercion(x, y)
#   File "sage/structure/coerce.pyx", line 1322, in sage.structure.coerce.CoercionModel.canonical_coercion (build/cythonized/sage/structure/coerce.c:11635)
#     y_elt = (<Map>y_map)._call_(y)
#   File "sage/categories/map.pyx", line 1694, in sage.categories.map.FormalCompositeMap._call_ (build/cythonized/sage/categories/map.c:11607)
#     x = f._call_(x)
#   File "sage/structure/coerce_maps.pyx", line 402, in sage.structure.coerce_maps.CallableConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:7695)
#     cpdef Element _call_(self, x):
#   File "sage/structure/coerce_maps.pyx", line 430, in sage.structure.coerce_maps.CallableConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:7349)
#     y = self._func(C, x)
#   File "sage/rings/fraction_field_element.pyx", line 1117, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.__init__ (build/cythonized/sage/rings/fraction_field_element.c:11744)
#     FractionFieldElement.__init__(self, parent, numerator, denominator,
#   File "sage/rings/fraction_field_element.pyx", line 121, in sage.rings.fraction_field_element.FractionFieldElement.__init__ (build/cythonized/sage/rings/fraction_field_element.c:3073)
#     self.reduce()
#   File "sage/rings/fraction_field_element.pyx", line 1189, in sage.rings.fraction_field_element.FractionFieldElement_1poly_field.reduce (build/cythonized/sage/rings/fraction_field_element.c:12473)
#     super(self.__class__, self).reduce()
#   File "sage/rings/fraction_field_element.pyx", line 164, in sage.rings.fraction_field_element.FractionFieldElement.reduce (build/cythonized/sage/rings/fraction_field_element.c:4076)
#     cpdef reduce(self):
#   File "sage/rings/fraction_field_element.pyx", line 188, in sage.rings.fraction_field_element.FractionFieldElement.reduce (build/cythonized/sage/rings/fraction_field_element.c:3600)
#     g = self.__numerator.gcd(self.__denominator)
#   File "sage/structure/element.pyx", line 4300, in sage.structure.element.coerce_binop.new_method (build/cythonized/sage/structure/element.c:26883)
#     return method(self, other, *args, **kwargs)
#   File "sage/rings/polynomial/polynomial_rational_flint.pyx", line 939, in sage.rings.polynomial.polynomial_rational_flint.Polynomial_rational_flint.gcd (build/cythonized/sage/rings/polynomial/polynomial_rational_flint.cpp:10325)
#     sig_str("FLINT exception")
# KeyboardInterrupt
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-04afc0697c25> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'pool = ProcessPoolExecutor(8)\nreduced_commutator_rw = commutator_rw.reduce_all()')
#
# /home/sage/sage/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </home/sage/sage/local/lib/python3.7/site-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /home/sage/sage/local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/sage/sage/local/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-9-1afeb264e994> in reduce_all(self)
#      43         reduced_bs = (pool.submit(self.reduce_rel, a, b) for a,b in self.rels.items())
#      44         for fut in futures.as_completed(reduced_bs):
# ---> 45             a, b = fut.result()
#      46             print(f"{a} : {b}")
#      47             rw.update({a:b})
#
# /home/sage/sage/local/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# /home/sage/sage/local/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# KeyboardInterrupt:

# %% [markdown]
# #### Generate  other Higher Relations

# %% [markdown]
# Autogenerate relations from the relations which are not commutativity and commutator relations.

# %%
def m_term_to_reduce(expr):
    """Select most important monomial containing an m_term from expr."""
    mmlst = []
    lst = []
    for i in expr.monomials():
        m_count = len(set(terms_of_product(i)).intersection(set(m_terms)))
        if m_count > 0:
            #add to lst if monomial contains an m_term
            lst.append((m_count, i))
            #return monomial with most m_terms and if joint largest monomial
    return (sorted(lst).pop())[1]

# %%
m_term_to_reduce(s_ab*s_ab_cd + s_b_c_d)

# %%
def generate_higher_from_rel(k, relations_system=basic_rw, rel_queue=None):
    """Given a key k=ab generate all relations which are required to resolve the ambiguity (ma)b = m(ab)."""
    print(f"generating relations from {k}")
    rel_set = []
    while rel_queue is not None and not rel_queue.empty():
        rel_set.append(rel_queue.get())
    rel_set = set(rel_set)
    gen_rels = {}
    a,b = terms_of_product(k)
    rel = relations_system[k]
    for m in A.gens():
        if m*a in m_relations:
            print(m*a*b)
            m1 = m_term_to_reduce(m_relations[m*a])
            term = m1*b
            if (not term in gen_rels and not term in rel_set and len(terms_of_product(term))==2):
                print(term)
                l = m_relations[m*a]*b
                r = reduce(m*rel, reduced_commutator_rw)
                new_rel = make_subject(l,r, term)
                print(new_rel)
                gen_rels.update(new_rel)
    return {k: x for k, x in gen_rels.items() if len(terms_of_product(k)) == 2}

# %%
import multiprocessing as mp

def rel_queue(rels):
    """Add relations to queue."""
    q = mp.Manager().Queue()
    for rel in rels:
        q.put(rel)
    return q

def generate_higher_rels(rel_system=basic_m_rels, original_rels={}):
    """Apply generate_higher_from_rel(k) for all relevant k=ab."""
    system = {**original_rels, **rel_system}
    queues = {k: rel_queue(original_rels) for k in rel_system.keys()}
    with ProcessPoolExecutor(8) as pool:
        future_to_key = {pool.submit(generate_higher_from_rel, k, system, queues[k]): k
            for k in rel_system.keys()}
        rels = {**original_rels}
        for higher in futures.as_completed(future_to_key):
            print(f"finished generating relations from {future_to_key[higher]}")
            try:
                rels.update(higher.result())
            except:
                raise 
            del queues[future_to_key[higher]]
            for q in queues.values():
                for k in higher.result():
                    q.put(k)
    return rels

# %%
higher_relations = generate_higher_rels(simple_relations, {})

# %%
len(higher_relations)

# %%
all_relations = {**reduced_commutator_rw.rels, **higher_relations}
all_rw_system = RewritingSystem(all_relations)

# %%
len(all_relations)

# %%
# %%time
pool = ProcessPoolExecutor(8)
reduced_rw = all_rw_system.reduce_all()

# %%
#minimal_m_rels = { k:m_relations[k] for k in filter(lambda k: is_ordered(k) and is_s_term_ordered(k), m_relations.keys()) }
#s_bc*s_ab_cd in minimal_m_rels

# %%
extra = generate_higher_rels(m_relations, reduced_rw.rels)

# %%
with_extra = {**extra, **reduced_rw.rels}

# %%
len(with_extra)

# %%
[b*a for a, b in combinations(A.gens(), 2) if not b*a in with_extra]

# %%
[a*b for a, b in combinations(A.gens(), 2) if not a*b in with_extra]

# %%
len([a*b for a, b in combinations(A.gens(), 2) if not a*b in with_extra])

# %%
extra_rw = RewritingSystem(with_extra)

# %%
# %%time
pool = ProcessPoolExecutor(8)
reduced_rw = extra_rw.reduce_all()

# %% [markdown]
# ### Reducable Check

# %% [markdown]
# In this section we check that we have generated all the rewriting rules that we expected to generate.

# %%
def loop_group(a):
    """Returns the type of loop."""
    point_lst = loop_point_groups(a)
    if len(point_lst) == 1:
        if len(point_lst[0]) == 3:
            return 'triple'
        if point_lst[0] in ['ac', 'bd']:
            return 'cross'
        else:
            return 'double'
    if len(point_lst) == 2:
            return 'commutative'
    if len(point_lst) == 3:
        if len(point_lst[1]) == 1:
            return '1miss'
        if len(point_lst[1]) == 2:
            return '2miss'
    return

# %%
def loop_group_number(a):
    """Returns group number of loop."""
    group = {'double': 1, '1miss': 2, 'commutative': 2, '2miss': 3, 'cross': 4, 'triple':5}
    return group[loop_group(a)]

# %%
def reducable(mon):
    """Tests if mon should be reducable."""
    #assumes mon = a*b
    a,b = terms_of_product(mon)
    if a > b:
        return True
    if loop_group(a) == loop_group(b):
        return True
    a_terms = terms_of_product(s_term_prod(a))
    b_terms = terms_of_product(s_term_prod(b))
    if set(a_terms).issubset(set(b_terms)):
        return False
    if loop_group(b) == 'triple':
        rest = [s for s in a_terms if not letters(s).issubset(letters(b))]
        if len(rest) == 0:
            return False
        if len(rest) == 1 and rest[0] in [s_ab, s_bc, s_cd, s_ad]:
            return False
    if loop_group(b) == 'cross' and (loop_group(a) == 'double' or loop_group(a) == 'commutative'):
        return False
    if loop_group(b) == 'cross' and len(loop_point_groups(a)) == 3 and set(loop_point_groups(a)[1]).issubset(letters(b)):
        return False
    else:
        return True

# %% [markdown]
# Check that all $ab$ which should be reducable have an associated rewriting rule.

# %%
[a*b for a, b in combinations(A.gens(), 2) if not a*b in with_extra and reducable(a*b)]

# %% [markdown]
# Check that all reduced $ab$ do not have an associated rewriting rule.

# %%
[a*b for a, b in combinations(A.gens(), 2) if a*b in with_extra and not reducable(a*b)]

# %% [markdown]
# # Checking Ambiguities

# %% [markdown]
# We now test all the ambiguities for the term rewriting system `reduced_rw`. To make it easier to deal with errors this is done in stages but there is a function `all_tests()` which will run all the tests at once.

# %%
def _amb_check1(t):
    i,j,k = t
    return t, check_amb(i,j,k, reduced_rw, 100)

# %%
def three_puncture_test1():
    """Tests all the ambiguities for the term rewriting system of the subalgebra containing only three points a,b,c."""
    gen = [s_ab, s_bc, s_ac, s_a_b_c, s_abc]
    
    futs = (pool.submit(_amb_check1, arg) for arg in permutations(gen, int(3)))
    for counter, fut in enumerate(futures.as_completed(futs), 1):
        args, res = fut.result()
        print(args)
        print(res)
        print(counter)
    return "end"

# %%
def three_puncture_gen_triples():
    lst_abc = [s_ab, s_bc, s_ac, s_a_b_c, s_abc]
    lst_abd = [s_ab, s_bd, s_ad, s_d_a_b, s_abd]
    lst_acd = [s_ac, s_cd, s_ad, s_c_d_a, s_acd]
    lst_bcd = [s_bc, s_cd, s_bd, s_b_c_d, s_bcd]
    return flatten([list(permutations(gen, int(3))) for  gen in [lst_abc, lst_abd, lst_acd, lst_bcd]], list)

def all_three_puncture_tests():
    """Tests all the ambiguities for each of the four subalgebras containing only three points."""
    choices = three_puncture_gen_triples()
    
    futs = (pool.submit(_amb_check1, arg) for arg in choices)
    for counter, fut in enumerate(futures.as_completed(futs), 1):
        args, res = fut.result()
        print(args)
        print(res)
        print(counter)
    return "end"

# %%
# %%time
#480 tests in total
pool = ProcessPoolExecutor(8)
all_three_puncture_tests()

# %%
#This is unnecessary as all these tests are convered in the next test.
def doubles_and_triples_tests():
    """Tests all ambiguities only involving simple generators."""
    choices = permutations(simple_terms, int(3))
    
    futs = {pool.submit(_amb_check1, arg): arg for arg in choices}
    failed_tests = []
    for counter, fut in enumerate(futures.as_completed(futs.keys()), 1):
        try:
            args, res = fut.result()
        except:
            print(f"error for arg {futs[fut]}")
        print(args)
        print(res)
        print(counter)
        if not isinstance(res, str):
            failed_tests.append(args)
        if len(failed_tests)>50:
            print(failed_tests)
            return "max failed tests exceeded"
    return "end"

# %%
#%%time
#pool = ProcessPoolExecutor(8)
#doubles_and_triples_tests()

# %%
non_central = [s for s in A.gens() if 1<len(letters(s))<4]

def all_other_tests():
    """Test all ambiguities which are not covered by all_three_puncture_tests()."""
    already_counted = three_puncture_gen_triples()
    choices = filter(lambda x: not x in already_counted, permutations(non_central, int(3)))
    
    futs = (pool.submit(_amb_check1, arg) for arg in choices)
    failed_tests = []
    for counter, fut in enumerate(futures.as_completed(futs), 1):
        try:
            args, res = fut.result()
        except:
            print(f"error for arg {futs[fut]}")
        print(args)
        print(res)
        print(counter)
        if not isinstance(res, str):
            failed_tests.append(args)
        if len(failed_tests)>50:
            print(failed_tests)
            return "max failed tests exceeded"
    return "end"

# %%
# %%time
pool = ProcessPoolExecutor(8)
all_other_tests()

# %%
def run_failed_tests():
    futs = (pool.submit(_amb_check1, arg) for arg in failed_test_pool)
    failed = 0
    passed = 0
    for counter, fut in enumerate(futures.as_completed(futs), 1):
        args, res = fut.result()
        print(args)
        print(res)
        print(counter)
        if not isinstance(res, str):
            failed = failed + 1
        else:
            passed = passed + 1
    print(f"Failed {failed} test and passed {passed} test out of a total of {len(failed_test_pool)} tests")
    return

# %%
#%%time
#pool = ProcessPoolExecutor(8)
#run_failed_tests()

# %%
def all_tests():
    """Test all ambiguities in one go."""
    choices = permutations(non_central, int(3))
    
    futs = (pool.submit(_amb_check1, arg) for arg in choices)
    failed_tests = []
    for counter, fut in enumerate(futures.as_completed(futs), 1):
        try:
            args, res = fut.result()
        except:
            print(f"error for arg {futs[fut]}")
        print(args)
        print(res)
        print(counter)
        if not isinstance(res, str):
            failed_tests.append(args)
        if len(failed_tests)>50:
            print(failed_tests)
            return "max failed tests exceeded"
    return "end"

# %%
#%%time
#pool = ProcessPoolExecutor(8)
#all_tests()

# %% [markdown]
# # Other Checking Code
#
# Below is all the code which does not relate to checking the the term rewriting system is unambiguous but other things which need to be checked e.g. termination.

# %% [markdown]
# ### Partial Ordering
# We construct a partial order and check that the partial order is compatible with the term rewriting system we have constructed. This partial order is `lt_combined` which is constructed by chaining three partial orders `le_inversion`, `le_total` and `le_nearness`.

# %%
def degree(expr):
    """Find the degree of expr assuming each variable is of degree 1."""
    return max([ len(terms_of_product(expr)) for expr in expr.monomials()])

def inversion_number(mon):
    """Count the number of pairwise terms in the monomial mon which are in the incorrect order."""
    terms = terms_of_product(to_gen_str(mon))
    return sum([1 for i,j in combinations([0..len(terms)-1], 2) if terms[i] > terms[j]])

def degree_n_inversion(expr, n):
    """Count the number of inversions of all monomials in expr of length n."""
    return sum([inversion_number(w) for w in expr.monomials() if len(terms_of_product(w)) == n ])

def safe_max(ls):
    """Safe maximum function which returns 0 if the list in empty."""
    if len(ls):
        return max(ls)
    return 0

def max_nonzero(ls):
    """Return index of last nonzero element of lst."""
    return safe_max([i for i, x in enumerate(ls) if x != 0])

# %%
def le_inversion(expr1, expr2):
    """Returns if expr1 is less than or equal to expr2 according to the reduced degree ordering."""
    inv_degree_1 = max_nonzero([degree_n_inversion(expr1, n) for n in [0..degree(expr1)]])
    inv_degree_2 = max_nonzero([degree_n_inversion(expr2, n) for n in [0..degree(expr2)]])
    if inv_degree_1 < inv_degree_2:
        return True
    if (inv_degree_1 == inv_degree_2 
        and degree_n_inversion(expr1, inv_degree_1) <= degree_n_inversion(expr2, inv_degree_2)):
        return True
    return False

# %%
def lt_inversion(expr1, expr2):
    """Returns if expr1 is strictly less than expr2 according to the reduced degree ordering."""
    if le_inversion(expr1, expr2):
        return not [degree_n_inversion(expr1, n) for n in [0..degree(expr1)]] == [degree_n_inversion(expr2, n) for n in [0..degree(expr2)]]
    return False

# %%
def generator_degree(s):
    """Finds the degree of generator s which is used in the grading."""
    if s == 1:
        return 0
    degrees = {'double': 2, 'cross': 2, 'triple': 3, '1miss': 4, 'commutative': 4, '2miss': 6}
    return degrees[loop_group(s)]

def monomial_degree(m):
    """Finds the graded degree of the monomial mon."""
    return sum([generator_degree(m) for m in terms_of_product(to_gen_str(m))])

def total_degree(expr):
    """Finds the graded degree of expr."""
    return max([monomial_degree(m) for m in expr.monomials()])

def highest_degree(expr):
    """Return a list of monomials of maximal degree."""
    N = total_degree(expr)
    return [m for m in expr.monomials() if total_degree(m) == N]

# %%
def lt_total(expr1, expr2):
    """Returns if expr1 is strictly less than expr2 according to the total degree ordering."""
    if total_degree(expr1) < total_degree(expr2):
        return True
    if (total_degree(expr1) == total_degree(expr2) 
        and all([m1 > m2 for m1 in expr1.monomials() for m2 in expr2.monomials()])):
        return True
    return False

def le_total(expr1, expr2):
    """Returns if expr1 is less than or equal to expr2 according to the total degree ordering."""
    return True if lt_total(expr1, expr2) or total_degree(expr1)==total_degree(expr2) else False

# %%
def number_distinct(expr):
    """Finds the maximal number of distint loops in the maximal degree terms of expr."""
    n = total_degree(expr)
    return max([len(terms_of_product(x)) for x in expr.monomials() if total_degree(x) == n])

def group_distance(x, y):
    """Finds the distance between loops x and y where distance is defined depending on the group of the loop."""
    return abs(loop_group_number(loop_group(x)) - loop_group_number(loop_group(y)))

def nearness_mon(mon):
    """Returns a measure of the pairwise nearness of the loops in the monomial mon."""
    return sum([group_distance(x, y) for x,y in combinations(terms_of_product(mon),2)])

def nearness(expr):
    """Returns a measure of the pairwise nearness of the loops in expr."""
    deg = total_degree(expr)
    return sum([nearness_mon(m) for m in expr.monomials() if total_degree(m) == deg])

# %%
def lt_nearness(expr1, expr2):
    """Returns if expr1 is strictly less than expr2 according to the group distance measure."""
    deg1, deg2 = (total_degree(expr1), total_degree(expr2))
    if deg1 != deg2:
        return deg1 < deg2
    if number_distinct(expr1) != number_distinct(expr2):
        return number_distinct(expr1) < number_distinct(expr2)
    print(nearness(expr1), nearness(expr2))
    return nearness(expr1) > nearness(expr2)

# %%
def lt_combined(expr1, expr2):
    """Returns if expr1 is strictly less than expr2 according to the combined partial order."""
    if (lt_inversion(expr1, expr2) 
        or (le_inversion(expr1, expr2) and lt_total(expr1, expr2)) 
        or (le_inversion(expr1, expr2) and le_total(expr1, expr2) and lt_nearness(expr1, expr2))):
        return True
    else:
        return False

# %% [markdown]
# Test term rewriting system is compatible with partial order

# %%
def test_order_compatibility(rws=reduced_rw, order=lt_combined):
    """Test if the rewriting system rws is compatible with the partial ordering order."""
    return len([k for k in rws if not order(rws[k], k)]) == 0

# %% [markdown]
# Code Tests

# %%
degree(s_a*s_b + s_ab*s_bc + s_abc) == 2

# %%
inversion_number(s_ab*s_abc) == 0

# %%
inversion_number(s_abc*s_ab) == 1

# %%
inversion_number(s_bc^2*s_bd) == 0

# %%
max_nonzero([]) == 0

# %%
max_nonzero([0,1,1]) == 2

# %%
max_nonzero([0, 0]) == 0

# %%
le_inversion(s_bc*s_ab, s_cd) == False

# %%
le_inversion(s_ab*s_bc, s_cd) == True

# %%
le_inversion(s_a_b_c*s_ab, s_ab*s_a_b_c) == False

# %%
monomial_degree(s_ab*s_abc) == 5

# %%
total_degree(s_ab*s_abc + s_bc*s_a_bc_d) == 8

# %% [markdown]
# ### Form of Reduced Monomials
# In this section we check that the reduced monomials are of the expected type.

# %%
def is_reduced(expr):
    """Test if expr is reduced."""
    return reduced_rw.replace(expr) == expr

# %%
def all_group_number(n):
    """Return a list of all loops of group number n."""
    return [x for x in A.gens() if loop_group_number(x) == n]

def is_subsetting(a, b):
    """Test if the loops in the monomial a are a subset of the loops in b."""
    return set(terms_of_product(s_term_prod(a))).issubset(set(terms_of_product(s_term_prod(b))))

# %%
def last_point(s):
    """Return the last letter which is a point of the loop s."""
    return loop_point_groups(s)[-1][-1]

def first_point(s):
    """Return the first letter which is a point of the loop s."""
    return loop_point_groups(s)[0][0]

def missing_points(s):
    """Return all of the points not in the loop s (excluding bar points)."""
    return "".join({'a','b','c','d'} - letters(s))

def is_consecutive(n,m):
    """Test if the points n and m are consecutive points if there are four points in a circle."""
    alph = 'abcd'
    return (alph.index(n) - alph.index(m)) % 4 == 1 or (alph.index(m) - alph.index(n)) % 4 == 1

def end_points(s):
    """Return the points of loop s which start and end it."""
    m = missing_points(s)
    if len(m) == 0:
        #When the loop contains all points the end points are just the first and last point
        return [first_point(s), last_point(s)]
    else:
        #Otherwise the end points are the points next to the missing points
        return [l for l in letters(s) if any([is_consecutive(l,n) for n in m])]

# %%
def standard_loop(s1, m,  s2):
    """Construct the loop which starts with point s1 goes around the points m and ends with the point s2."""
    #Note that s1 and s2 are assumed to be single points as this is the form of the generators
    if m == 'ad':
        m = 'da'
    else:
        m = ''.join(sorted(m))
    try: 
        loop = eval(f's_{s1}_{m}_{s2}')
    except:
        loop = eval(f's_{s2}_{m}_{s1}')
    return loop

def looping_terms(s):
    """Returns the list of the loop(s) which form a complete loop when multiplied by s."""
    m = missing_points(s)
    #note s 
    s1, s2 = end_points(s)
    if len(m) == 0:
        fl = "".join(sorted(s1+s2))
        return [eval(f"s_{fl}")]
    if loop_group(s) == 'cross':
        return [standard_loop(s1, n, s2) for n in m]
    return [standard_loop(s1, m, s2)]

def complete_loop(a,b):
    """Tests if a*b forms a loop."""
    return set(terms_of_product(s_term_prod(looping_terms(b)[0]))).issubset(set(terms_of_product(s_term_prod(a))))

# %%
#List of all reduced pairs
all_reduced_pairs = [(x,y) for x,y in permutations(A.gens(),int(2)) if is_reduced(x*y)]

#the generating loops split into groups
groups = [all_group_number(n) for n in [1..5]]

# %%
#Test have all reodering relations
len([x*y for x,y in all_reduced_pairs if x>y]) == 0

# %%
#test have relations between all pairs of loops of the same group
all([not is_reduced(a*b) for x in groups for a,b in combinations( x, 2)])

# %%
#test have relaions between all group III and group IV loops
all([not is_reduced(a*b) for a in groups[2] for b in groups[3] ])

# %%
#test if group I, II and III are subsetting then they are reduced
all([is_reduced(a*b)
     for i,j in [(0, 1), (0,2), (1,2)] for a in groups[i] for b in groups[j] if is_subsetting(a,b)])

# %%
#test if group I, II and III are not subsetting then they are not reduced
all([not is_reduced(a*b)
     for i,j in [(0, 1), (0,2), (1,2)] for a in groups[i] for b in groups[j] if not is_subsetting(a,b)])

# %%
# all groups I,II, III loops which do not complete the loop are reduced
all([is_reduced(a*b) for a in flatten([groups[0], groups[1], groups[2]]) for b in groups[4] if not complete_loop(a,b) ])

# %%
# all groups I,II, III loops which complete the loop are not reduced
all([not is_reduced(a*b) for a in flatten([groups[0], groups[1], groups[2]]) for b in groups[4] if complete_loop(a,b) ])

# %%
# if the type IV loop is a subset of the type V loop then it is reduced
all([is_reduced(a*b) for a in groups[3] for b in groups[4] if letters(a).issubset(letters(b))])

# %%
# if the type IV loop is not a subset of the type V loop then it is not reduced
all([not is_reduced(a*b) for a in groups[3] for b in groups[4] if not letters(a).issubset(letters(b))])

# %% [markdown]
# Code Tests

# %%
last_point(s_d_a_b) == 'b'

# %%
last_point(s_acd) == 'd'

# %%
first_point(s_d_a_b) == 'd'

# %%
missing_points(s_ab) == 'dc'

# %%
is_consecutive('d','b') == False

# %%
is_consecutive('a','d') == True

# %%
end_points(s_d_ab_c)

# %%
end_points(s_abc)

# %%
standard_loop('b', 'dc', 'a') == s_b_cd_a

# %%
standard_loop('a', 'dc', 'b') == s_b_cd_a

# %%
looping_terms(s_a_bc_d) == s_ad

# %%
looping_terms(s_a_b_c) == s_cd*s_ad

# %% [markdown]
# ## Hilbert Series

# %% [markdown]
# We now check that the Hilbert series of the Skein algebra `hilbert_series_skein` when n=4 agrees with the Hilbert series `new_hilbert` of the algebra whose presentation we have constructed.

# %%
var('t')
var('m')
var('n')

# %%
 the new Hilbert sdef binomial_replace(n, m):
    """Number of choices of m from n with replacement."""
    return binomial(n+m-1, m)

def hilbert_series_skein(n):
    """The Hilbert series of the skein algebra for n+1 punctures"""
    return (1+t)^n/(1-t)^n*(hypergeometric([n,n],[1], t^2) - n*t*hypergeometric([n,n+1],[2], t^2))

# %%
#Parts of the new Hilbert series
central_hilb = 1/((1-t^4)*(1-t)^4)
III_term = (1-t^8)/(1-t^2)^4
III_V_term = t^3/(1-t^3)*(1-t^4)/(1-t^2)^4
IV_term = t^2/(1-t^2)*( 1 + 2*t^3/(1-t^3) )*( 1 + 4*t^2/(1-t^2) + 4*t^4/(1-t^2)^2)

#Combined together
new_hilbert = central_hilb*(III_term + 4*III_V_term + 2*IV_term)

# %%
# Test the Hilbert series match
((hilbert_series_skein(4).simplify_hypergeometric()) - new_hilbert).full_simplify()

# %% [markdown]
# ### Relations Reduce

# %% [markdown]
# Finally, we check that the we can eliminate the extra generators and when we do so we only have the expected relations.

# %% [markdown]
# The free algebra used so far is A which is an algebra over P. We define a new free algebra B with only the reduced generators which is an algebra over R.

# %%
R.<r_a,r_b,r_c, r_d, r_abcd> = PolynomialRing(F,5,order='neglex')

# %%
variablesB = ('r_ab, r_bc, r_cd, r_ad, '
             'r_ac, r_bd, r_abc, r_bcd, r_acd, r_abd').split(', ')
B = FreeAlgebra(R, order='neglex', names=variablesB)
for k, v in zip(variablesB, B._first_ngens(len(variablesB))):
    locals()[k] = v

# %%
def reverse_m_rels():
    """Reverses the m_rels to give relations which can eliminate the extra generators."""
    rels = [make_subject(k, r, m_term_to_reduce(r)) for  k,r in m_relations.items() if is_ordered(k)]
    rels + [{s_ab_cd: s_ab*s_cd}, {s_bc_ad: s_bc*s_ad}]
    return functools.reduce((lambda x, y: {**x, **y}), rels, {})

# %%
reverse = RewritingSystem(reverse_m_rels())

# %%
# %%time
pool = ProcessPoolExecutor(8)
reduced_reverse = reverse.reduce_all_seq()

# %%
ordered_reduced_reverse = RewritingSystem({k: reduce(reduced_reverse[k], RewritingSystem(reordering)) 
                                           for k in reduced_reverse})

# %%
def basis_mapping(expr):
    """Map the extended generators of A to expressions in B."""
    #eliminate extra generators using the rules in ordered_reduced_reverse
    expr = reduce(expr, ordered_reduced_reverse)
    #map the terms to elements of B
    return eval(re.sub('s','r', str(to_gen_str(expr))))

def relation_mapping(rels):
    """Convert a reduction rule for A to a reduction rule for B."""
    m_rel = {}
    #convert the expressions in rels to elements of B
    mapped = {basis_mapping(k): basis_mapping(rels[k]) for k in rels}
    #for each relation rearrange the relation so the key is a single monomial again
    for k in mapped: 
        d = max( [len(terms_of_product(x)) for x in k.monomials()])
        term = [x for x in k.monomials() if len(terms_of_product(x)) == d][0]
        print(make_subject(k, mapped[k], term))
        m_rel.update(make_subject(k, mapped[k], term))
    return m_rel

# %%
#The two cases are to prevent overcounting of triple or quadratic relations but reordering the key 
basic_rels = {k:r for k,r in relation_mapping(simple_relations).items() if (len(terms_of_product(k)) == 2 or is_ordered(k)) }

basic_commutators = relation_mapping({a*b: reduced_rw[a*b] for a,b in permutations(simple_terms, int(2)) 
                                      if a*b in reordering})

#TRWS containing all the relations which pertain to the reduced basis
base_rw = RewritingSystem({**basic_rels, **basic_commutators})

# %%
#Check correct number of relations
len(base_rw) == 65

# %%
# %%time
pool = ProcessPoolExecutor(8)
reduced_base = base_rw.reduce_all()#Construct a list of all the relations for A mapped to relations of B

# %% [markdown]
# Construct a list of all the relations for A mapped to relations of B

# %%
algebra_relations = []
for k in basic_m_rw:
    print(basis_mapping(k) - basis_mapping(basic_m_rw[k]))
    algebra_relations = algebra_relations + [basis_mapping(k) - basis_mapping(basic_m_rw[k])]

# %% [markdown]
# Test that all relations of A are satisfied in B

# %%
for eq in algebra_relations:
    to_solve = []
    red = reduce(eq, reduced_base)
    print(print(red))
    if red != 0:
        to_solve = to_solve + [red]

# %% [markdown]
# We must show that eq is 0 in B.
# The term $r_{ab} r_{bc} r_{cd} r_{ac}$ can be simplified by the relation $r_{ab} r_{bc} r_{cd} r_{ac}$ but the $s_{cd}$ term stops the TRWS automatically reducing it.

# %%
eq = ((((q^8-q^6+q^2-1)/q^4)*r_c*r_d+(-q^4+1)*r_b^2*r_c*r_d+((q^8-q^6+q^2-1)/q^3)*r_a*r_b*r_abcd
       +(q^4-q^2)*r_a^2*r_c*r_d) + ((q^6+q^4-q^2-1)*r_abcd+(q^5-q^3)*r_a*r_b*r_c*r_d)*r_ab 
      + (((-q^4+1)/q)*r_b*r_d)*r_bc + ((-2*q^8-2*q^6+q^4-1)/q^5+q^3*r_c^2+q*r_b^2+q^5*r_a^2)*r_cd 
      + (((q^2-1)/q^3)*r_a*r_c)*r_ad + ((q^4-q^2)*r_b*r_c*r_abcd+(q^5-q)*r_a*r_d)*r_ac 
      + (((-q^6+1)/q)*r_b*r_c)*r_bd + ((q^3-q)*r_c*r_abcd+(q^4-q^2)*r_a*r_b*r_d)*r_abc 
      + (((-q^6+q^4+q^2-1)/q^4)*r_b+(-q^4+q^2)*r_b*r_c^2)*r_bcd + (((q^10-q^6+q^4-1)/q^4)*r_a)*r_acd 
      + ((-q^2+1)*r_a*r_b*r_c)*r_abd + ((q^6-q^4)*r_c*r_d)*r_ab^2 + q^6*r_a*r_b*r_ab*r_cd 
      + ((q^4-1)*r_b*r_c)*r_ab*r_ad + ((q^4-q^2)*r_b*r_d)*r_ab*r_ac + ((q^5-q)*r_d)*r_ab*r_abc 
      + ((q^5-q)*r_b)*r_ab*r_acd + ((q^5-q^3)*r_c)*r_ab*r_abd + q^4*r_b*r_c*r_bc*r_cd + ((-q^8+1)/q^4)*r_bc*r_bd 
      + ((-q^3+q)*r_c)*r_bc*r_bcd + (((-q^4+1)/q^3)*r_a)*r_bc*r_abd + q^4*r_a*r_c*r_cd*r_ac 
      + q^3*r_a*r_b*r_c*r_cd*r_abc + ((q^5-q^3)*r_c)*r_ac*r_acd + q^7*r_ab^2*r_cd 
      + ((q^4-1)/q)*r_ab*r_bc*r_ad + q^4*r_c*r_ab*r_cd*r_abc + q^3*r_bc^2*r_cd + q^2*r_a*r_bc*r_cd*r_abc 
      + q^3*r_cd*r_ac^2 + q^2*r_b*r_cd*r_ac*r_abc + q*r_cd*r_abc^2 + (-q^4)*r_ab*r_bc*r_cd*r_ac)

# %% [markdown]
# Construct relation for $r_{ab}r_{bc}r_{cd}r_{ac}$

# %%
l = r_cd*reduce(r_ab*r_bc*r_ac, reduced_base)
r = reduce(reduce(r_cd*r_ab, reduced_base)*r_bc*r_ac, reduced_base)
extra_rel = make_subject(l, r, r_ab*r_bc*r_cd*r_ac)

# %% [markdown]
# Now it reduces

# %%
reduce(reduce(eq, RewritingSystem(extra_rel)), reduced_base)
